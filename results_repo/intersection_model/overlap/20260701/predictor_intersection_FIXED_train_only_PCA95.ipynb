# %% [markdown]
# # Intersection / Overlap classifier — FIXED
#
# Notebook corregido para entrenar un **modelo independiente de victim–perpetrator overlap** (`INTERSECT`) evitando leakage:
#
# - Se crea `INTERSECT = (VÍCTIMA > 0) & (PERPETRADOR > 0)`.
# - Se hace **train/test split antes de escalar y antes de PCA**.
# - `MinMaxScaler`, medias de centrado y `PCA` se ajustan **solo con train**.
# - Test se transforma con el scaler/PCA ya ajustado en train.
# - Se usa el mismo criterio PCA de los otros modelos: **componentes hasta preservar ≥95% de varianza**.
# - Se guardan predicciones, métricas, binarios TP/FP/TN/FN, varianza PCA y loadings.
#
# Ejecutar después de tener disponibles:
#
# - `./data/lista_global_vars.csv`
# - `./data/target_col.csv`

# %%
import os
import json
from pathlib import Path
import itertools
import random

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    balanced_accuracy_score,
    precision_score,
    recall_score,
    f1_score,
)

import joblib
import tensorflow as tf
from tensorflow.keras import layers, models, mixed_precision
from tensorflow.keras.callbacks import EarlyStopping, Callback

# ============================================================
# Configuración general
# ============================================================
SEED = 42
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

OUTPUT_DIR = Path("./content/intersection_fixed")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

PCA_VARIANCE_THRESHOLD = 0.95
TEST_SIZE = 0.25
BATCH_SIZE = 128

# Si quieres una búsqueda rápida para probar, pon FAST_GRID=True.
# Para replicar una búsqueda más amplia, deja FAST_GRID=False.
FAST_GRID = False

print("TensorFlow:", tf.__version__)
print("GPU available:", bool(tf.config.list_physical_devices("GPU")))
print("Output dir:", OUTPUT_DIR)


# ============================================================
# Helpers
# ============================================================
def report_to_dataframe(y_true, y_pred):
    """classification_report robusto para guardar como CSV sin romper Colab."""
    report_dict = classification_report(
        y_true,
        y_pred,
        digits=3,
        output_dict=True,
        zero_division=0,
    )

    rows = []
    for label, metrics in report_dict.items():
        if isinstance(metrics, dict):
            rows.append({
                "label": label,
                "precision": metrics.get("precision"),
                "recall": metrics.get("recall"),
                "f1-score": metrics.get("f1-score"),
                "support": metrics.get("support"),
            })
        else:
            rows.append({
                "label": label,
                "precision": None,
                "recall": None,
                "f1-score": metrics,
                "support": report_dict["weighted avg"]["support"],
            })
    return pd.DataFrame(rows)


def binary_metrics_dataframe(y_true, y_pred, label_name="intersection"):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()
    ppv = tp / (tp + fp) if (tp + fp) > 0 else np.nan
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else np.nan
    specificity = tn / (tn + fp) if (tn + fp) > 0 else np.nan
    npv = tn / (tn + fn) if (tn + fn) > 0 else np.nan
    f1 = 2 * ppv * sensitivity / (ppv + sensitivity) if (ppv + sensitivity) > 0 else np.nan
    acc = (tp + tn) / (tp + fp + tn + fn)
    bal_acc = (sensitivity + specificity) / 2

    return pd.DataFrame([{
        "outcome": label_name,
        "accuracy": acc,
        "balanced_accuracy": bal_acc,
        "precision_ppv": ppv,
        "recall_sensitivity": sensitivity,
        "specificity": specificity,
        "npv": npv,
        "f1_positive": f1,
        "TP": int(tp),
        "FP": int(fp),
        "TN": int(tn),
        "FN": int(fn),
        "support": int(tp + fp + tn + fn),
    }])


def fit_train_only_pca(X_train_df, X_test_df, threshold=0.95, output_dir=OUTPUT_DIR):
    """
    Fit MinMaxScaler + PCA SOLO con train y transforma train/test.
    Replica la lógica de los notebooks originales: MinMaxScaler -> centrar con medias -> PCA.
    """
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    scaler = MinMaxScaler(feature_range=(0, 1))
    X_train_scaled = scaler.fit_transform(X_train_df.values)
    X_test_scaled = scaler.transform(X_test_df.values)

    means_array = X_train_scaled.mean(axis=0)
    means = pd.Series(means_array, index=X_train_df.columns, name="mean")

    X_train_centered = X_train_scaled - means_array
    X_test_centered = X_test_scaled - means_array

    pca = PCA(n_components=X_train_df.shape[1], random_state=SEED)
    X_train_pca_all = pca.fit_transform(X_train_centered)
    X_test_pca_all = pca.transform(X_test_centered)

    cols_all = [f"PC{i+1}" for i in range(X_train_df.shape[1])]
    var_ratio = pca.explained_variance_ratio_
    cum_var = var_ratio.cumsum()
    df_variance = pd.DataFrame({
        "PC": cols_all,
        "explained variance": var_ratio,
        "cumulative variance": cum_var,
    })

    n_components = int(np.searchsorted(cum_var, threshold) + 1)
    cols = cols_all[:n_components]

    X_train_pca = pd.DataFrame(X_train_pca_all[:, :n_components], index=X_train_df.index, columns=cols)
    X_test_pca = pd.DataFrame(X_test_pca_all[:, :n_components], index=X_test_df.index, columns=cols)

    # Loadings completos y reducidos
    loadings = pd.DataFrame(
        pca.components_,
        columns=X_train_df.columns,
        index=cols_all,
    )

    top_rows = []
    for pc in cols:
        s = loadings.loc[pc].sort_values(key=np.abs, ascending=False).head(10)
        row = {"PC": pc}
        for i, (var, val) in enumerate(s.items(), start=1):
            row[f"var_{i}"] = var
            row[f"loading_{i}"] = val
        top_rows.append(row)
    top_loadings = pd.DataFrame(top_rows)

    # Guardar artefactos
    joblib.dump(scaler, output_dir / "scaler_minmax_train_only.pkl")
    joblib.dump(pca, output_dir / "pca_train_only.pkl")
    means.to_csv(output_dir / "pca_train_means.csv", encoding="utf-8-sig")
    df_variance.to_csv(output_dir / "df_PCA_variance_intersection.csv", index=False, encoding="utf-8-sig")
    loadings.to_csv(output_dir / "pca_loadings_intersection.csv", encoding="utf-8-sig")
    top_loadings.to_csv(output_dir / "pca_top_loadings_intersection.csv", index=False, encoding="utf-8-sig")
    X_train_pca.to_csv(output_dir / "X_train_pca.csv", index=True, encoding="utf-8-sig")
    X_test_pca.to_csv(output_dir / "X_test_pca.csv", index=True, encoding="utf-8-sig")

    print(f"PCA threshold: {threshold}")
    print(f"PCA components retained: {n_components}")
    print(f"Cumulative variance retained: {cum_var[n_components-1]:.4f}")

    return X_train_pca, X_test_pca, df_variance, loadings, top_loadings, scaler, pca, means


class OverfitStopping(Callback):
    def __init__(self, threshold=0.15):
        super().__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        tr = logs.get("recall")
        vr = logs.get("val_recall")
        if tr is not None and vr is not None and (tr - vr) > self.threshold:
            print(f"\nDetenido en epoch {epoch+1}: Δrecall > {self.threshold}")
            self.model.stop_training = True


def train_overlap_nn(X_train_df, X_test_df, y_train_s, y_test_s, output_dir=OUTPUT_DIR, batch_size=128, fast_grid=False):
    """Entrena red neuronal para INTERSECT sobre PCA ya ajustado solo con train."""
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    # Estrategia TPU/GPU/CPU
    try:
        resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
        tf.config.experimental_connect_to_cluster(resolver)
        tf.tpu.experimental.initialize_tpu_system(resolver)
        strategy = tf.distribute.TPUStrategy(resolver)
        print("👾 TPU inicializado:", resolver.master())
    except Exception:
        strategy = tf.distribute.get_strategy()
        print("⚠️ No se encontró TPU, usando", type(strategy).__name__)

    # En GPU/CPU normal puede ir mejor float32 que bfloat16. En TPU, bfloat16 suele ir bien.
    try:
        if "TPUStrategy" in type(strategy).__name__:
            mixed_precision.set_global_policy("mixed_bfloat16")
        else:
            mixed_precision.set_global_policy("float32")
        print("Política de precisión:", mixed_precision.global_policy())
    except Exception as e:
        print("No se pudo ajustar mixed precision:", e)

    X_train = X_train_df.values.astype("float32")
    X_test = X_test_df.values.astype("float32")
    y_train = y_train_s.astype(int).values
    y_test = y_test_s.astype(int).values

    unique_classes, counts = np.unique(y_train, return_counts=True)
    class_weight = {int(cls): 1.0 for cls in unique_classes}
    if set(unique_classes) == {0, 1}:
        n0 = counts[unique_classes == 0].sum()
        n1 = counts[unique_classes == 1].sum()
        class_weight = {0: 1.0, 1: float(n0 / n1)}
    print("Class weight:", class_weight)

    train_ds = (
        tf.data.Dataset.from_tensor_slices((X_train, y_train))
        .shuffle(10000, seed=SEED)
        .batch(batch_size)
        .prefetch(tf.data.AUTOTUNE)
    )
    test_ds = (
        tf.data.Dataset.from_tensor_slices((X_test, y_test))
        .batch(batch_size)
        .prefetch(tf.data.AUTOTUNE)
    )

    if fast_grid:
        grid_params = {
            "u1": [64, 32], "a1": ["relu", "tanh"], "d1": [0.3, 0.2],
            "u2": [16, 8],  "a2": ["relu", "tanh"], "d2": [0.1, 0.05],
        }
    else:
        grid_params = {
            "u1": [64, 32, 16], "a1": ["relu", "linear", "tanh", "sigmoid"], "d1": [0.3, 0.2, 0.1],
            "u2": [16, 8, 4],   "a2": ["relu", "linear", "tanh", "sigmoid"], "d2": [0.1, 0.05, 0.0],
        }

    thresholds = [0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.50]

    results = []
    best = None
    best_model = None
    best_probs = None
    best_preds = None

    with strategy.scope():
        for u1, a1, d1, u2, a2, d2 in itertools.product(
            grid_params["u1"], grid_params["a1"], grid_params["d1"],
            grid_params["u2"], grid_params["a2"], grid_params["d2"]
        ):
            tf.keras.backend.clear_session()
            model = models.Sequential([
                layers.Input(shape=(X_train.shape[1],)),
                layers.Dense(u1, activation=a1),
                layers.Dropout(d1),
                layers.Dense(u2, activation=a2),
                layers.Dropout(d2),
                layers.Dense(1, activation="sigmoid", dtype="float32"),
            ])
            model.compile(
                optimizer=tf.keras.optimizers.Adam(1e-3),
                loss="binary_crossentropy",
                metrics=[
                    tf.keras.metrics.Recall(name="recall"),
                    tf.keras.metrics.Precision(name="precision"),
                    tf.keras.metrics.BinaryAccuracy(name="accuracy"),
                ],
            )

            model.fit(
                train_ds,
                validation_data=test_ds,
                epochs=200,
                class_weight=class_weight,
                callbacks=[
                    OverfitStopping(0.15),
                    EarlyStopping(monitor="val_recall", mode="max", patience=8, restore_best_weights=True),
                ],
                verbose=0,
            )

            probs = model.predict(test_ds, verbose=0).flatten()

            for thr in thresholds:
                preds = (probs >= thr).astype(int)
                tn, fp, fn, tp = confusion_matrix(y_test, preds, labels=[0, 1]).ravel()
                sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0.0
                specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0
                precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
                npv = tn / (tn + fn) if (tn + fn) > 0 else 0.0
                f1 = f1_score(y_test, preds, zero_division=0)
                acc = accuracy_score(y_test, preds)
                bal_acc = balanced_accuracy_score(y_test, preds)

                row = {
                    "u1": u1, "a1": a1, "d1": d1,
                    "u2": u2, "a2": a2, "d2": d2,
                    "threshold": thr,
                    "accuracy": acc,
                    "balanced_accuracy": bal_acc,
                    "recall_sensitivity": sensitivity,
                    "specificity": specificity,
                    "precision_ppv": precision,
                    "npv": npv,
                    "f1_positive": f1,
                    "TP": int(tp), "FP": int(fp), "TN": int(tn), "FN": int(fn),
                }
                results.append(row)

                # Criterio de selección para screening:
                # 1) prioriza recall >= .80; 2) maximiza balanced accuracy; 3) desempata por NPV y F1.
                eligible = sensitivity >= 0.80
                score_tuple = (
                    1 if eligible else 0,
                    bal_acc,
                    npv,
                    f1,
                    sensitivity,
                    specificity,
                )
                if best is None or score_tuple > best["score_tuple"]:
                    best = dict(row)
                    best["score_tuple"] = score_tuple
                    best_model = model
                    best_probs = probs.copy()
                    best_preds = preds.copy()

            print("Evaluado:", {"u1": u1, "a1": a1, "d1": d1, "u2": u2, "a2": a2, "d2": d2})

    df_results = pd.DataFrame(results)
    df_results.to_csv(output_dir / "gridsearch_results_intersection.csv", index=False, encoding="utf-8-sig")

    # Guardar mejor modelo y mejor configuración
    if best_model is not None:
        best_model.save(output_dir / "best_model_intersection.keras")

    best_public = {k: v for k, v in best.items() if k != "score_tuple"}
    with open(output_dir / "best_config_intersection.json", "w", encoding="utf-8") as f:
        json.dump(best_public, f, indent=2, ensure_ascii=False)

    # Guardar splits y matrices
    splits = {
        "train": X_train_df.index.astype(int).tolist(),
        "test": X_test_df.index.astype(int).tolist(),
    }
    with open(output_dir / "splits_indices.json", "w", encoding="utf-8") as f:
        json.dump(splits, f, indent=2)

    X_train_df.to_csv(output_dir / "X_train.csv", index=True, encoding="utf-8-sig")
    X_test_df.to_csv(output_dir / "X_test.csv", index=True, encoding="utf-8-sig")
    y_train_s.to_csv(output_dir / "y_train.csv", index=True, encoding="utf-8-sig")
    y_test_s.to_csv(output_dir / "y_test.csv", index=True, encoding="utf-8-sig")

    # Predicciones finales con el mejor threshold
    df_pred = pd.DataFrame({
        "idx_original": X_test_df.index,
        "y_true_intersection": y_test,
        "y_pred_intersection": best_preds.astype(int),
        "y_prob_intersection": best_probs,
        "threshold": best_public["threshold"],
    }).sort_values("idx_original")
    df_pred.to_csv(output_dir / "predictions_with_probs.csv", index=False, encoding="utf-8-sig")

    df_report = report_to_dataframe(y_test, best_preds)
    df_report.to_csv(output_dir / "results_intersection.csv", index=False, encoding="utf-8-sig")

    df_binary = binary_metrics_dataframe(y_test, best_preds, label_name="intersection")
    df_binary.to_csv(output_dir / "binary_metrics_intersection.csv", index=False, encoding="utf-8-sig")

    print("\n=== BEST CONFIG — INTERSECTION ===")
    print(pd.Series(best_public).to_string())

    print("\n=== FINAL REPORT — INTERSECTION ===")
    print(df_report.to_string(index=False))

    print("\n=== BINARY METRICS — INTERSECTION ===")
    print(df_binary.to_string(index=False))

    print("\nSaved files in:", output_dir)
    return df_results, best_public, df_pred, df_report, df_binary


# ============================================================
# 1) Carga y preparación de datos igual que el notebook original
# ============================================================
feat_df = pd.read_csv("./data/lista_global_vars.csv")
target_df = pd.read_csv("./data/target_col.csv").fillna(0)

print("Dim características:", feat_df.shape)
print("Dim target:", target_df.shape)
print("Valores faltantes:", feat_df.isna().sum().sum() + target_df.isna().sum().sum())
print("Target columns:", target_df.columns.to_list())

# Join + eliminación de categorías muy desbalanceadas, igual que en los otros notebooks.
df_merged = feat_df.join(target_df, how="inner")
df_merged = (
    df_merged[~((df_merged["GENERO_BIN_2"] == 1) | (df_merged["ORIENTSEX.BN_3"] == 1))]
    .drop(columns=["GENERO_BIN_2", "ORIENTSEX.BN_3"])
    .reset_index(drop=True)
)

# Target específico de overlap/intersección.
df_merged["INTERSECT"] = ((df_merged["VÍCTIMA"] > 0) & (df_merged["PERPETRADOR"] > 0)).astype(int)

print("\n=== CHECK TARGET INTERSECT EN MUESTRA COMPLETA ===")
print(df_merged["INTERSECT"].value_counts().sort_index())
print(df_merged["INTERSECT"].value_counts(normalize=True).sort_index())
print("Total analytical sample after filtering:", len(df_merged))
print("Total INTERSECT:", int(df_merged["INTERSECT"].sum()))

# Eliminar columnas de outcome/derivadas para evitar leakage conceptual.
drop_target_cols = [
    "VÍCTIMA", "PERPETRADOR", "VICTIMA_PERPETRADOR",
    "POLIVICTIMIZACION", "POLIPERPETRACION",
    "SOLO.VICTIMA", "SOLO.PERPETRADOR", "NO.VICT_NO.PERP",
    "V.O", "P.SUM.TOTAL", "V.SUM.TOTAL",
]
df_intersection = df_merged.drop(columns=drop_target_cols)
X = df_intersection.drop(columns=["INTERSECT"]).copy()
y = df_intersection["INTERSECT"].astype(int).copy()

# Recodificaciones idénticas al notebook de intersection original.
pd.set_option("future.no_silent_downcasting", True)

X["PAÍS"] = X["PAÍS"].replace({1: True, 2: False})
X["ETNIA.BN"] = X["ETNIA.BN"].replace({0.0: False, 1.0: True})
X["FUGAS.BN"] = X["FUGAS.BN"].replace({0.0: False, 1.0: True})

# Alternativa usada en el notebook original: convertir dummy de género/orientación a booleanos sin limpiar.
X["GENERO.BN0"] = X["GENERO_BIN_0"].replace({0.0: False, 1.0: True})
X["ORIENTSEX.BN0"] = X["ORIENTSEX.BN_1"].replace({0.0: False, 1.0: True})
X["GENERO.BN1"] = X["GENERO_BIN_1"].replace({0.0: False, 1.0: True})
X["ORIENTSEX.BN1"] = X["ORIENTSEX.BN_2"].replace({0.0: False, 1.0: True})
X = X.drop(columns=["GENERO_BIN_0", "GENERO_BIN_1", "ORIENTSEX.BN_1", "ORIENTSEX.BN_2"])

# Convive con hermanos / cero progenitores, igual que original.
X = X.rename(columns={"CONVIVEN.5": "CONVIVEN_H"})
X["CONVIVEN_H"] = X["CONVIVEN_H"].replace({0.0: False, 1.0: True})

X = X.rename(columns={"CONVIVEN.6": "CONVIVEN_0"})
X["CONVIVEN_0"] = X["CONVIVEN_0"].replace({0.0: False, 1.0: True})

# Asegurar numérico para scaler/PCA.
X = X.apply(pd.to_numeric, errors="coerce")
if X.isna().sum().sum() > 0:
    print("WARNING: Hay NaN tras conversión numérica. Se imputan a 0 para mantener el pipeline original.")
    print(X.isna().sum()[X.isna().sum() > 0])
    X = X.fillna(0)

X.to_csv(OUTPUT_DIR / "df_intersection_feat.csv", index=True, encoding="utf-8-sig")
y.to_csv(OUTPUT_DIR / "df_intersection_target.csv", index=True, encoding="utf-8-sig")

print("\nX shape:", X.shape)
print("y shape:", y.shape)
print("Feature columns:", X.columns.tolist())


# ============================================================
# 2) Split ANTES de scaler/PCA para evitar leakage
# ============================================================
idx_train, idx_test = train_test_split(
    X.index,
    test_size=TEST_SIZE,
    random_state=SEED,
    stratify=y,
)

X_train_raw = X.loc[idx_train].copy()
X_test_raw = X.loc[idx_test].copy()
y_train = y.loc[idx_train].copy()
y_test = y.loc[idx_test].copy()

print("\n=== CHECK SPLIT ===")
print("Train size:", len(idx_train), "Test size:", len(idx_test))
print("y_train value_counts:")
print(y_train.value_counts().sort_index())
print("y_test value_counts:")
print(y_test.value_counts().sort_index())


# ============================================================
# 3) PCA train-only, mismo criterio 95% que victim/perp
# ============================================================
X_train_pca, X_test_pca, df_variance, loadings, top_loadings, scaler, pca, means = fit_train_only_pca(
    X_train_raw,
    X_test_raw,
    threshold=PCA_VARIANCE_THRESHOLD,
    output_dir=OUTPUT_DIR,
)

print("\n=== TOP LOADINGS RETAINED PCS ===")
display(top_loadings)


# ============================================================
# 4) Entrenar modelo independiente de overlap/intersection
# ============================================================
df_results, best_config, df_pred, df_report, df_binary = train_overlap_nn(
    X_train_pca,
    X_test_pca,
    y_train,
    y_test,
    output_dir=OUTPUT_DIR,
    batch_size=BATCH_SIZE,
    fast_grid=FAST_GRID,
)
# Out:
# TensorFlow: 2.20.0
# GPU available: True
# Output dir: content/intersection_fixed
# Dim características: (4024, 29)
# Dim target: (4024, 11)
# Valores faltantes: 0
# Target columns: ['VÍCTIMA', 'PERPETRADOR', 'VICTIMA_PERPETRADOR', 'POLIVICTIMIZACION', 'POLIPERPETRACION', 'SOLO.VICTIMA', 'SOLO.PERPETRADOR', 'NO.VICT_NO.PERP', 'V.O', 'P.SUM.TOTAL', 'V.SUM.TOTAL']
#
# === CHECK TARGET INTERSECT EN MUESTRA COMPLETA ===
# INTERSECT
# 0    3054
# 1     713
# Name: count, dtype: int64
# INTERSECT
# 0    0.810725
# 1    0.189275
# Name: proportion, dtype: float64
# Total analytical sample after filtering: 3767
# Total INTERSECT: 713
#
# X shape: (3767, 27)
# y shape: (3767,)
# Feature columns: ['PAÍS', 'ETNIA.BN', 'EDAD', 'FUGAS.BN', 'ABUSOSUBS1', 'ABUSOSUBS2', 'CONVIVEN.1', 'CONVIVEN.2', 'CONVIVEN.3', 'CONVIVEN.4', 'CONVIVEN_H', 'CONVIVEN_0', 'AUTOEFIC.MEAN', 'AUTOEFIC.VAR', 'IMPULS.MEAN', 'IMPULS.MEDIAN', 'IMPULS.VAR', 'APOYO.MEAN', 'APOYO.MEDIAN', 'APOYO.VAR', 'MORAL.MEAN', 'MORAL.VAR', 'PORNO.T', 'GENERO.BN0', 'ORIENTSEX.BN0', 'GENERO.BN1', 'ORIENTSEX.BN1']
#
# === CHECK SPLIT ===
# Train size: 2825 Test size: 942
# y_train value_counts:
# INTERSECT
# 0    2290
# 1     535
# Name: count, dtype: int64
# y_test value_counts:
# INTERSECT
# 0    764
# 1    178
# Name: count, dtype: int64
# PCA threshold: 0.95
# PCA components retained: 18
# Cumulative variance retained: 0.9500
#
# === TOP LOADINGS RETAINED PCS ===
#       PC          var_1  loading_1          var_2  loading_2          var_3  \
# 0    PC1     GENERO.BN0   0.661408     GENERO.BN1  -0.661408        PORNO.T
# 1    PC2     CONVIVEN_H   0.663658     CONVIVEN.2   0.532331       ETNIA.BN
# 2    PC3  ORIENTSEX.BN0   0.618468  ORIENTSEX.BN1  -0.618468     CONVIVEN_H
# 3    PC4       ETNIA.BN   0.601288     CONVIVEN_H   0.590107     CONVIVEN.2
# 4    PC5     ABUSOSUBS1   0.447878           EDAD   0.441129       ETNIA.BN
# 5    PC6     CONVIVEN.2   0.574141       ETNIA.BN   0.410065       FUGAS.BN
# 6    PC7       FUGAS.BN   0.538397           EDAD  -0.498498   APOYO.MEDIAN
# 7    PC8       FUGAS.BN   0.483821   APOYO.MEDIAN   0.454137           EDAD
# 8    PC9     CONVIVEN_0   0.824569     CONVIVEN.1  -0.426904       FUGAS.BN
# 9   PC10        PORNO.T   0.702710           EDAD  -0.403165       FUGAS.BN
# 10  PC11     CONVIVEN.1   0.685388     CONVIVEN.3  -0.457525     CONVIVEN_0
# 11  PC12     ABUSOSUBS1   0.570582        PORNO.T  -0.501452     ABUSOSUBS2
# 12  PC13           PAÍS   0.833343       ETNIA.BN   0.340804     CONVIVEN.3
# 13  PC14     CONVIVEN.3   0.611882     CONVIVEN.1   0.426490           PAÍS
# 14  PC15      APOYO.VAR   0.505212     IMPULS.VAR   0.378861   APOYO.MEDIAN
# 15  PC16     MORAL.MEAN   0.643328      MORAL.VAR  -0.478214  IMPULS.MEDIAN
# 16  PC17  IMPULS.MEDIAN   0.464294  AUTOEFIC.MEAN  -0.430154   AUTOEFIC.VAR
# 17  PC18   AUTOEFIC.VAR   0.499639      APOYO.VAR  -0.498870  AUTOEFIC.MEAN
#
#     loading_3          var_4  loading_4          var_5  ...          var_6  \
# 0    0.283769  ORIENTSEX.BN1  -0.125134  ORIENTSEX.BN0  ...  AUTOEFIC.MEAN
# 1   -0.200309  ORIENTSEX.BN0   0.193844  ORIENTSEX.BN1  ...       FUGAS.BN
# 2   -0.285456        PORNO.T  -0.187334     CONVIVEN.2  ...   APOYO.MEDIAN
# 3   -0.339355           PAÍS  -0.276534     CONVIVEN.3  ...      APOYO.VAR
# 4   -0.387802     CONVIVEN.2  -0.311232     ABUSOSUBS2  ...       FUGAS.BN
# 5    0.338259           EDAD   0.290556     ABUSOSUBS1  ...     CONVIVEN.3
# 6   -0.337992      APOYO.VAR   0.301595     APOYO.MEAN  ...       ETNIA.BN
# 7   -0.392356     APOYO.MEAN   0.382890      APOYO.VAR  ...     CONVIVEN_0
# 8   -0.199166       ETNIA.BN  -0.158366     CONVIVEN.2  ...        PORNO.T
# 9   -0.367484     ABUSOSUBS1   0.210835     CONVIVEN_0  ...     CONVIVEN.3
# 10   0.359692     CONVIVEN.4  -0.302828     CONVIVEN.2  ...        PORNO.T
# 11   0.428286           EDAD  -0.291503       FUGAS.BN  ...           PAÍS
# 12  -0.297839     CONVIVEN.1  -0.193927     ABUSOSUBS2  ...     CONVIVEN.2
# 13   0.304841     CONVIVEN_0   0.293068      APOYO.VAR  ...     CONVIVEN.2
# 14   0.334597   AUTOEFIC.VAR   0.311925  IMPULS.MEDIAN  ...      MORAL.VAR
# 15  -0.412519    IMPULS.MEAN  -0.251218   AUTOEFIC.VAR  ...  AUTOEFIC.MEAN
# 16   0.396427     MORAL.MEAN   0.383451    IMPULS.MEAN  ...   APOYO.MEDIAN
# 17  -0.443577  IMPULS.MEDIAN  -0.368923   APOYO.MEDIAN  ...     IMPULS.VAR
#
#    loading_6          var_7 loading_7          var_8 loading_8          var_9  \
# 0   0.057381     CONVIVEN_H -0.050241     MORAL.MEAN -0.049408     IMPULS.VAR
# 1  -0.163849     CONVIVEN.1  0.160773   APOYO.MEDIAN  0.116181           PAÍS
# 2   0.110011     GENERO.BN1  0.095754     GENERO.BN0 -0.095754       FUGAS.BN
# 3   0.112016       FUGAS.BN  0.110459     CONVIVEN_0  0.101226   APOYO.MEDIAN
# 4   0.261583     CONVIVEN_H  0.258134        PORNO.T  0.223950           PAÍS
# 5  -0.254036     ABUSOSUBS2  0.191865     CONVIVEN_H -0.188855        PORNO.T
# 6  -0.258845           PAÍS  0.158049  AUTOEFIC.MEAN -0.152116  ORIENTSEX.BN0
# 7   0.165171  AUTOEFIC.MEAN  0.139936     CONVIVEN.1 -0.105593  ORIENTSEX.BN1
# 8   0.106692   APOYO.MEDIAN -0.080342     CONVIVEN.4  0.073975     APOYO.MEAN
# 9   0.178322     GENERO.BN1  0.148675     GENERO.BN0 -0.148675     ABUSOSUBS2
# 10  0.166706           EDAD -0.129311           PAÍS -0.039901     ABUSOSUBS2
# 11 -0.129295     MORAL.MEAN -0.117145     GENERO.BN1 -0.116092     GENERO.BN0
# 12 -0.111433     MORAL.MEAN -0.086614       FUGAS.BN -0.071662        PORNO.T
# 13  0.207424   APOYO.MEDIAN  0.159880           EDAD  0.148241   AUTOEFIC.VAR
# 14  0.295860     CONVIVEN.3 -0.275482     CONVIVEN.1 -0.178071    IMPULS.MEAN
# 15  0.143499      APOYO.VAR  0.131279   APOYO.MEDIAN -0.116950     IMPULS.VAR
# 16  0.270031      MORAL.VAR -0.266202      APOYO.VAR  0.154344     APOYO.MEAN
# 17  0.196537    IMPULS.MEAN -0.186296      MORAL.VAR  0.105929     CONVIVEN.1
#
#    loading_9         var_10 loading_10
# 0  -0.031012           PAÍS  -0.025939
# 1   0.113427     CONVIVEN.3  -0.112305
# 2  -0.095601     APOYO.MEAN   0.094499
# 3  -0.095150     APOYO.MEAN  -0.087378
# 4   0.168851  ORIENTSEX.BN1  -0.130459
# 5   0.152477           PAÍS  -0.145767
# 6   0.113508  ORIENTSEX.BN1  -0.113508
# 7   0.097387  ORIENTSEX.BN0  -0.097387
# 8  -0.059984           PAÍS  -0.059204
# 9   0.120236       ETNIA.BN   0.096590
# 10  0.035813     GENERO.BN1   0.034228
# 11  0.116092     CONVIVEN.1   0.097348
# 12 -0.071284      MORAL.VAR   0.064665
# 13  0.138842       ETNIA.BN   0.130652
# 14 -0.167537       ETNIA.BN  -0.134092
# 15  0.116628     APOYO.MEAN  -0.068475
# 16  0.100943       ETNIA.BN   0.082977
# 17  0.035848     CONVIVEN.2   0.034395
#
# [18 rows x 21 columns]
# ⚠️ No se encontró TPU, usando _DefaultDistributionStrategy
# Política de precisión: <DTypePolicy "float32">
# Class weight: {0: 1.0, 1: 4.280373831775701}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.05}
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a5458124e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.0}
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a55a857dbc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 4, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 4, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 4, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 4, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 4, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 4, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 4, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 4, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 4, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'linear', 'd1': 0.1, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 4, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 4, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 4, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 4, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 4, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 4, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 4, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 4, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 4, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'tanh', 'd1': 0.1, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0}
#
# Detenido en epoch 3: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.05}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.0}
#
# Detenido en epoch 7: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.1}
#
# Detenido en epoch 2: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.05}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.1}
#
# Detenido en epoch 4: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.05}
#
# Detenido en epoch 6: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05}
#
# Detenido en epoch 3: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.1}
#
# Detenido en epoch 3: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.05}
#
# Detenido en epoch 4: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.1}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.05}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.0}
#
# Detenido en epoch 6: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.1}
#
# Detenido en epoch 4: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.1}
#
# Detenido en epoch 4: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.05}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.0}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.1}
#
# Detenido en epoch 4: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.05}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.0}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.1}
#
# Detenido en epoch 3: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.05}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.0}
#
# Detenido en epoch 3: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.1}
#
# Detenido en epoch 2: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.05}
#
# Detenido en epoch 2: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1}
#
# Detenido en epoch 2: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0}
#
# Detenido en epoch 2: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.1}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.0}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.05}
#
# Detenido en epoch 1: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.1}
#
# Detenido en epoch 2: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.05}
#
# Detenido en epoch 2: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.1}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.05}
#
# Detenido en epoch 2: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.0}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.1}
#
# Detenido en epoch 2: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.05}
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.0}
#
# Detenido en epoch 2: Δrecall > 0.15
# Evaluado: {'u1': 64, 'a1': 'sigmoid', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_406/4045582897.py in <cell line: 0>()
#     518 # 4) Entrenar modelo independiente de overlap/intersection
#     519 # ============================================================
# --> 520 df_results, best_config, df_pred, df_report, df_binary = train_overlap_nn(
#     521     X_train_pca,
#     522     X_test_pca,
#
# /tmp/ipykernel_406/4045582897.py in train_overlap_nn(X_train_df, X_test_df, y_train_s, y_test_s, output_dir, batch_size, fast_grid)
#     290             )
#     291
# --> 292             model.fit(
#     293                 train_ds,
#     294                 validation_data=test_ds,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     421                         shuffle=False,
#     422                     )
# --> 423                 val_logs = self.evaluate(
#     424                     x=val_x,
#     425                     y=val_y,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     509             for begin_step, end_step, iterator in epoch_iterator:
#     510                 callbacks.on_test_batch_begin(begin_step)
# --> 511                 logs = self.test_function(iterator)
#     512                 callbacks.on_test_batch_end(end_step, logs)
#     513                 if self.stop_evaluating:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     239                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240             ):
# --> 241                 opt_outputs = multi_step_on_iterator(iterator)
#     242                 if not opt_outputs.has_value():
#     243                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
