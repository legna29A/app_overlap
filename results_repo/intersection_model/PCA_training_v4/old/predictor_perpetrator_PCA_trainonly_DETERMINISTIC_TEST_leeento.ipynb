# %% [markdown]
# # PCA train-only DETERMINISTIC TEST
#
# Versión de prueba para perpetrador: split antes de escalado/PCA, scaler/PCA ajustados solo en train y entrenamiento DNN con semillas/determinismo reforzado. Guarda resultados en `./content/perpetrator`.

# %% [markdown]
# # Perpetrator clasificator
# Script backend para construir y evaluar el clasificador de perpetrador.<br>
# Junta todas las celdas de código en una.<br>
# Construye la tabla con datos, el conjunto de entrenamiento y validación.<br>
# Entrena el modelo DNN, lo evalua y muestra los resultados de la evaluación como resultado final.<br>

# %% [markdown]
# ### Pre-condición
# Tu gráfica puede ayudarte con el cálculo, comprúebalo ejecutando el código de aqui abajo👇

# %%
#%pip install torch
import torch
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# ### Ejecución
# El siguiente código realiza el proceso de clasificación explicado al comienzo.

# %%
# ============================
# Perpetrator PCA train-only DETERMINISTIC TEST
# Cambios principales:
# - split antes de scaler/PCA
# - scaler/PCA ajustados solo en train
# - semillas fijadas para Python/NumPy/TensorFlow
# - float32 en lugar de mixed_bfloat16
# - tf.data shuffle determinista
# - Dropout e inicializadores con seed
# - clear_session antes de cada candidato
# - best model/predicciones guardados desde el candidato seleccionado, no desde variables residuales
# - output_dir se mantiene en ./content/perpetrator, como pediste
# ============================

import os
os.environ["PYTHONHASHSEED"] = "42"
os.environ["TF_DETERMINISTIC_OPS"] = "1"
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"

import re
import json
import random
import itertools
import joblib
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    balanced_accuracy_score,
)

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, Callback

RANDOM_STATE = 42
THRESHOLD = 0.50

try:
    tf.keras.utils.set_random_seed(RANDOM_STATE)
    tf.config.experimental.enable_op_determinism()
    print("Determinismo TensorFlow activado.")
except Exception as e:
    print("Aviso: no se pudo activar determinismo completo de TensorFlow:", repr(e))

# Usamos float32 para minimizar variabilidad numérica frente a mixed_bfloat16.
tf.keras.mixed_precision.set_global_policy("float32")
print("Política de precisión:", tf.keras.mixed_precision.global_policy())


def perform_pca(df: pd.DataFrame,
                save_scaler_path: str = "models/scaler_minmax.pkl",
                save_pca_path: str = "models/modelo_pca.pkl",
                save_means_path: str = "models/medias_escalado.csv"
               ):
    """
    Realiza un PCA sobre el DataFrame de entrada y devuelve:
      1) df_pca: DataFrame con las componentes principales (PC1, PC2, …).
      2) df_var: DataFrame con las varianzas explicada y acumulada por componente.
      3) scaler: MinMaxScaler ya entrenado.
      4) pca: PCA ya entrenado.
      5) means: Series con la media de cada variable tras escalado.
    Además guarda automáticamente el scaler, el modelo PCA y el vector de medias en rutas predeterminadas.

    Parámetros
    ----------
    df : pd.DataFrame
        DataFrame numérico de entrada (n muestras × p variables).
    save_scaler_path : str
        Ruta por defecto donde volcar el scaler (pickle).
    save_pca_path : str
        Ruta por defecto donde volcar el modelo PCA (pickle).
    save_means_path : str
        Ruta por defecto donde guardar las medias de cada variable tras escalado (CSV).

    Retorna
    -------
    df_pca : pd.DataFrame
        Transformación PCA (n muestras × p componentes), columnas PC1…PCp.
    df_var : pd.DataFrame
        Tabla con columnas:
          - PC: nombre de la componente ("PC1", "PC2", …)
          - explained variance: varianza explicada por cada componente
          - cumulative variance: varianza acumulada hasta esa componente
    scaler : MinMaxScaler
        Objeto scaler ajustado (fit).
    pca : PCA
        Objeto PCA ajustado (fit).
    means : pd.Series
        Media de cada variable tras el escalado (para centrar nuevos datos).
    """
    # Crear carpetas si no existen

    os.makedirs(os.path.dirname(save_scaler_path), exist_ok=True)
    os.makedirs(os.path.dirname(save_pca_path), exist_ok=True)
    os.makedirs(os.path.dirname(save_means_path), exist_ok=True)

    # 1) Escalado al rango [0,1]
    scaler = MinMaxScaler(feature_range=(0, 1))
    X_scaled = scaler.fit_transform(df.values)

    # 2) Cálculo de medias para centrar
    means_array = X_scaled.mean(axis=0)
    means = pd.Series(means_array, index=df.columns, name='mean')

    # 3) Centramos cada variable usando las medias calculadas
    X_centered = X_scaled - means_array

    # 4) Ajustar y transformar PCA
    pca = PCA(n_components=df.shape[1])
    comps = pca.fit_transform(X_centered)

    # 5) DataFrame de componentes principales
    cols = [f"PC{i+1}" for i in range(df.shape[1])]
    df_pca = pd.DataFrame(comps, index=df.index, columns=cols)

    # 6) Varianzas explicada y acumulada
    var_ratio = pca.explained_variance_ratio_
    cum_var  = var_ratio.cumsum()
    df_var = pd.DataFrame({
        "PC": cols,
        "explained variance": var_ratio,
        "cumulative variance": cum_var
    })

    # 7) Guardar a disco en rutas por defecto
    joblib.dump(scaler, save_scaler_path)
    joblib.dump(pca, save_pca_path)
    means.to_csv(save_means_path, header=True)

    return df_pca, df_var, scaler, pca, means

def plot_pca_variance(df_var):
    """
    Genera un barplot de la varianza explicada (barras amarillas) y un lineplot
    de la varianza acumulada (línea azul), marcando con un punto rojo donde
    la varianza acumulada supera el 0.95.

    Parámetros
    ----------
    df_var : pandas.DataFrame
        DataFrame con columnas:
          - "PC": nombres de componentes ("PC1", "PC2", …)
          - "explained variance": varianza explicada por componente
          - "cumulative variance": varianza acumulada
    """
    # Preparar datos
    x = range(len(df_var))
    explained = df_var['explained variance']
    cumulative = df_var['cumulative variance']

    # Crear la figura
    plt.figure(figsize=(10, 6))

    # Barplot de varianza explicada
    plt.bar(x, explained, color='orange', label='Explained Variance')

    # Lineplot de varianza acumulada
    plt.plot(x, cumulative, color='blue', marker='o', label='Cumulative Variance')

    # Punto rojo donde cumulative > 0.95
    above_idx = df_var.index[cumulative > 0.95]
    if not above_idx.empty:
        idx0 = above_idx[0]
        plt.scatter(idx0, cumulative[idx0], color='red', zorder=5, label='Cumulative > 0.95')
        plt.axvline(x=idx0, color='red', linestyle='--')

    # Configuración de ejes y leyenda
    plt.xticks(x, df_var['PC'], rotation=90)
    plt.xlabel('Principal Components')
    plt.ylabel('Variance')
    plt.title('Explained and Cumulative Variance by PCA Components')
    plt.legend()
    plt.tight_layout()
    plt.show()


def select_PCA_df(df_var: pd.DataFrame, df_PCA: pd.DataFrame, threshold: float) -> pd.DataFrame:
    """
    Selecciona las primeras i componentes principales de df_PCA donde i es el número de componente
    tal que el primer valor de 'cumulative variance' en df_var supera el umbral dado.

    Args:
        df_var (pd.DataFrame): DataFrame con columnas 'PC' (etiquetas 'PC1', 'PC2', ...) y
                               'cumulative variance' (float entre 0 y 1).
        df_PCA (pd.DataFrame): DataFrame resultante de una PCA, con tantas columnas como componentes.
        threshold (float): Umbral de varianza acumulada entre 0 y 1.

    Returns:
        pd.DataFrame: Subset de df_PCA con las primeras i columnas.
    """
    # Validación de umbral
    if not (0 <= threshold <= 1):
        raise ValueError("El umbral debe estar entre 0 y 1")

    # Buscar el primer índice que supere el threshold
    mask = df_var['cumulative variance'] > threshold
    if not mask.any():
        raise ValueError("Ningún valor de varianza acumulada supera el umbral dado")

    idx = mask.idxmax()  # índice del primer True
    pc_label = df_var.loc[idx, 'PC']  # p.ej. 'PC3'

    # Extraer i del string 'PCi'
    match = re.match(r'PC(\d+)', pc_label)
    if not match:
        raise ValueError(f"Formato inesperado en etiqueta PC: {pc_label}")
    i = int(match.group(1))

    # Seleccionar las primeras i columnas de df_PCA
    return df_PCA.iloc[:, :i]



def NN_perpetrator_classifier(
    df_features,
    df_merged_perpetrador_target,
    output_dir='./content/perpetrator',
    batch_size=128,
    grid_params=None,
    tpu_address=None,
    pca_threshold=0.95,
    random_state=RANDOM_STATE,
    threshold=THRESHOLD,
    stop_at_first_match=True,
    min_recall_1=0.90,
    min_recall_0=0.27,
):
    """
    Entrena un clasificador neuronal para perpetración con PCA train-only.

    Versión determinista para comprobar repetibilidad:
    - fija semillas de Python, NumPy y TensorFlow;
    - usa float32;
    - usa shuffle determinista con reshuffle_each_iteration=False;
    - usa seeds en Dense/Dropout;
    - limpia sesión de Keras antes de cada candidato;
    - guarda siempre los artefactos del candidato seleccionado.

    Criterio de selección por defecto:
    - candidato válido si recall_1 >= min_recall_1 y recall_0 >= min_recall_0;
    - con stop_at_first_match=True se detiene en el primer candidato válido, pero ahora debería repetir;
    - si no aparece candidato válido, se selecciona el mayor balanced_accuracy.
    """
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    # 1. Semillas globales al entrar en la función
    os.environ["PYTHONHASHSEED"] = str(random_state)
    random.seed(random_state)
    np.random.seed(random_state)
    tf.keras.utils.set_random_seed(random_state)
    try:
        tf.config.experimental.enable_op_determinism()
    except Exception:
        pass

    # 2. Estrategia. No forzamos mixed precision.
    try:
        resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu=tpu_address)
        tf.config.experimental_connect_to_cluster(resolver)
        tf.tpu.experimental.initialize_tpu_system(resolver)
        strategy = tf.distribute.TPUStrategy(resolver)
        print("👾 TPU inicializado:", resolver.master())
    except Exception:
        strategy = tf.distribute.get_strategy()
        print("⚠️ No se encontró TPU, usando", type(strategy).__name__)

    tf.keras.mixed_precision.set_global_policy("float32")
    print("Política de precisión:", tf.keras.mixed_precision.global_policy())

    # 3. Preparar datos y split
    y_series = df_merged_perpetrador_target.astype(int)
    all_idx = df_features.index.to_numpy()

    train_idx, val_idx = train_test_split(
        all_idx,
        test_size=0.25,
        random_state=random_state,
        stratify=y_series,
    )

    splits = {
        'train': train_idx.tolist(),
        'val': val_idx.tolist(),
        'pca_scope': 'train_only',
        'random_state': random_state,
        'threshold': threshold,
    }
    with open(output_dir / 'splits_indices.json', 'w', encoding='utf-8') as f:
        json.dump(splits, f, indent=2)
    print(f"Índices de split guardados en '{output_dir}/splits_indices.json'")

    # 4. PCA train-only
    X_train_raw = df_features.loc[train_idx].copy()
    X_val_raw = df_features.loc[val_idx].copy()
    y_train = y_series.loc[train_idx].values.astype(int)
    y_val = y_series.loc[val_idx].values.astype(int)

    scaler = MinMaxScaler(feature_range=(0, 1))
    X_train_scaled = scaler.fit_transform(X_train_raw.values)
    X_val_scaled = scaler.transform(X_val_raw.values)

    means_array = X_train_scaled.mean(axis=0)
    means = pd.Series(means_array, index=X_train_raw.columns, name='mean')
    X_train_centered = X_train_scaled - means_array
    X_val_centered = X_val_scaled - means_array

    pca = PCA(n_components=X_train_raw.shape[1], random_state=random_state)
    X_train_pca_all = pca.fit_transform(X_train_centered)
    X_val_pca_all = pca.transform(X_val_centered)

    var_ratio = pca.explained_variance_ratio_
    cum_var = var_ratio.cumsum()
    pc_all_cols = [f"PC{i+1}" for i in range(X_train_raw.shape[1])]
    df_variance_local = pd.DataFrame({
        "PC": pc_all_cols,
        "explained variance": var_ratio,
        "cumulative variance": cum_var,
    })
    n_components = int(np.argmax(cum_var >= pca_threshold) + 1)
    pc_cols = pc_all_cols[:n_components]

    X_train = X_train_pca_all[:, :n_components].astype("float32")
    X_val = X_val_pca_all[:, :n_components].astype("float32")

    joblib.dump(scaler, output_dir / 'scaler_minmax.pkl')
    joblib.dump(pca, output_dir / 'modelo_pca.pkl')
    means.to_csv(output_dir / 'medias_escalado.csv', header=True)
    df_variance_local.to_csv(output_dir / 'df_PCA_variance_trainonly.csv', index=False)
    pd.DataFrame(
        np.vstack([X_train, X_val]),
        columns=pc_cols,
    ).to_csv(output_dir / f'df_PCA_{int(pca_threshold*100)}_trainonly_stacked.csv', index=False)

    globals().update({
        "scaler": scaler,
        "pca": pca,
        "means": means,
        "df_variance": df_variance_local,
        "PCA_N_COMPONENTS_TRAINONLY": n_components,
    })

    print(f"PCA train-only seleccionado: {n_components} componentes (threshold={pca_threshold})")
    print(f"Train n={len(train_idx)} positives={int(y_train.sum())}; Val n={len(val_idx)} positives={int(y_val.sum())}")

    # 5. Class weights
    unique_classes, counts = np.unique(y_train, return_counts=True)
    class_weight = {int(cls): 1.0 for cls in unique_classes}
    if 0 in unique_classes and 1 in unique_classes:
        n0 = counts[unique_classes == 0].sum()
        n1 = counts[unique_classes == 1].sum()
        class_weight = {0: 1.0, 1: float(n0 / n1)}
    print("class_weight:", class_weight)

    # 6. Dataset determinista
    ds_options = tf.data.Options()
    ds_options.experimental_deterministic = True

    train_ds = (
        tf.data.Dataset.from_tensor_slices((X_train, y_train))
        .shuffle(buffer_size=len(X_train), seed=random_state, reshuffle_each_iteration=False)
        .batch(batch_size)
        .with_options(ds_options)
    )
    val_ds = (
        tf.data.Dataset.from_tensor_slices((X_val, y_val))
        .batch(batch_size)
        .with_options(ds_options)
    )

    # 7. Callback para detener por sobreajuste
    class OverfitStopping(Callback):
        def __init__(self, threshold_delta=0.1):
            super().__init__()
            self.threshold_delta = threshold_delta

        def on_epoch_end(self, epoch, logs=None):
            logs = logs or {}
            tr = logs.get('recall')
            vr = logs.get('val_recall')
            if tr is not None and vr is not None and (tr - vr) > self.threshold_delta:
                print(f"\nDetenido en epoch {epoch+1}: Δrecall > {self.threshold_delta}")
                self.model.stop_training = True

    # 8. Grid por defecto. Se mantiene igual que el notebook original.
    if grid_params is None:
        grid_params = {
            'u1': [64, 32, 16],
            'a1': ['relu', 'linear', 'tanh', 'sigmoid'],
            'd1': [0.3, 0.2, 0.1],
            'u2': [16, 8, 4],
            'a2': ['relu', 'linear', 'tanh', 'sigmoid'],
            'd2': [0.1, 0.05, 0.0],
        }

    def build_model(u1, a1, d1, u2, a2, d2, seed):
        return models.Sequential([
            layers.Input(shape=(X_train.shape[1],)),
            layers.Dense(
                u1,
                activation=a1,
                kernel_initializer=tf.keras.initializers.GlorotUniform(seed=seed + 11),
                bias_initializer=tf.keras.initializers.Zeros(),
            ),
            layers.Dropout(d1, seed=seed + 12),
            layers.Dense(
                u2,
                activation=a2,
                kernel_initializer=tf.keras.initializers.GlorotUniform(seed=seed + 21),
                bias_initializer=tf.keras.initializers.Zeros(),
            ),
            layers.Dropout(d2, seed=seed + 22),
            layers.Dense(
                1,
                activation='sigmoid',
                dtype='float32',
                kernel_initializer=tf.keras.initializers.GlorotUniform(seed=seed + 31),
                bias_initializer=tf.keras.initializers.Zeros(),
            ),
        ])

    results = []
    best_state = None
    best_valid_state = None
    condition_met = False

    candidate_iter = itertools.product(
        grid_params['u1'], grid_params['a1'], grid_params['d1'],
        grid_params['u2'], grid_params['a2'], grid_params['d2'],
    )

    with strategy.scope():
        for candidate_i, (u1, a1, d1, u2, a2, d2) in enumerate(candidate_iter):
            candidate_seed = random_state + candidate_i * 1000
            tf.keras.backend.clear_session()
            random.seed(candidate_seed)
            np.random.seed(candidate_seed)
            tf.keras.utils.set_random_seed(candidate_seed)

            model = build_model(u1, a1, d1, u2, a2, d2, candidate_seed)
            model.compile(
                optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                loss='binary_crossentropy',
                metrics=[
                    tf.keras.metrics.Recall(name='recall'),
                    tf.keras.metrics.Precision(name='precision'),
                    tf.keras.metrics.BinaryAccuracy(name='accuracy'),
                ],
            )

            history = model.fit(
                train_ds,
                validation_data=val_ds,
                epochs=200,
                class_weight=class_weight,
                callbacks=[
                    OverfitStopping(0.1),
                    EarlyStopping(
                        monitor='val_recall',
                        mode='max',
                        patience=5,
                        restore_best_weights=True,
                    ),
                ],
                verbose=0,
            )

            y_pred_probs = model.predict(val_ds, verbose=0).reshape(-1)
            y_pred = (y_pred_probs >= threshold).astype(int)
            y_val_true = y_val.astype(int)

            report = classification_report(y_val_true, y_pred, output_dict=True, zero_division=0)
            recall0 = float(report.get('0', {}).get('recall', 0))
            recall1 = float(report.get('1', {}).get('recall', 0))
            precision1 = float(report.get('1', {}).get('precision', 0))
            f1_1 = float(report.get('1', {}).get('f1-score', 0))
            accuracy = float(report.get('accuracy', 0))
            bal_acc = float(balanced_accuracy_score(y_val_true, y_pred))
            tn, fp, fn, tp = confusion_matrix(y_val_true, y_pred, labels=[0, 1]).ravel()

            row = {
                'candidate_i': candidate_i,
                'seed': candidate_seed,
                'u1': u1,
                'a1': a1,
                'd1': d1,
                'u2': u2,
                'a2': a2,
                'd2': d2,
                'recall_0': recall0,
                'recall_1': recall1,
                'precision_1': precision1,
                'f1_1': f1_1,
                'accuracy': accuracy,
                'balanced_accuracy': bal_acc,
                'TP': int(tp),
                'FP': int(fp),
                'TN': int(tn),
                'FN': int(fn),
                'epochs_run': len(history.history.get('loss', [])),
            }
            results.append(row)
            print(row)

            state = {
                'row': row,
                'report': report,
                'model': model,
                'y_pred_probs': y_pred_probs.copy(),
                'y_pred': y_pred.copy(),
            }

            # Fallback: mejor balanced accuracy si no se encuentra candidato válido.
            if best_state is None or (
                row['balanced_accuracy'], row['recall_1'], row['recall_0'], row['precision_1']
            ) > (
                best_state['row']['balanced_accuracy'], best_state['row']['recall_1'], best_state['row']['recall_0'], best_state['row']['precision_1']
            ):
                best_state = state

            is_valid = (recall1 >= min_recall_1 and recall0 >= min_recall_0)
            if is_valid:
                if best_valid_state is None or (
                    row['balanced_accuracy'], row['recall_0'], row['precision_1'], row['accuracy']
                ) > (
                    best_valid_state['row']['balanced_accuracy'], best_valid_state['row']['recall_0'], best_valid_state['row']['precision_1'], best_valid_state['row']['accuracy']
                ):
                    best_valid_state = state

                if stop_at_first_match:
                    print(
                        f"\n🚀 Condición alcanzada (recall_1={recall1:.3f}, recall_0={recall0:.3f}); "
                        "deteniendo grid-search de forma determinista."
                    )
                    condition_met = True
                    break

    df_results = pd.DataFrame(results)
    df_results.to_csv(output_dir / 'gridsearch_results.csv', index=False)

    selected = best_valid_state if best_valid_state is not None else best_state
    if selected is None:
        raise RuntimeError("No se entrenó ningún candidato del grid-search.")

    selected_row = selected['row']
    print("\nCandidato seleccionado:")
    print(pd.Series(selected_row))
    print("\nReporte seleccionado:")
    print(classification_report(y_val, selected['y_pred'], digits=3, zero_division=0))

    selected['model'].save(output_dir / 'best_model.h5')
    with open(output_dir / 'best_report.json', 'w', encoding='utf-8') as f:
        json.dump(selected['report'], f, indent=2)

    config = {
        'random_state': random_state,
        'threshold': threshold,
        'pca_threshold': pca_threshold,
        'pca_scope': 'train_only',
        'n_components': n_components,
        'batch_size': batch_size,
        'precision_policy': str(tf.keras.mixed_precision.global_policy()),
        'deterministic_ops_requested': True,
        'shuffle_seed': random_state,
        'reshuffle_each_iteration': False,
        'stop_at_first_match': stop_at_first_match,
        'min_recall_1': min_recall_1,
        'min_recall_0': min_recall_0,
        'selected_candidate': selected_row,
        'condition_met': condition_met,
    }
    with open(output_dir / 'config.json', 'w', encoding='utf-8') as f:
        json.dump(config, f, indent=2)

    # 9. Guardar conjuntos entreno/val a CSV
    pd.DataFrame(X_train, columns=pc_cols).to_csv(output_dir / 'X_train.csv', index=False)
    pd.DataFrame(X_val, columns=pc_cols).to_csv(output_dir / 'X_val.csv', index=False)
    pd.Series(y_train, name='PERPETRADOR').to_csv(output_dir / 'y_train.csv', index=False)
    pd.Series(y_val, name='PERPETRADOR').to_csv(output_dir / 'y_val.csv', index=False)

    # 10. Predicciones con probabilidades y guardado desde el candidato seleccionado
    df_pred = pd.DataFrame({
        'idx_original': val_idx,
        'y_true_perp': y_val.astype(int),
        'y_pred_perp': selected['y_pred'].astype(int),
        'y_prob_perp': selected['y_pred_probs'].astype(float),
    }).sort_values('idx_original').reset_index(drop=True)

    pred_path = output_dir / 'predictions_with_probs.csv'
    df_pred.to_csv(pred_path, index=False)

    print(f"Saved: {pred_path}")
    print(df_pred.head())
    print(df_pred.shape)

    # También dejamos best_combination compatible con tu código previo.
    best_combination = pd.Series(selected_row)
    return df_results, best_combination


#Montamos el dataset original
feat_df = pd.read_csv('./../data/lista_global_vars.csv')
target_df = pd.read_csv('./../data/target_col.csv').fillna(0) # fillna imputa los missings con la categoría 0 que es la correcta.
df_merged = feat_df.join(target_df, how='inner')
df_merged = df_merged[~((df_merged["GENERO_BIN_2"] == 1) | (df_merged["ORIENTSEX.BN_3"] == 1))].drop(columns=["GENERO_BIN_2","ORIENTSEX.BN_3"]).reset_index(drop=True)

df_merged_perpretador = df_merged.drop(columns=['VÍCTIMA', 'VICTIMA_PERPETRADOR', 'POLIVICTIMIZACION', 'POLIPERPETRACION', 'SOLO.VICTIMA', 'SOLO.PERPETRADOR', 'NO.VICT_NO.PERP', 'V.O', 'P.SUM.TOTAL', 'V.SUM.TOTAL'])

df_merged_perpetrador_feat = df_merged_perpretador.drop(columns=["PERPETRADOR"])
df_merged_perpetrador_target = df_merged_perpretador["PERPETRADOR"]

#Quitamos el warning de replace
pd.set_option('future.no_silent_downcasting', True)

#Pasamos País a Booleano
df_merged_perpetrador_feat['PAÍS'] = df_merged_perpetrador_feat['PAÍS'].replace({1: True, 2: False})
#Pasamos Etnia a Booleano
df_merged_perpetrador_feat['ETNIA.BN'] = df_merged_perpetrador_feat['ETNIA.BN'].replace({0.0: False, 1.0: True})
#Pasamos Fugas a Booleano
df_merged_perpetrador_feat['FUGAS.BN'] = df_merged_perpetrador_feat['FUGAS.BN'].replace({0.0: False, 1.0: True})
#One-hot encoding de Porno
#df_merged_perpetrador_feat = pd.get_dummies(df_merged_perpetrador_feat, columns=['PORNO.T'])
"""
# ABUSOSUBS2 hereda de ABUSOSUBS1 si es 0
df_merged_perpetrador_feat.loc[df_merged_perpetrador_feat['ABUSOSUBS1'] == 0, 'ABUSOSUBS2'] = 0
# Agrupamos ABUSOSUBS2, categoría False es nunca, anual, mensual True es Diario, Semanal. Dejamos solo la binaria
df_merged_perpetrador_feat['ABUSOSUBS2.BN'] = (~df_merged_perpetrador_feat['ABUSOSUBS2'].isin([1,2,3]))
df_merged_perpetrador_feat = df_merged_perpetrador_feat.drop(columns=["ABUSOSUBS2"])
df_merged_perpetrador_feat = pd.get_dummies(df_merged_perpetrador_feat, columns=['ABUSOSUBS1'])
"""
"""
#Limpiamos genero y orientacion sexual
df_merged_perpetrador_feat = df_merged_perpetrador_feat.drop(columns=["GENERO_BIN_1","ORIENTSEX.BN_2"])
#Renombramos
df_merged_perpetrador_feat = df_merged_perpetrador_feat.rename(columns=
                                                       {'GENERO_BIN_0': 'GENERO.BN', 'ORIENTSEX.BN_1': 'ORIENTSEX.BN'})
#Convertimos a booleano
df_merged_perpetrador_feat['GENERO.BN'] = df_merged_perpetrador_feat['GENERO.BN'].replace({0.0: False, 1.0: True})
df_merged_perpetrador_feat['ORIENTSEX.BN'] = df_merged_perpetrador_feat['ORIENTSEX.BN'].replace({0.0: False, 1.0: True})
"""

#Alternativa, convertimos a booleanos sin limpiar para no perder precisión
df_merged_perpetrador_feat['GENERO.BN0'] = df_merged_perpetrador_feat['GENERO_BIN_0'].replace({0.0: False, 1.0: True})
df_merged_perpetrador_feat['ORIENTSEX.BN0'] = df_merged_perpetrador_feat['ORIENTSEX.BN_1'].replace({0.0: False, 1.0: True})
df_merged_perpetrador_feat['GENERO.BN1'] = df_merged_perpetrador_feat['GENERO_BIN_1'].replace({0.0: False, 1.0: True})
df_merged_perpetrador_feat['ORIENTSEX.BN1'] = df_merged_perpetrador_feat['ORIENTSEX.BN_2'].replace({0.0: False, 1.0: True})
df_merged_perpetrador_feat = df_merged_perpetrador_feat.drop(columns=["GENERO_BIN_0","GENERO_BIN_1","ORIENTSEX.BN_1","ORIENTSEX.BN_2"])

#Convive con hermanos
df_merged_perpetrador_feat = df_merged_perpetrador_feat.rename(columns= {'CONVIVEN.5': 'CONVIVEN_H'})
df_merged_perpetrador_feat['CONVIVEN_H'] = df_merged_perpetrador_feat['CONVIVEN_H'].replace({0.0: False, 1.0: True})
#Conviven con 0 progenitores
df_merged_perpetrador_feat = df_merged_perpetrador_feat.rename(columns= {'CONVIVEN.6': 'CONVIVEN_0'})
df_merged_perpetrador_feat['CONVIVEN_0'] = df_merged_perpetrador_feat['CONVIVEN_0'].replace({0.0: False, 1.0: True})
"""
#Conviven con 1 progenitore
df_merged_perpetrador_feat['CONVIVEN_1'] = ((df_merged_perpetrador_feat[['CONVIVEN.1','CONVIVEN.2','CONVIVEN.3','CONVIVEN.4']] == 1).sum(axis=1) == 1)
#Conviven con 2 progenitores
df_merged_perpetrador_feat['CONVIVEN_2'] = ((df_merged_perpetrador_feat[['CONVIVEN.1','CONVIVEN.2','CONVIVEN.3','CONVIVEN.4']] == 1).sum(axis=1) > 1)
#Limpiamos las conviven viejas
df_merged_perpetrador_feat = df_merged_perpetrador_feat.drop(columns=["CONVIVEN.1","CONVIVEN.2","CONVIVEN.3","CONVIVEN.4"])
"""
#Mostramos el data-set final
display(df_merged_perpetrador_feat)

df_merged_perpetrador_feat.to_csv("df_perpetrador_feat.csv")
df_merged_perpetrador_target.to_csv("df_perpretador_target.csv")

# PCA TRAIN-ONLY TEST
# No se ajusta scaler/PCA sobre toda la muestra. El split se hace dentro del clasificador y el PCA se ajusta SOLO en train.
df_results, best_combination = NN_perpetrator_classifier(
    df_merged_perpetrador_feat,
    df_merged_perpetrador_target,
    output_dir='./content/perpetrator',
    batch_size=128,
    grid_params=None,
    tpu_address=None,
    pca_threshold=0.95
)
plot_pca_variance(df_variance)

#Mostramos las max_variables variables más importantes de cada PC hasta max_PC
max_PC = 18
max_variables = 5
loadings = pd.DataFrame(
    pca.components_,
    columns=df_merged_perpetrador_feat.columns,
    index=[f"PC{i+1}" for i in range(pca.n_components_)]
)
filas = []
for pc in loadings.index[:max_PC]:
    s = loadings.loc[pc].sort_values(key=abs, ascending=False).head(max_variables)

    fila = {"PC": pc}

    for i, (var, valor) in enumerate(s.items(), start=1):
        fila[f"var_{i}"] = var
        fila[f"loading_{i}"] = valor

    filas.append(fila)
tabla_top_pcs = pd.DataFrame(filas)
display(tabla_top_pcs)

# Comprobación final del CSV de predicciones para SMART AND
data_set = pd.read_csv('./content/perpetrator/predictions_with_probs.csv')

print("=== CHECK predictions_with_probs.csv ===")
print(data_set.head())
print(data_set.shape)
print(data_set.columns.tolist())

true_column = data_set['y_true_perp']
pred_column = data_set['y_pred_perp']

print(classification_report(true_column, pred_column, digits=3))
# Out:
# Determinismo TensorFlow activado.
# Política de precisión: <DTypePolicy "float32">
# /var/folders/5x/ww_kz7lx5wz4pn1typnpk_g40000gn/T/ipykernel_51422/2507511522.py:622: Pandas4Warning: 'future.no_silent_downcasting' is deprecated, please refrain from using it.
#   pd.set_option('future.no_silent_downcasting', True)
#        PAÍS ETNIA.BN  EDAD FUGAS.BN  ABUSOSUBS1  ABUSOSUBS2  CONVIVEN.1  \
# 0      True    False  16.0    False           4           4         1.0
# 1      True    False  16.0    False           3           2         1.0
# 2      True    False  17.0    False           3           3         1.0
# 3      True    False  16.0    False           3           3         1.0
# 4      True    False  17.0    False           3           3         1.0
# ...     ...      ...   ...      ...         ...         ...         ...
# 3762   True    False  14.0    False           0           0         1.0
# 3763  False    False  14.0     True           2           0         1.0
# 3764   True    False  14.0    False           2           0         1.0
# 3765  False    False  14.0    False           0           0         1.0
# 3766   True    False  15.0     True           4           4         0.0
#
#       CONVIVEN.2  CONVIVEN.3  CONVIVEN.4  ... APOYO.MEAN APOYO.MEDIAN  \
# 0            1.0         0.0         0.0  ...   4.000000          4.0
# 1            1.0         0.0         0.0  ...   3.428571          4.0
# 2            1.0         0.0         0.0  ...   3.285714          4.0
# 3            1.0         0.0         0.0  ...   3.285714          4.0
# 4            1.0         0.0         0.0  ...   3.571429          4.0
# ...          ...         ...         ...  ...        ...          ...
# 3762         1.0         0.0         0.0  ...   3.285714          4.0
# 3763         1.0         0.0         0.0  ...   2.714286          3.0
# 3764         1.0         0.0         0.0  ...   3.714286          4.0
# 3765         1.0         0.0         0.0  ...   3.714286          4.0
# 3766         0.0         0.0         1.0  ...   2.571429          3.0
#
#       APOYO.VAR  MORAL.MEAN  MORAL.VAR  PORNO.T  GENERO.BN0  ORIENTSEX.BN0  \
# 0      0.000000         5.0       0.00      1.0       False           True
# 1      0.530612         2.8       0.56      4.0        True           True
# 2      0.775510         4.2       0.96      3.0       False           True
# 3      0.775510         4.0       0.40      4.0        True           True
# 4      0.530612         4.4       1.44      2.0       False           True
# ...         ...         ...        ...      ...         ...            ...
# 3762   1.061224         3.6       0.24      1.0       False           True
# 3763   1.061224         4.4       0.64      1.0       False           True
# 3764   0.489796         4.8       0.16      1.0       False           True
# 3765   0.204082         5.0       0.00      1.0       False           True
# 3766   1.959184         1.8       0.96      2.0       False           True
#
#       GENERO.BN1  ORIENTSEX.BN1
# 0           True          False
# 1          False          False
# 2           True          False
# 3          False          False
# 4           True          False
# ...          ...            ...
# 3762        True          False
# 3763        True          False
# 3764        True          False
# 3765        True          False
# 3766        True          False
#
# [3767 rows x 27 columns]
# ⚠️ No se encontró TPU, usando _DefaultDistributionStrategy
# Política de precisión: <DTypePolicy "float32">
# Índices de split guardados en 'content/perpetrator/splits_indices.json'
# PCA train-only seleccionado: 18 componentes (threshold=0.95)
# Train n=2825 positives=664; Val n=942 positives=221
# class_weight: {0: 1.0, 1: 3.2545180722891565}
# {'candidate_i': 0, 'seed': 42, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.7004160887656034, 'recall_1': 0.6199095022624435, 'precision_1': 0.3881019830028329, 'f1_1': 0.47735191637630664, 'accuracy': 0.6815286624203821, 'balanced_accuracy': 0.6601627955140235, 'TP': 137, 'FP': 216, 'TN': 505, 'FN': 84, 'epochs_run': 15}
# {'candidate_i': 1, 'seed': 1042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.4590846047156727, 'recall_1': 0.7058823529411765, 'precision_1': 0.2857142857142857, 'f1_1': 0.4067796610169492, 'accuracy': 0.5169851380042463, 'balanced_accuracy': 0.5824834788284246, 'TP': 156, 'FP': 390, 'TN': 331, 'FN': 65, 'epochs_run': 6}
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x135bd6e80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# {'candidate_i': 2, 'seed': 2042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.5686546463245492, 'recall_1': 0.6199095022624435, 'precision_1': 0.30580357142857145, 'f1_1': 0.40956651718983555, 'accuracy': 0.5806794055201698, 'balanced_accuracy': 0.5942820742934963, 'TP': 137, 'FP': 311, 'TN': 410, 'FN': 84, 'epochs_run': 6}
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x135f2ca40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# {'candidate_i': 3, 'seed': 3042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.6754507628294036, 'recall_1': 0.6244343891402715, 'precision_1': 0.3709677419354839, 'f1_1': 0.4654300168634064, 'accuracy': 0.6634819532908705, 'balanced_accuracy': 0.6499425759848376, 'TP': 138, 'FP': 234, 'TN': 487, 'FN': 83, 'epochs_run': 7}
# {'candidate_i': 4, 'seed': 4042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.5603328710124826, 'recall_1': 0.6606334841628959, 'precision_1': 0.31533477321814257, 'f1_1': 0.4269005847953216, 'accuracy': 0.583864118895966, 'balanced_accuracy': 0.6104831775876893, 'TP': 146, 'FP': 317, 'TN': 404, 'FN': 75, 'epochs_run': 6}
# {'candidate_i': 5, 'seed': 5042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.5977808599167822, 'recall_1': 0.665158371040724, 'precision_1': 0.33638443935926776, 'f1_1': 0.44680851063829785, 'accuracy': 0.613588110403397, 'balanced_accuracy': 0.6314696154787531, 'TP': 147, 'FP': 290, 'TN': 431, 'FN': 74, 'epochs_run': 6}
# {'candidate_i': 6, 'seed': 6042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6699029126213593, 'recall_1': 0.6515837104072398, 'precision_1': 0.3769633507853403, 'f1_1': 0.47761194029850745, 'accuracy': 0.6656050955414012, 'balanced_accuracy': 0.6607433115142995, 'TP': 144, 'FP': 238, 'TN': 483, 'FN': 77, 'epochs_run': 20}
# {'candidate_i': 7, 'seed': 7042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.5714285714285714, 'recall_1': 0.6606334841628959, 'precision_1': 0.3208791208791209, 'f1_1': 0.4319526627218935, 'accuracy': 0.5923566878980892, 'balanced_accuracy': 0.6160310277957337, 'TP': 146, 'FP': 309, 'TN': 412, 'FN': 75, 'epochs_run': 6}
#
# Detenido en epoch 1: Δrecall > 0.1
# {'candidate_i': 8, 'seed': 8042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.5866851595006934, 'recall_1': 0.5248868778280543, 'precision_1': 0.28019323671497587, 'f1_1': 0.3653543307086614, 'accuracy': 0.5721868365180467, 'balanced_accuracy': 0.5557860186643739, 'TP': 116, 'FP': 298, 'TN': 423, 'FN': 105, 'epochs_run': 1}
# {'candidate_i': 9, 'seed': 9042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 10, 'seed': 10042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.6615811373092927, 'recall_1': 0.6108597285067874, 'precision_1': 0.3562005277044855, 'f1_1': 0.45, 'accuracy': 0.6496815286624203, 'balanced_accuracy': 0.6362204329080401, 'TP': 135, 'FP': 244, 'TN': 477, 'FN': 86, 'epochs_run': 8}
# {'candidate_i': 11, 'seed': 11042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.6768377253814147, 'recall_1': 0.6199095022624435, 'precision_1': 0.37027027027027026, 'f1_1': 0.46362098138747887, 'accuracy': 0.6634819532908705, 'balanced_accuracy': 0.6483736138219292, 'TP': 137, 'FP': 233, 'TN': 488, 'FN': 84, 'epochs_run': 8}
# {'candidate_i': 12, 'seed': 12042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.7018030513176144, 'recall_1': 0.583710407239819, 'precision_1': 0.375, 'f1_1': 0.45663716814159294, 'accuracy': 0.6740976645435244, 'balanced_accuracy': 0.6427567292787167, 'TP': 129, 'FP': 215, 'TN': 506, 'FN': 92, 'epochs_run': 10}
# {'candidate_i': 13, 'seed': 13042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.5159500693481276, 'recall_1': 0.669683257918552, 'precision_1': 0.2977867203219316, 'f1_1': 0.41225626740947074, 'accuracy': 0.5520169851380042, 'balanced_accuracy': 0.5928166636333398, 'TP': 148, 'FP': 349, 'TN': 372, 'FN': 73, 'epochs_run': 6}
#
# Detenido en epoch 1: Δrecall > 0.1
# {'candidate_i': 14, 'seed': 14042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.5936199722607489, 'recall_1': 0.5113122171945701, 'precision_1': 0.27832512315270935, 'f1_1': 0.36044657097288674, 'accuracy': 0.5743099787685775, 'balanced_accuracy': 0.5524660947276595, 'TP': 113, 'FP': 293, 'TN': 428, 'FN': 108, 'epochs_run': 1}
# {'candidate_i': 15, 'seed': 15042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.6865464632454924, 'recall_1': 0.6289592760180995, 'precision_1': 0.38082191780821917, 'f1_1': 0.47440273037542663, 'accuracy': 0.673036093418259, 'balanced_accuracy': 0.657752869631796, 'TP': 139, 'FP': 226, 'TN': 495, 'FN': 82, 'epochs_run': 16}
# {'candidate_i': 16, 'seed': 16042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.6449375866851595, 'recall_1': 0.665158371040724, 'precision_1': 0.36476426799007444, 'f1_1': 0.47115384615384615, 'accuracy': 0.6496815286624203, 'balanced_accuracy': 0.6550479788629417, 'TP': 147, 'FP': 256, 'TN': 465, 'FN': 74, 'epochs_run': 7}
# {'candidate_i': 17, 'seed': 17042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.5436893203883495, 'recall_1': 0.6063348416289592, 'precision_1': 0.2894168466522678, 'f1_1': 0.391812865497076, 'accuracy': 0.5583864118895966, 'balanced_accuracy': 0.5750120810086543, 'TP': 134, 'FP': 329, 'TN': 392, 'FN': 87, 'epochs_run': 6}
# {'candidate_i': 18, 'seed': 18042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6227461858529819, 'recall_1': 0.6289592760180995, 'precision_1': 0.3381995133819951, 'f1_1': 0.439873417721519, 'accuracy': 0.6242038216560509, 'balanced_accuracy': 0.6258527309355407, 'TP': 139, 'FP': 272, 'TN': 449, 'FN': 82, 'epochs_run': 7}
# {'candidate_i': 19, 'seed': 19042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.6893203883495146, 'recall_1': 0.6380090497737556, 'precision_1': 0.3863013698630137, 'f1_1': 0.4812286689419795, 'accuracy': 0.6772823779193206, 'balanced_accuracy': 0.6636647190616352, 'TP': 141, 'FP': 224, 'TN': 497, 'FN': 80, 'epochs_run': 9}
# {'candidate_i': 20, 'seed': 20042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.7198335644937587, 'recall_1': 0.6199095022624435, 'precision_1': 0.40412979351032446, 'f1_1': 0.48928571428571427, 'accuracy': 0.6963906581740976, 'balanced_accuracy': 0.6698715333781011, 'TP': 137, 'FP': 202, 'TN': 519, 'FN': 84, 'epochs_run': 9}
# {'candidate_i': 21, 'seed': 21042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 22, 'seed': 22042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.6768377253814147, 'recall_1': 0.6380090497737556, 'precision_1': 0.3770053475935829, 'f1_1': 0.47394957983193275, 'accuracy': 0.667728237791932, 'balanced_accuracy': 0.6574233875775852, 'TP': 141, 'FP': 233, 'TN': 488, 'FN': 80, 'epochs_run': 21}
# {'candidate_i': 23, 'seed': 23042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 24, 'seed': 24042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.31622746185852985, 'recall_1': 0.8280542986425339, 'precision_1': 0.27071005917159763, 'f1_1': 0.4080267558528428, 'accuracy': 0.43630573248407645, 'balanced_accuracy': 0.5721408802505319, 'TP': 183, 'FP': 493, 'TN': 228, 'FN': 38, 'epochs_run': 6}
# {'candidate_i': 25, 'seed': 25042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.5464632454923717, 'recall_1': 0.6561085972850679, 'precision_1': 0.3072033898305085, 'f1_1': 0.4184704184704185, 'accuracy': 0.5721868365180467, 'balanced_accuracy': 0.6012859213887198, 'TP': 145, 'FP': 327, 'TN': 394, 'FN': 76, 'epochs_run': 6}
# {'candidate_i': 26, 'seed': 26042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.6463245492371706, 'recall_1': 0.6923076923076923, 'precision_1': 0.375, 'f1_1': 0.4864864864864865, 'accuracy': 0.6571125265392781, 'balanced_accuracy': 0.6693161207724314, 'TP': 153, 'FP': 255, 'TN': 466, 'FN': 68, 'epochs_run': 19}
# {'candidate_i': 27, 'seed': 27042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.7253814147018031, 'recall_1': 0.6334841628959276, 'precision_1': 0.41420118343195267, 'f1_1': 0.5008944543828264, 'accuracy': 0.7038216560509554, 'balanced_accuracy': 0.6794327887988654, 'TP': 140, 'FP': 198, 'TN': 523, 'FN': 81, 'epochs_run': 12}
# {'candidate_i': 28, 'seed': 28042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.6185852981969486, 'recall_1': 0.6244343891402715, 'precision_1': 0.3341404358353511, 'f1_1': 0.4353312302839117, 'accuracy': 0.6199575371549894, 'balanced_accuracy': 0.6215098436686101, 'TP': 138, 'FP': 275, 'TN': 446, 'FN': 83, 'epochs_run': 6}
# {'candidate_i': 29, 'seed': 29042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.6990291262135923, 'recall_1': 0.6108597285067874, 'precision_1': 0.3835227272727273, 'f1_1': 0.4712041884816754, 'accuracy': 0.678343949044586, 'balanced_accuracy': 0.6549444273601899, 'TP': 135, 'FP': 217, 'TN': 504, 'FN': 86, 'epochs_run': 11}
# {'candidate_i': 30, 'seed': 30042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6671289875173371, 'recall_1': 0.6244343891402715, 'precision_1': 0.36507936507936506, 'f1_1': 0.4607679465776294, 'accuracy': 0.6571125265392781, 'balanced_accuracy': 0.6457816883288043, 'TP': 138, 'FP': 240, 'TN': 481, 'FN': 83, 'epochs_run': 8}
# {'candidate_i': 31, 'seed': 31042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.6920943134535368, 'recall_1': 0.6018099547511312, 'precision_1': 0.37464788732394366, 'f1_1': 0.4618055555555556, 'accuracy': 0.6709129511677282, 'balanced_accuracy': 0.646952134102334, 'TP': 133, 'FP': 222, 'TN': 499, 'FN': 88, 'epochs_run': 12}
# {'candidate_i': 32, 'seed': 32042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.6962552011095701, 'recall_1': 0.6018099547511312, 'precision_1': 0.3778409090909091, 'f1_1': 0.4642233856893543, 'accuracy': 0.6740976645435244, 'balanced_accuracy': 0.6490325779303506, 'TP': 133, 'FP': 219, 'TN': 502, 'FN': 88, 'epochs_run': 11}
# {'candidate_i': 33, 'seed': 33042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 34, 'seed': 34042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 35, 'seed': 35042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 36, 'seed': 36042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.5533980582524272, 'recall_1': 0.6742081447963801, 'precision_1': 0.31634819532908703, 'f1_1': 0.430635838150289, 'accuracy': 0.5817409766454352, 'balanced_accuracy': 0.6138031015244036, 'TP': 149, 'FP': 322, 'TN': 399, 'FN': 72, 'epochs_run': 7}
# {'candidate_i': 37, 'seed': 37042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.5117891816920943, 'recall_1': 0.746606334841629, 'precision_1': 0.3191489361702128, 'f1_1': 0.44715447154471544, 'accuracy': 0.5668789808917197, 'balanced_accuracy': 0.6291977582668616, 'TP': 165, 'FP': 352, 'TN': 369, 'FN': 56, 'epochs_run': 6}
# {'candidate_i': 38, 'seed': 38042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.651872399445215, 'recall_1': 0.6199095022624435, 'precision_1': 0.35309278350515466, 'f1_1': 0.44991789819376027, 'accuracy': 0.6443736730360934, 'balanced_accuracy': 0.6358909508538293, 'TP': 137, 'FP': 251, 'TN': 470, 'FN': 84, 'epochs_run': 8}
# {'candidate_i': 39, 'seed': 39042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.59500693481276, 'recall_1': 0.7058823529411765, 'precision_1': 0.3482142857142857, 'f1_1': 0.4663677130044843, 'accuracy': 0.6210191082802548, 'balanced_accuracy': 0.6504446438769682, 'TP': 156, 'FP': 292, 'TN': 429, 'FN': 65, 'epochs_run': 7}
#
# Detenido en epoch 1: Δrecall > 0.1
# {'candidate_i': 40, 'seed': 40042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.6116504854368932, 'recall_1': 0.5927601809954751, 'precision_1': 0.31873479318734793, 'f1_1': 0.41455696202531644, 'accuracy': 0.6072186836518046, 'balanced_accuracy': 0.6022053332161841, 'TP': 131, 'FP': 280, 'TN': 441, 'FN': 90, 'epochs_run': 1}
# {'candidate_i': 41, 'seed': 41042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.5742024965325936, 'recall_1': 0.6063348416289592, 'precision_1': 0.30385487528344673, 'f1_1': 0.40483383685800606, 'accuracy': 0.5817409766454352, 'balanced_accuracy': 0.5902686690807764, 'TP': 134, 'FP': 307, 'TN': 414, 'FN': 87, 'epochs_run': 6}
# {'candidate_i': 42, 'seed': 42042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6546463245492372, 'recall_1': 0.6153846153846154, 'precision_1': 0.35324675324675325, 'f1_1': 0.44884488448844884, 'accuracy': 0.6454352441613588, 'balanced_accuracy': 0.6350154699669264, 'TP': 136, 'FP': 249, 'TN': 472, 'FN': 85, 'epochs_run': 6}
# {'candidate_i': 43, 'seed': 43042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.7184466019417476, 'recall_1': 0.6108597285067874, 'precision_1': 0.3994082840236686, 'f1_1': 0.48300536672629696, 'accuracy': 0.6932059447983014, 'balanced_accuracy': 0.6646531652242675, 'TP': 135, 'FP': 203, 'TN': 518, 'FN': 86, 'epochs_run': 12}
# {'candidate_i': 44, 'seed': 44042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.4895977808599168, 'recall_1': 0.665158371040724, 'precision_1': 0.2854368932038835, 'f1_1': 0.39945652173913043, 'accuracy': 0.5307855626326964, 'balanced_accuracy': 0.5773780759503204, 'TP': 147, 'FP': 368, 'TN': 353, 'FN': 74, 'epochs_run': 6}
# {'candidate_i': 45, 'seed': 45042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.5270457697642164, 'recall_1': 0.751131221719457, 'precision_1': 0.32741617357001973, 'f1_1': 0.45604395604395603, 'accuracy': 0.5796178343949044, 'balanced_accuracy': 0.6390884957418367, 'TP': 166, 'FP': 341, 'TN': 380, 'FN': 55, 'epochs_run': 6}
# {'candidate_i': 46, 'seed': 46042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.6962552011095701, 'recall_1': 0.6515837104072398, 'precision_1': 0.39669421487603307, 'f1_1': 0.4931506849315068, 'accuracy': 0.6857749469214437, 'balanced_accuracy': 0.673919455758405, 'TP': 144, 'FP': 219, 'TN': 502, 'FN': 77, 'epochs_run': 17}
# {'candidate_i': 47, 'seed': 47042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.6865464632454924, 'recall_1': 0.6470588235294118, 'precision_1': 0.3875338753387534, 'f1_1': 0.4847457627118644, 'accuracy': 0.6772823779193206, 'balanced_accuracy': 0.6668026433874521, 'TP': 143, 'FP': 226, 'TN': 495, 'FN': 78, 'epochs_run': 16}
# {'candidate_i': 48, 'seed': 48042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.6879334257975035, 'recall_1': 0.6470588235294118, 'precision_1': 0.38858695652173914, 'f1_1': 0.4855687606112054, 'accuracy': 0.678343949044586, 'balanced_accuracy': 0.6674961246634576, 'TP': 143, 'FP': 225, 'TN': 496, 'FN': 78, 'epochs_run': 14}
#
# Detenido en epoch 4: Δrecall > 0.1
# {'candidate_i': 49, 'seed': 49042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.12343966712898752, 'recall_1': 0.9140271493212669, 'precision_1': 0.2422062350119904, 'f1_1': 0.38293838862559243, 'accuracy': 0.3089171974522293, 'balanced_accuracy': 0.5187334082251273, 'TP': 202, 'FP': 632, 'TN': 89, 'FN': 19, 'epochs_run': 4}
# {'candidate_i': 50, 'seed': 50042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.4604715672676838, 'recall_1': 0.7647058823529411, 'precision_1': 0.30286738351254483, 'f1_1': 0.4338896020539153, 'accuracy': 0.5318471337579618, 'balanced_accuracy': 0.6125887248103125, 'TP': 169, 'FP': 389, 'TN': 332, 'FN': 52, 'epochs_run': 6}
# {'candidate_i': 51, 'seed': 51042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.5492371705963939, 'recall_1': 0.6832579185520362, 'precision_1': 0.3172268907563025, 'f1_1': 0.4332855093256815, 'accuracy': 0.5806794055201698, 'balanced_accuracy': 0.616247544574215, 'TP': 151, 'FP': 325, 'TN': 396, 'FN': 70, 'epochs_run': 6}
# {'candidate_i': 52, 'seed': 52042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.680998613037448, 'recall_1': 0.6470588235294118, 'precision_1': 0.38337801608579086, 'f1_1': 0.48148148148148145, 'accuracy': 0.673036093418259, 'balanced_accuracy': 0.6640287182834299, 'TP': 143, 'FP': 230, 'TN': 491, 'FN': 78, 'epochs_run': 12}
# {'candidate_i': 53, 'seed': 53042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.6574202496532594, 'recall_1': 0.6425339366515838, 'precision_1': 0.36503856041131105, 'f1_1': 0.46557377049180326, 'accuracy': 0.6539278131634819, 'balanced_accuracy': 0.6499770931524216, 'TP': 142, 'FP': 247, 'TN': 474, 'FN': 79, 'epochs_run': 8}
# {'candidate_i': 54, 'seed': 54042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6837725381414702, 'recall_1': 0.6334841628959276, 'precision_1': 0.3804347826086957, 'f1_1': 0.47538200339558573, 'accuracy': 0.6719745222929936, 'balanced_accuracy': 0.658628350518699, 'TP': 140, 'FP': 228, 'TN': 493, 'FN': 81, 'epochs_run': 16}
# {'candidate_i': 55, 'seed': 55042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.44382801664355065, 'recall_1': 0.6742081447963801, 'precision_1': 0.27090909090909093, 'f1_1': 0.3865110246433204, 'accuracy': 0.4978768577494692, 'balanced_accuracy': 0.5590180807199654, 'TP': 149, 'FP': 401, 'TN': 320, 'FN': 72, 'epochs_run': 6}
# {'candidate_i': 56, 'seed': 56042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.6851595006934813, 'recall_1': 0.6334841628959276, 'precision_1': 0.3814713896457766, 'f1_1': 0.47619047619047616, 'accuracy': 0.673036093418259, 'balanced_accuracy': 0.6593218317947045, 'TP': 140, 'FP': 227, 'TN': 494, 'FN': 81, 'epochs_run': 8}
# {'candidate_i': 57, 'seed': 57042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.4188626907073509, 'recall_1': 0.6923076923076923, 'precision_1': 0.2674825174825175, 'f1_1': 0.3858764186633039, 'accuracy': 0.4830148619957537, 'balanced_accuracy': 0.5555851915075216, 'TP': 153, 'FP': 419, 'TN': 302, 'FN': 68, 'epochs_run': 6}
# {'candidate_i': 58, 'seed': 58042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.6629680998613038, 'recall_1': 0.6515837104072398, 'precision_1': 0.37209302325581395, 'f1_1': 0.47368421052631576, 'accuracy': 0.6602972399150743, 'balanced_accuracy': 0.6572759051342718, 'TP': 144, 'FP': 243, 'TN': 478, 'FN': 77, 'epochs_run': 20}
# {'candidate_i': 59, 'seed': 59042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.6699029126213593, 'recall_1': 0.6515837104072398, 'precision_1': 0.3769633507853403, 'f1_1': 0.47761194029850745, 'accuracy': 0.6656050955414012, 'balanced_accuracy': 0.6607433115142995, 'TP': 144, 'FP': 238, 'TN': 483, 'FN': 77, 'epochs_run': 20}
# {'candidate_i': 60, 'seed': 60042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.5423023578363384, 'recall_1': 0.665158371040724, 'precision_1': 0.3081761006289308, 'f1_1': 0.42120343839541546, 'accuracy': 0.5711252653927813, 'balanced_accuracy': 0.6037303644385312, 'TP': 147, 'FP': 330, 'TN': 391, 'FN': 74, 'epochs_run': 8}
# {'candidate_i': 61, 'seed': 61042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.6435506241331485, 'recall_1': 0.5972850678733032, 'precision_1': 0.3393316195372751, 'f1_1': 0.43278688524590164, 'accuracy': 0.6326963906581741, 'balanced_accuracy': 0.6204178460032258, 'TP': 132, 'FP': 257, 'TN': 464, 'FN': 89, 'epochs_run': 7}
# {'candidate_i': 62, 'seed': 62042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.6643550624133149, 'recall_1': 0.6606334841628959, 'precision_1': 0.37628865979381443, 'f1_1': 0.4794745484400657, 'accuracy': 0.6634819532908705, 'balanced_accuracy': 0.6624942732881054, 'TP': 146, 'FP': 242, 'TN': 479, 'FN': 75, 'epochs_run': 15}
# {'candidate_i': 63, 'seed': 63042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.6754507628294036, 'recall_1': 0.6018099547511312, 'precision_1': 0.36239782016348776, 'f1_1': 0.4523809523809524, 'accuracy': 0.6581740976645435, 'balanced_accuracy': 0.6386303587902674, 'TP': 133, 'FP': 234, 'TN': 487, 'FN': 88, 'epochs_run': 6}
# {'candidate_i': 64, 'seed': 64042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.47434119278779474, 'recall_1': 0.6515837104072398, 'precision_1': 0.27533460803059273, 'f1_1': 0.3870967741935484, 'accuracy': 0.5159235668789809, 'balanced_accuracy': 0.5629624515975173, 'TP': 144, 'FP': 379, 'TN': 342, 'FN': 77, 'epochs_run': 6}
# {'candidate_i': 65, 'seed': 65042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.6837725381414702, 'recall_1': 0.6244343891402715, 'precision_1': 0.3770491803278688, 'f1_1': 0.47018739352640543, 'accuracy': 0.6698513800424628, 'balanced_accuracy': 0.6541034636408709, 'TP': 138, 'FP': 228, 'TN': 493, 'FN': 83, 'epochs_run': 13}
# {'candidate_i': 66, 'seed': 66042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.44244105409153955, 'recall_1': 0.6063348416289592, 'precision_1': 0.25, 'f1_1': 0.35402906208718626, 'accuracy': 0.48089171974522293, 'balanced_accuracy': 0.5243879478602493, 'TP': 134, 'FP': 402, 'TN': 319, 'FN': 87, 'epochs_run': 6}
# {'candidate_i': 67, 'seed': 67042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.6782246879334258, 'recall_1': 0.6199095022624435, 'precision_1': 0.3712737127371274, 'f1_1': 0.46440677966101696, 'accuracy': 0.6645435244161358, 'balanced_accuracy': 0.6490670950979347, 'TP': 137, 'FP': 232, 'TN': 489, 'FN': 84, 'epochs_run': 13}
# {'candidate_i': 68, 'seed': 68042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.47572815533980584, 'recall_1': 0.755656108597285, 'precision_1': 0.30642201834862387, 'f1_1': 0.4360313315926893, 'accuracy': 0.5414012738853503, 'balanced_accuracy': 0.6156921319685454, 'TP': 167, 'FP': 378, 'TN': 343, 'FN': 54, 'epochs_run': 6}
# {'candidate_i': 69, 'seed': 69042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.6754507628294036, 'recall_1': 0.6470588235294118, 'precision_1': 0.3793103448275862, 'f1_1': 0.4782608695652174, 'accuracy': 0.6687898089171974, 'balanced_accuracy': 0.6612547931794077, 'TP': 143, 'FP': 234, 'TN': 487, 'FN': 78, 'epochs_run': 26}
# {'candidate_i': 70, 'seed': 70042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 71, 'seed': 71042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.6615811373092927, 'recall_1': 0.6606334841628959, 'precision_1': 0.37435897435897436, 'f1_1': 0.4779050736497545, 'accuracy': 0.6613588110403397, 'balanced_accuracy': 0.6611073107360943, 'TP': 146, 'FP': 244, 'TN': 477, 'FN': 75, 'epochs_run': 30}
# {'candidate_i': 72, 'seed': 72042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.6990291262135923, 'recall_1': 0.5972850678733032, 'precision_1': 0.37822349570200575, 'f1_1': 0.4631578947368421, 'accuracy': 0.6751592356687898, 'balanced_accuracy': 0.6481570970434477, 'TP': 132, 'FP': 217, 'TN': 504, 'FN': 89, 'epochs_run': 12}
# {'candidate_i': 73, 'seed': 73042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.43966712898751736, 'recall_1': 0.7104072398190046, 'precision_1': 0.2798573975044563, 'f1_1': 0.40153452685422, 'accuracy': 0.5031847133757962, 'balanced_accuracy': 0.5750371844032609, 'TP': 157, 'FP': 404, 'TN': 317, 'FN': 64, 'epochs_run': 6}
# {'candidate_i': 74, 'seed': 74042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.680998613037448, 'recall_1': 0.6515837104072398, 'precision_1': 0.3850267379679144, 'f1_1': 0.48403361344537815, 'accuracy': 0.6740976645435244, 'balanced_accuracy': 0.6662911617223439, 'TP': 144, 'FP': 230, 'TN': 491, 'FN': 77, 'epochs_run': 19}
#
# Detenido en epoch 1: Δrecall > 0.1
# {'candidate_i': 75, 'seed': 75042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.6213592233009708, 'recall_1': 0.6063348416289592, 'precision_1': 0.32923832923832924, 'f1_1': 0.4267515923566879, 'accuracy': 0.6178343949044586, 'balanced_accuracy': 0.613847032464965, 'TP': 134, 'FP': 273, 'TN': 448, 'FN': 87, 'epochs_run': 1}
# {'candidate_i': 76, 'seed': 76042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.6934812760055479, 'recall_1': 0.5972850678733032, 'precision_1': 0.37393767705382436, 'f1_1': 0.45993031358885017, 'accuracy': 0.6709129511677282, 'balanced_accuracy': 0.6453831719394255, 'TP': 132, 'FP': 221, 'TN': 500, 'FN': 89, 'epochs_run': 13}
# {'candidate_i': 77, 'seed': 77042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.5159500693481276, 'recall_1': 0.6425339366515838, 'precision_1': 0.2892057026476578, 'f1_1': 0.398876404494382, 'accuracy': 0.5456475583864119, 'balanced_accuracy': 0.5792420029998557, 'TP': 142, 'FP': 349, 'TN': 372, 'FN': 79, 'epochs_run': 6}
# {'candidate_i': 78, 'seed': 78042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.7004160887656034, 'recall_1': 0.6244343891402715, 'precision_1': 0.3898305084745763, 'f1_1': 0.48, 'accuracy': 0.6825902335456475, 'balanced_accuracy': 0.6624252389529375, 'TP': 138, 'FP': 216, 'TN': 505, 'FN': 83, 'epochs_run': 17}
# {'candidate_i': 79, 'seed': 79042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.7115117891816921, 'recall_1': 0.6244343891402715, 'precision_1': 0.3988439306358382, 'f1_1': 0.48677248677248675, 'accuracy': 0.6910828025477707, 'balanced_accuracy': 0.6679730891609819, 'TP': 138, 'FP': 208, 'TN': 513, 'FN': 83, 'epochs_run': 10}
# {'candidate_i': 80, 'seed': 80042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.6671289875173371, 'recall_1': 0.665158371040724, 'precision_1': 0.3798449612403101, 'f1_1': 0.48355263157894735, 'accuracy': 0.6666666666666666, 'balanced_accuracy': 0.6661436792790305, 'TP': 147, 'FP': 240, 'TN': 481, 'FN': 74, 'epochs_run': 7}
# {'candidate_i': 81, 'seed': 81042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 82, 'seed': 82042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.6990291262135923, 'recall_1': 0.6289592760180995, 'precision_1': 0.3904494382022472, 'f1_1': 0.48180242634315423, 'accuracy': 0.6825902335456475, 'balanced_accuracy': 0.663994201115846, 'TP': 139, 'FP': 217, 'TN': 504, 'FN': 82, 'epochs_run': 14}
#
# Detenido en epoch 2: Δrecall > 0.1
# {'candidate_i': 83, 'seed': 83042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.044382801664355064, 'recall_1': 0.9049773755656109, 'precision_1': 0.2249718785151856, 'f1_1': 0.36036036036036034, 'accuracy': 0.24628450106157113, 'balanced_accuracy': 0.47468008861498295, 'TP': 200, 'FP': 689, 'TN': 32, 'FN': 21, 'epochs_run': 2}
#
# Detenido en epoch 1: Δrecall > 0.1
# {'candidate_i': 84, 'seed': 84042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.5644937586685159, 'recall_1': 0.497737556561086, 'precision_1': 0.25943396226415094, 'f1_1': 0.34108527131782945, 'accuracy': 0.5488322717622081, 'balanced_accuracy': 0.531115657614801, 'TP': 110, 'FP': 314, 'TN': 407, 'FN': 111, 'epochs_run': 1}
# {'candidate_i': 85, 'seed': 85042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.6393897364771152, 'recall_1': 0.665158371040724, 'precision_1': 0.36117936117936117, 'f1_1': 0.4681528662420382, 'accuracy': 0.6454352441613588, 'balanced_accuracy': 0.6522740537589196, 'TP': 147, 'FP': 260, 'TN': 461, 'FN': 74, 'epochs_run': 20}
# {'candidate_i': 86, 'seed': 86042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.6851595006934813, 'recall_1': 0.6425339366515838, 'precision_1': 0.38482384823848237, 'f1_1': 0.48135593220338985, 'accuracy': 0.6751592356687898, 'balanced_accuracy': 0.6638467186725325, 'TP': 142, 'FP': 227, 'TN': 494, 'FN': 79, 'epochs_run': 12}
# {'candidate_i': 87, 'seed': 87042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.710124826629681, 'recall_1': 0.6108597285067874, 'precision_1': 0.39244186046511625, 'f1_1': 0.4778761061946903, 'accuracy': 0.6868365180467091, 'balanced_accuracy': 0.6604922775682343, 'TP': 135, 'FP': 209, 'TN': 512, 'FN': 86, 'epochs_run': 21}
# {'candidate_i': 88, 'seed': 88042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.6851595006934813, 'recall_1': 0.6108597285067874, 'precision_1': 0.3729281767955801, 'f1_1': 0.4631217838765009, 'accuracy': 0.667728237791932, 'balanced_accuracy': 0.6480096146001344, 'TP': 135, 'FP': 227, 'TN': 494, 'FN': 86, 'epochs_run': 11}
# {'candidate_i': 89, 'seed': 89042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.6282940360610264, 'recall_1': 0.6380090497737556, 'precision_1': 0.34474327628361856, 'f1_1': 0.44761904761904764, 'accuracy': 0.6305732484076433, 'balanced_accuracy': 0.6331515429173911, 'TP': 141, 'FP': 268, 'TN': 453, 'FN': 80, 'epochs_run': 6}
# {'candidate_i': 90, 'seed': 90042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6837725381414702, 'recall_1': 0.6153846153846154, 'precision_1': 0.37362637362637363, 'f1_1': 0.46495726495726497, 'accuracy': 0.667728237791932, 'balanced_accuracy': 0.6495785767630429, 'TP': 136, 'FP': 228, 'TN': 493, 'FN': 85, 'epochs_run': 14}
# {'candidate_i': 91, 'seed': 91042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.7045769764216366, 'recall_1': 0.6199095022624435, 'precision_1': 0.3914285714285714, 'f1_1': 0.4798598949211909, 'accuracy': 0.6847133757961783, 'balanced_accuracy': 0.6622432393420401, 'TP': 137, 'FP': 213, 'TN': 508, 'FN': 84, 'epochs_run': 9}
# {'candidate_i': 92, 'seed': 92042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.7004160887656034, 'recall_1': 0.6153846153846154, 'precision_1': 0.38636363636363635, 'f1_1': 0.47469458987783597, 'accuracy': 0.6804670912951167, 'balanced_accuracy': 0.6579003520751094, 'TP': 136, 'FP': 216, 'TN': 505, 'FN': 85, 'epochs_run': 10}
# {'candidate_i': 93, 'seed': 93042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.6865464632454924, 'recall_1': 0.6244343891402715, 'precision_1': 0.3791208791208791, 'f1_1': 0.4717948717948718, 'accuracy': 0.6719745222929936, 'balanced_accuracy': 0.655490426192882, 'TP': 138, 'FP': 226, 'TN': 495, 'FN': 83, 'epochs_run': 16}
# {'candidate_i': 94, 'seed': 94042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 95, 'seed': 95042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.6851595006934813, 'recall_1': 0.6289592760180995, 'precision_1': 0.3797814207650273, 'f1_1': 0.4735945485519591, 'accuracy': 0.6719745222929936, 'balanced_accuracy': 0.6570593883557905, 'TP': 139, 'FP': 227, 'TN': 494, 'FN': 82, 'epochs_run': 18}
# {'candidate_i': 96, 'seed': 96042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.43134535367545074, 'recall_1': 0.6108597285067874, 'precision_1': 0.24770642201834864, 'f1_1': 0.3524804177545692, 'accuracy': 0.4734607218683652, 'balanced_accuracy': 0.5211025410911191, 'TP': 135, 'FP': 410, 'TN': 311, 'FN': 86, 'epochs_run': 7}
# {'candidate_i': 97, 'seed': 97042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.550624133148405, 'recall_1': 0.755656108597285, 'precision_1': 0.34012219959266804, 'f1_1': 0.4691011235955056, 'accuracy': 0.5987261146496815, 'balanced_accuracy': 0.653140120872845, 'TP': 167, 'FP': 324, 'TN': 397, 'FN': 54, 'epochs_run': 8}
# {'candidate_i': 98, 'seed': 98042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.47018030513176146, 'recall_1': 0.6380090497737556, 'precision_1': 0.2695984703632887, 'f1_1': 0.3790322580645161, 'accuracy': 0.5095541401273885, 'balanced_accuracy': 0.5540946774527585, 'TP': 141, 'FP': 382, 'TN': 339, 'FN': 80, 'epochs_run': 6}
# {'candidate_i': 99, 'seed': 99042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.5547850208044383, 'recall_1': 0.6561085972850679, 'precision_1': 0.3111587982832618, 'f1_1': 0.42212518195050946, 'accuracy': 0.578556263269639, 'balanced_accuracy': 0.6054468090447531, 'TP': 145, 'FP': 321, 'TN': 400, 'FN': 76, 'epochs_run': 6}
# {'candidate_i': 100, 'seed': 100042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.6907073509015257, 'recall_1': 0.6153846153846154, 'precision_1': 0.3788300835654596, 'f1_1': 0.4689655172413793, 'accuracy': 0.673036093418259, 'balanced_accuracy': 0.6530459831430706, 'TP': 136, 'FP': 223, 'TN': 498, 'FN': 85, 'epochs_run': 13}
# {'candidate_i': 101, 'seed': 101042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.6893203883495146, 'recall_1': 0.6289592760180995, 'precision_1': 0.38292011019283745, 'f1_1': 0.476027397260274, 'accuracy': 0.6751592356687898, 'balanced_accuracy': 0.6591398321838071, 'TP': 139, 'FP': 224, 'TN': 497, 'FN': 82, 'epochs_run': 14}
# {'candidate_i': 102, 'seed': 102042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6865464632454924, 'recall_1': 0.6153846153846154, 'precision_1': 0.3756906077348066, 'f1_1': 0.4665523156089194, 'accuracy': 0.6698513800424628, 'balanced_accuracy': 0.650965539315054, 'TP': 136, 'FP': 226, 'TN': 495, 'FN': 85, 'epochs_run': 21}
# {'candidate_i': 103, 'seed': 103042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.7073509015256588, 'recall_1': 0.6334841628959276, 'precision_1': 0.39886039886039887, 'f1_1': 0.48951048951048953, 'accuracy': 0.6900212314225053, 'balanced_accuracy': 0.6704175322107933, 'TP': 140, 'FP': 211, 'TN': 510, 'FN': 81, 'epochs_run': 13}
# {'candidate_i': 104, 'seed': 104042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.6823855755894591, 'recall_1': 0.6063348416289592, 'precision_1': 0.3691460055096419, 'f1_1': 0.4589041095890411, 'accuracy': 0.6645435244161358, 'balanced_accuracy': 0.6443602086092092, 'TP': 134, 'FP': 229, 'TN': 492, 'FN': 87, 'epochs_run': 7}
# {'candidate_i': 105, 'seed': 105042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.6435506241331485, 'recall_1': 0.665158371040724, 'precision_1': 0.36386138613861385, 'f1_1': 0.4704, 'accuracy': 0.648619957537155, 'balanced_accuracy': 0.6543544975869362, 'TP': 147, 'FP': 257, 'TN': 464, 'FN': 74, 'epochs_run': 39}
# {'candidate_i': 106, 'seed': 106042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 107, 'seed': 107042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 108, 'seed': 108042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.7309292649098474, 'recall_1': 0.5882352941176471, 'precision_1': 0.4012345679012346, 'f1_1': 0.47706422018348627, 'accuracy': 0.697452229299363, 'balanced_accuracy': 0.6595822795137473, 'TP': 130, 'FP': 194, 'TN': 527, 'FN': 91, 'epochs_run': 8}
# {'candidate_i': 109, 'seed': 109042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.6463245492371706, 'recall_1': 0.6470588235294118, 'precision_1': 0.3592964824120603, 'f1_1': 0.4620355411954766, 'accuracy': 0.6464968152866242, 'balanced_accuracy': 0.6466916863832912, 'TP': 143, 'FP': 255, 'TN': 466, 'FN': 78, 'epochs_run': 9}
# {'candidate_i': 110, 'seed': 110042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.6768377253814147, 'recall_1': 0.6334841628959276, 'precision_1': 0.3753351206434316, 'f1_1': 0.4713804713804714, 'accuracy': 0.6666666666666666, 'balanced_accuracy': 0.6551609441386712, 'TP': 140, 'FP': 233, 'TN': 488, 'FN': 81, 'epochs_run': 23}
# {'candidate_i': 111, 'seed': 111042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.6782246879334258, 'recall_1': 0.6425339366515838, 'precision_1': 0.37967914438502676, 'f1_1': 0.4773109243697479, 'accuracy': 0.6698513800424628, 'balanced_accuracy': 0.6603793122925048, 'TP': 142, 'FP': 232, 'TN': 489, 'FN': 79, 'epochs_run': 8}
# {'candidate_i': 112, 'seed': 112042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.6199722607489597, 'recall_1': 0.6289592760180995, 'precision_1': 0.3365617433414044, 'f1_1': 0.4384858044164038, 'accuracy': 0.6220806794055201, 'balanced_accuracy': 0.6244657683835296, 'TP': 139, 'FP': 274, 'TN': 447, 'FN': 82, 'epochs_run': 6}
# {'candidate_i': 113, 'seed': 113042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.7004160887656034, 'recall_1': 0.6199095022624435, 'precision_1': 0.3881019830028329, 'f1_1': 0.47735191637630664, 'accuracy': 0.6815286624203821, 'balanced_accuracy': 0.6601627955140235, 'TP': 137, 'FP': 216, 'TN': 505, 'FN': 84, 'epochs_run': 8}
# {'candidate_i': 114, 'seed': 114042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6629680998613038, 'recall_1': 0.6380090497737556, 'precision_1': 0.3671875, 'f1_1': 0.46611570247933887, 'accuracy': 0.6571125265392781, 'balanced_accuracy': 0.6504885748175298, 'TP': 141, 'FP': 243, 'TN': 478, 'FN': 80, 'epochs_run': 6}
# {'candidate_i': 115, 'seed': 115042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.636615811373093, 'recall_1': 0.6334841628959276, 'precision_1': 0.3482587064676617, 'f1_1': 0.449438202247191, 'accuracy': 0.6358811040339702, 'balanced_accuracy': 0.6350499871345103, 'TP': 140, 'FP': 262, 'TN': 459, 'FN': 81, 'epochs_run': 6}
# {'candidate_i': 116, 'seed': 116042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.6920943134535368, 'recall_1': 0.6334841628959276, 'precision_1': 0.3867403314917127, 'f1_1': 0.48027444253859347, 'accuracy': 0.678343949044586, 'balanced_accuracy': 0.6627892381747322, 'TP': 140, 'FP': 222, 'TN': 499, 'FN': 81, 'epochs_run': 10}
# ...
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:889, in Function._call(self, *args, **kwds)
#     886 try:
#     887   # This is the first call of __call__, so we have to initialize.
#     888   initializers = []
# --> 889   self._initialize(args, kwds, add_initializers_to=initializers)
#     890 finally:
#     891   # At this point we know that the initialization is complete (or less
#     892   # interestingly an exception was raised) so we no longer need a lock.
#     893   self._lock.release()
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/framework/func_graph.py:1060, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057   return x
#    1059 _, original_func = tf_decorator.unwrap(python_func)
# -> 1060 func_outputs = python_func(*func_args, **func_kwargs)
#    1062 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1063 # TensorArrays and `None`s.
#    1064 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:339, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     337 if is_autograph_artifact(f):
#     338   logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339   return _call_unconverted(f, args, kwargs, options)
#     341 # If this is a partial, unwrap it and redo all the checks.
#     342 if isinstance(f, functools.partial):
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:154, in TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator(iterator)
#     150 @tf.autograph.experimental.do_not_convert
#     151 def multi_step_on_iterator(iterator):
#     152     if self.steps_per_execution == 1:
#     153         return tf.experimental.Optional.from_value(
# --> 154             one_step_on_data(iterator.get_next())
#     155         )
#     157     # the spec is set lazily during the tracing of `tf.while_loop`
#     158     empty_outputs = tf.experimental.Optional.empty(None)
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:125, in TensorFlowTrainer._autoconvert_optionals.<locals>.wrapper(data)
#     117 @functools.wraps(step_func)
#     118 def wrapper(data):
#     119     converted_data = tree.map_structure(
#     120         lambda i: (
#     121             None if isinstance(i, tf.experimental.Optional) else i
#     122         ),
#     123         data,
#     124     )
# --> 125     result = step_func(converted_data)
#     126     return result
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:906, in Function._call(self, *args, **kwds)
#     902     pass  # Fall through to cond-based initialization.
#     903   else:
#     904     # Lifting succeeded, so variables are initialized and we can run the
#     905     # no_variable_creation function.
# --> 906     return tracing_compilation.call_function(
#     907         args, kwds, self._no_variable_creation_config
#     908     )
#     909 else:
#     910   bound_args = self._concrete_variable_creation_fn.function_type.bind(
#     911       *args, **kwds
#     912   )
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:132, in call_function(args, kwargs, tracing_options)
#     130 args = args if args else ()
#     131 kwargs = kwargs if kwargs else {}
# --> 132 function = trace_function(
#     133     args=args, kwargs=kwargs, tracing_options=tracing_options
#     134 )
#     136 # Bind it ourselves to skip unnecessary canonicalization of default call.
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/framework/func_graph.py:988, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#     985 else:
#     986   deps_control_manager = ops.NullContextmanager()
# --> 988 with func_graph.as_default(), deps_control_manager as deps_ctx:
#     989   current_scope = variable_scope.get_variable_scope()
#     990   default_use_resource = current_scope.use_resource
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/framework/auto_control_deps.py:459, in AutomaticControlDependencies.__exit__(self, unused_type, unused_value, unused_traceback)
#     456 resource_inputs = set()
#     457 # Check for any resource inputs. If we find any, we update control_inputs
#     458 # and last_write_to_resource.
# --> 459 for inp, resource_type in _get_resource_inputs(op):
#     460   is_read = resource_type == ResourceType.READ_ONLY
#     461   input_id = ops.tensor_id(inp)
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/framework/auto_control_deps.py:608, in _get_resource_inputs(op)
#     606 def _get_resource_inputs(op):
#     607   """Returns an iterable of resources touched by this `op`."""
# --> 608   reads, writes = utils.get_read_write_resource_inputs(op)
#     609   saturated = False
#     610   while not saturated:
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/framework/auto_control_deps_utils.py:105, in get_read_write_resource_inputs(op)
#     102   return (reads, writes)
#     104 try:
# --> 105   read_only_input_indices = op.get_attr(READ_ONLY_RESOURCE_INPUTS_ATTR)
#     106 except ValueError:
#     107   # Attr was not set. Add all resource inputs to `writes` and return.
#     108   writes.update(t for t in op.inputs if t.dtype == dtypes.resource)
#
# File ~/WORKSPACE/ICREA/app_overlap/results_repo/intersection_model/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:1606, in Operation.get_attr(self, name)
#    1604 fields = ("s", "i", "f", "b", "type", "shape", "tensor", "func")
#    1605 try:
# -> 1606   with c_api_util.tf_buffer() as buf:   # pytype: disable=wrong-arg-count
#    1607     pywrap_tf_session.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    1608     data = pywrap_tf_session.TF_GetBuffer(buf)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.13_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/contextlib.py:141, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     138     except StopIteration:
#     139         raise RuntimeError("generator didn't yield") from None
# --> 141 def __exit__(self, typ, value, traceback):
#     142     if typ is None:
#     143         try:
#
# KeyboardInterrupt:

# %%
# CHECK opcional: ejecutar SOLO después de que haya terminado la celda principal.
# No usa variables internas de la función; lee directamente el CSV generado.
import pandas as pd
from sklearn.metrics import classification_report
from pathlib import Path

pred_path = Path("./content/perpetrator/predictions_with_probs.csv")

if pred_path.exists():
    df_pred = pd.read_csv(pred_path)
    print("Saved:", pred_path)
    print(df_pred.head())
    print(df_pred.shape)
    print(df_pred.columns.tolist())

    print("\n=== FINAL REPORT — PERPETRATOR CSV ===")
    print(classification_report(df_pred["y_true_perp"], df_pred["y_pred_perp"], digits=3))
else:
    print("Todavía no existe:", pred_path)
    print("Ejecuta primero la celda principal que entrena el modelo.")
