# %% [markdown]
# # PCA train-only DETERMINISTIC TEST
#
# Versión de prueba para perpetrador: split antes de escalado/PCA, scaler/PCA ajustados solo en train y entrenamiento DNN con semillas/determinismo reforzado. Guarda resultados en `./content/perpetrator`.

# %% [markdown]
# # Perpetrator clasificator
# Script backend para construir y evaluar el clasificador de perpetrador.<br>
# Junta todas las celdas de código en una.<br>
# Construye la tabla con datos, el conjunto de entrenamiento y validación.<br>
# Entrena el modelo DNN, lo evalua y muestra los resultados de la evaluación como resultado final.<br>

# %% [markdown]
# ### Pre-condición
# Tu gráfica puede ayudarte con el cálculo, comprúebalo ejecutando el código de aqui abajo👇

# %%
#%pip install torch
import torch
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# ### Ejecución
# El siguiente código realiza el proceso de clasificación explicado al comienzo.

# %%
# ============================
# Perpetrator PCA train-only DETERMINISTIC TEST
# Cambios principales:
# - split antes de scaler/PCA
# - scaler/PCA ajustados solo en train
# - semillas fijadas para Python/NumPy/TensorFlow
# - float32 en lugar de mixed_bfloat16
# - tf.data shuffle determinista
# - Dropout e inicializadores con seed
# - clear_session antes de cada candidato
# - best model/predicciones guardados desde el candidato seleccionado, no desde variables residuales
# - output_dir se mantiene en ./content/perpetrator, como pediste
# ============================

import os
os.environ["PYTHONHASHSEED"] = "42"
os.environ["TF_DETERMINISTIC_OPS"] = "1"
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"

import re
import json
import random
import itertools
import joblib
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    balanced_accuracy_score,
)

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, Callback

RANDOM_STATE = 42
THRESHOLD = 0.50

try:
    tf.keras.utils.set_random_seed(RANDOM_STATE)
    tf.config.experimental.enable_op_determinism()
    print("Determinismo TensorFlow activado.")
except Exception as e:
    print("Aviso: no se pudo activar determinismo completo de TensorFlow:", repr(e))

# Usamos float32 para minimizar variabilidad numérica frente a mixed_bfloat16.
tf.keras.mixed_precision.set_global_policy("float32")
print("Política de precisión:", tf.keras.mixed_precision.global_policy())


def perform_pca(df: pd.DataFrame,
                save_scaler_path: str = "models/scaler_minmax.pkl",
                save_pca_path: str = "models/modelo_pca.pkl",
                save_means_path: str = "models/medias_escalado.csv"
               ):
    """
    Realiza un PCA sobre el DataFrame de entrada y devuelve:
      1) df_pca: DataFrame con las componentes principales (PC1, PC2, …).
      2) df_var: DataFrame con las varianzas explicada y acumulada por componente.
      3) scaler: MinMaxScaler ya entrenado.
      4) pca: PCA ya entrenado.
      5) means: Series con la media de cada variable tras escalado.
    Además guarda automáticamente el scaler, el modelo PCA y el vector de medias en rutas predeterminadas.

    Parámetros
    ----------
    df : pd.DataFrame
        DataFrame numérico de entrada (n muestras × p variables).
    save_scaler_path : str
        Ruta por defecto donde volcar el scaler (pickle).
    save_pca_path : str
        Ruta por defecto donde volcar el modelo PCA (pickle).
    save_means_path : str
        Ruta por defecto donde guardar las medias de cada variable tras escalado (CSV).

    Retorna
    -------
    df_pca : pd.DataFrame
        Transformación PCA (n muestras × p componentes), columnas PC1…PCp.
    df_var : pd.DataFrame
        Tabla con columnas:
          - PC: nombre de la componente ("PC1", "PC2", …)
          - explained variance: varianza explicada por cada componente
          - cumulative variance: varianza acumulada hasta esa componente
    scaler : MinMaxScaler
        Objeto scaler ajustado (fit).
    pca : PCA
        Objeto PCA ajustado (fit).
    means : pd.Series
        Media de cada variable tras el escalado (para centrar nuevos datos).
    """
    # Crear carpetas si no existen

    os.makedirs(os.path.dirname(save_scaler_path), exist_ok=True)
    os.makedirs(os.path.dirname(save_pca_path), exist_ok=True)
    os.makedirs(os.path.dirname(save_means_path), exist_ok=True)

    # 1) Escalado al rango [0,1]
    scaler = MinMaxScaler(feature_range=(0, 1))
    X_scaled = scaler.fit_transform(df.values)

    # 2) Cálculo de medias para centrar
    means_array = X_scaled.mean(axis=0)
    means = pd.Series(means_array, index=df.columns, name='mean')

    # 3) Centramos cada variable usando las medias calculadas
    X_centered = X_scaled - means_array

    # 4) Ajustar y transformar PCA
    pca = PCA(n_components=df.shape[1])
    comps = pca.fit_transform(X_centered)

    # 5) DataFrame de componentes principales
    cols = [f"PC{i+1}" for i in range(df.shape[1])]
    df_pca = pd.DataFrame(comps, index=df.index, columns=cols)

    # 6) Varianzas explicada y acumulada
    var_ratio = pca.explained_variance_ratio_
    cum_var  = var_ratio.cumsum()
    df_var = pd.DataFrame({
        "PC": cols,
        "explained variance": var_ratio,
        "cumulative variance": cum_var
    })

    # 7) Guardar a disco en rutas por defecto
    joblib.dump(scaler, save_scaler_path)
    joblib.dump(pca, save_pca_path)
    means.to_csv(save_means_path, header=True)

    return df_pca, df_var, scaler, pca, means

def plot_pca_variance(df_var):
    """
    Genera un barplot de la varianza explicada (barras amarillas) y un lineplot
    de la varianza acumulada (línea azul), marcando con un punto rojo donde
    la varianza acumulada supera el 0.95.

    Parámetros
    ----------
    df_var : pandas.DataFrame
        DataFrame con columnas:
          - "PC": nombres de componentes ("PC1", "PC2", …)
          - "explained variance": varianza explicada por componente
          - "cumulative variance": varianza acumulada
    """
    # Preparar datos
    x = range(len(df_var))
    explained = df_var['explained variance']
    cumulative = df_var['cumulative variance']

    # Crear la figura
    plt.figure(figsize=(10, 6))

    # Barplot de varianza explicada
    plt.bar(x, explained, color='orange', label='Explained Variance')

    # Lineplot de varianza acumulada
    plt.plot(x, cumulative, color='blue', marker='o', label='Cumulative Variance')

    # Punto rojo donde cumulative > 0.95
    above_idx = df_var.index[cumulative > 0.95]
    if not above_idx.empty:
        idx0 = above_idx[0]
        plt.scatter(idx0, cumulative[idx0], color='red', zorder=5, label='Cumulative > 0.95')
        plt.axvline(x=idx0, color='red', linestyle='--')

    # Configuración de ejes y leyenda
    plt.xticks(x, df_var['PC'], rotation=90)
    plt.xlabel('Principal Components')
    plt.ylabel('Variance')
    plt.title('Explained and Cumulative Variance by PCA Components')
    plt.legend()
    plt.tight_layout()
    plt.show()


def select_PCA_df(df_var: pd.DataFrame, df_PCA: pd.DataFrame, threshold: float) -> pd.DataFrame:
    """
    Selecciona las primeras i componentes principales de df_PCA donde i es el número de componente
    tal que el primer valor de 'cumulative variance' en df_var supera el umbral dado.

    Args:
        df_var (pd.DataFrame): DataFrame con columnas 'PC' (etiquetas 'PC1', 'PC2', ...) y
                               'cumulative variance' (float entre 0 y 1).
        df_PCA (pd.DataFrame): DataFrame resultante de una PCA, con tantas columnas como componentes.
        threshold (float): Umbral de varianza acumulada entre 0 y 1.

    Returns:
        pd.DataFrame: Subset de df_PCA con las primeras i columnas.
    """
    # Validación de umbral
    if not (0 <= threshold <= 1):
        raise ValueError("El umbral debe estar entre 0 y 1")

    # Buscar el primer índice que supere el threshold
    mask = df_var['cumulative variance'] > threshold
    if not mask.any():
        raise ValueError("Ningún valor de varianza acumulada supera el umbral dado")

    idx = mask.idxmax()  # índice del primer True
    pc_label = df_var.loc[idx, 'PC']  # p.ej. 'PC3'

    # Extraer i del string 'PCi'
    match = re.match(r'PC(\d+)', pc_label)
    if not match:
        raise ValueError(f"Formato inesperado en etiqueta PC: {pc_label}")
    i = int(match.group(1))

    # Seleccionar las primeras i columnas de df_PCA
    return df_PCA.iloc[:, :i]



def NN_perpetrator_classifier(
    df_features,
    df_merged_perpetrador_target,
    output_dir='./content/perpetrator',
    batch_size=128,
    grid_params=None,
    tpu_address=None,
    pca_threshold=0.99,
    random_state=RANDOM_STATE,
    threshold=THRESHOLD,
    stop_at_first_match=True,
    min_recall_1=0.90,
    min_recall_0=0.27,
):
    """
    Entrena un clasificador neuronal para perpetración con PCA train-only.

    Versión determinista para comprobar repetibilidad:
    - fija semillas de Python, NumPy y TensorFlow;
    - usa float32;
    - usa shuffle determinista con reshuffle_each_iteration=False;
    - usa seeds en Dense/Dropout;
    - limpia sesión de Keras antes de cada candidato;
    - guarda siempre los artefactos del candidato seleccionado.

    Criterio de selección por defecto:
    - candidato válido si recall_1 >= min_recall_1 y recall_0 >= min_recall_0;
    - con stop_at_first_match=True se detiene en el primer candidato válido, pero ahora debería repetir;
    - si no aparece candidato válido, se selecciona el mayor balanced_accuracy.
    """
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    # 1. Semillas globales al entrar en la función
    os.environ["PYTHONHASHSEED"] = str(random_state)
    random.seed(random_state)
    np.random.seed(random_state)
    tf.keras.utils.set_random_seed(random_state)
    try:
        tf.config.experimental.enable_op_determinism()
    except Exception:
        pass

    # 2. Estrategia. No forzamos mixed precision.
    try:
        resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu=tpu_address)
        tf.config.experimental_connect_to_cluster(resolver)
        tf.tpu.experimental.initialize_tpu_system(resolver)
        strategy = tf.distribute.TPUStrategy(resolver)
        print("👾 TPU inicializado:", resolver.master())
    except Exception:
        strategy = tf.distribute.get_strategy()
        print("⚠️ No se encontró TPU, usando", type(strategy).__name__)

    tf.keras.mixed_precision.set_global_policy("float32")
    print("Política de precisión:", tf.keras.mixed_precision.global_policy())

    # 3. Preparar datos y split
    y_series = df_merged_perpetrador_target.astype(int)
    all_idx = df_features.index.to_numpy()

    train_idx, val_idx = train_test_split(
        all_idx,
        test_size=0.25,
        random_state=random_state,
        stratify=y_series,
    )

    splits = {
        'train': train_idx.tolist(),
        'val': val_idx.tolist(),
        'pca_scope': 'train_only',
        'random_state': random_state,
        'threshold': threshold,
    }
    with open(output_dir / 'splits_indices.json', 'w', encoding='utf-8') as f:
        json.dump(splits, f, indent=2)
    print(f"Índices de split guardados en '{output_dir}/splits_indices.json'")

    # 4. PCA train-only
    X_train_raw = df_features.loc[train_idx].copy()
    X_val_raw = df_features.loc[val_idx].copy()
    y_train = y_series.loc[train_idx].values.astype(int)
    y_val = y_series.loc[val_idx].values.astype(int)

    scaler = MinMaxScaler(feature_range=(0, 1))
    X_train_scaled = scaler.fit_transform(X_train_raw.values)
    X_val_scaled = scaler.transform(X_val_raw.values)

    means_array = X_train_scaled.mean(axis=0)
    means = pd.Series(means_array, index=X_train_raw.columns, name='mean')
    X_train_centered = X_train_scaled - means_array
    X_val_centered = X_val_scaled - means_array

    pca = PCA(n_components=X_train_raw.shape[1], random_state=random_state)
    X_train_pca_all = pca.fit_transform(X_train_centered)
    X_val_pca_all = pca.transform(X_val_centered)

    var_ratio = pca.explained_variance_ratio_
    cum_var = var_ratio.cumsum()
    pc_all_cols = [f"PC{i+1}" for i in range(X_train_raw.shape[1])]
    df_variance_local = pd.DataFrame({
        "PC": pc_all_cols,
        "explained variance": var_ratio,
        "cumulative variance": cum_var,
    })
    n_components = int(np.argmax(cum_var >= pca_threshold) + 1)
    pc_cols = pc_all_cols[:n_components]

    X_train = X_train_pca_all[:, :n_components].astype("float32")
    X_val = X_val_pca_all[:, :n_components].astype("float32")

    joblib.dump(scaler, output_dir / 'scaler_minmax.pkl')
    joblib.dump(pca, output_dir / 'modelo_pca.pkl')
    means.to_csv(output_dir / 'medias_escalado.csv', header=True)
    df_variance_local.to_csv(output_dir / 'df_PCA_variance_trainonly.csv', index=False)
    pd.DataFrame(
        np.vstack([X_train, X_val]),
        columns=pc_cols,
    ).to_csv(output_dir / f'df_PCA_{int(pca_threshold*100)}_trainonly_stacked.csv', index=False)

    globals().update({
        "scaler": scaler,
        "pca": pca,
        "means": means,
        "df_variance": df_variance_local,
        "PCA_N_COMPONENTS_TRAINONLY": n_components,
    })

    print(f"PCA train-only seleccionado: {n_components} componentes (threshold={pca_threshold})")
    print(f"Train n={len(train_idx)} positives={int(y_train.sum())}; Val n={len(val_idx)} positives={int(y_val.sum())}")

    # 5. Class weights
    unique_classes, counts = np.unique(y_train, return_counts=True)
    class_weight = {int(cls): 1.0 for cls in unique_classes}
    if 0 in unique_classes and 1 in unique_classes:
        n0 = counts[unique_classes == 0].sum()
        n1 = counts[unique_classes == 1].sum()
        class_weight = {0: 1.0, 1: float(n0 / n1)}
    print("class_weight:", class_weight)

    # 6. Dataset determinista
    ds_options = tf.data.Options()
    ds_options.experimental_deterministic = True

    train_ds = (
        tf.data.Dataset.from_tensor_slices((X_train, y_train))
        .shuffle(buffer_size=len(X_train), seed=random_state, reshuffle_each_iteration=False)
        .batch(batch_size)
        .with_options(ds_options)
    )
    val_ds = (
        tf.data.Dataset.from_tensor_slices((X_val, y_val))
        .batch(batch_size)
        .with_options(ds_options)
    )

    # 7. Callback para detener por sobreajuste
    class OverfitStopping(Callback):
        def __init__(self, threshold_delta=0.1):
            super().__init__()
            self.threshold_delta = threshold_delta

        def on_epoch_end(self, epoch, logs=None):
            logs = logs or {}
            tr = logs.get('recall')
            vr = logs.get('val_recall')
            if tr is not None and vr is not None and (tr - vr) > self.threshold_delta:
                print(f"\nDetenido en epoch {epoch+1}: Δrecall > {self.threshold_delta}")
                self.model.stop_training = True

    # 8. Grid por defecto. Se mantiene igual que el notebook original.
    if grid_params is None:
        grid_params = {
            'u1': [64, 32, 16],
            'a1': ['relu', 'linear', 'tanh', 'sigmoid'],
            'd1': [0.3, 0.2, 0.1],
            'u2': [16, 8, 4],
            'a2': ['relu', 'linear', 'tanh', 'sigmoid'],
            'd2': [0.1, 0.05, 0.0],
        }

    def build_model(u1, a1, d1, u2, a2, d2, seed):
        return models.Sequential([
            layers.Input(shape=(X_train.shape[1],)),
            layers.Dense(
                u1,
                activation=a1,
                kernel_initializer=tf.keras.initializers.GlorotUniform(seed=seed + 11),
                bias_initializer=tf.keras.initializers.Zeros(),
            ),
            layers.Dropout(d1, seed=seed + 12),
            layers.Dense(
                u2,
                activation=a2,
                kernel_initializer=tf.keras.initializers.GlorotUniform(seed=seed + 21),
                bias_initializer=tf.keras.initializers.Zeros(),
            ),
            layers.Dropout(d2, seed=seed + 22),
            layers.Dense(
                1,
                activation='sigmoid',
                dtype='float32',
                kernel_initializer=tf.keras.initializers.GlorotUniform(seed=seed + 31),
                bias_initializer=tf.keras.initializers.Zeros(),
            ),
        ])

    results = []
    best_state = None
    best_valid_state = None
    condition_met = False

    candidate_iter = itertools.product(
        grid_params['u1'], grid_params['a1'], grid_params['d1'],
        grid_params['u2'], grid_params['a2'], grid_params['d2'],
    )

    with strategy.scope():
        for candidate_i, (u1, a1, d1, u2, a2, d2) in enumerate(candidate_iter):
            candidate_seed = random_state + candidate_i * 1000
            tf.keras.backend.clear_session()
            random.seed(candidate_seed)
            np.random.seed(candidate_seed)
            tf.keras.utils.set_random_seed(candidate_seed)

            model = build_model(u1, a1, d1, u2, a2, d2, candidate_seed)
            model.compile(
                optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                loss='binary_crossentropy',
                metrics=[
                    tf.keras.metrics.Recall(name='recall'),
                    tf.keras.metrics.Precision(name='precision'),
                    tf.keras.metrics.BinaryAccuracy(name='accuracy'),
                ],
            )

            history = model.fit(
                train_ds,
                validation_data=val_ds,
                epochs=200,
                class_weight=class_weight,
                callbacks=[
                    OverfitStopping(0.1),
                    EarlyStopping(
                        monitor='val_recall',
                        mode='max',
                        patience=5,
                        restore_best_weights=True,
                    ),
                ],
                verbose=0,
            )

            y_pred_probs = model.predict(val_ds, verbose=0).reshape(-1)
            y_pred = (y_pred_probs >= threshold).astype(int)
            y_val_true = y_val.astype(int)

            report = classification_report(y_val_true, y_pred, output_dict=True, zero_division=0)
            recall0 = float(report.get('0', {}).get('recall', 0))
            recall1 = float(report.get('1', {}).get('recall', 0))
            precision1 = float(report.get('1', {}).get('precision', 0))
            f1_1 = float(report.get('1', {}).get('f1-score', 0))
            accuracy = float(report.get('accuracy', 0))
            bal_acc = float(balanced_accuracy_score(y_val_true, y_pred))
            tn, fp, fn, tp = confusion_matrix(y_val_true, y_pred, labels=[0, 1]).ravel()

            row = {
                'candidate_i': candidate_i,
                'seed': candidate_seed,
                'u1': u1,
                'a1': a1,
                'd1': d1,
                'u2': u2,
                'a2': a2,
                'd2': d2,
                'recall_0': recall0,
                'recall_1': recall1,
                'precision_1': precision1,
                'f1_1': f1_1,
                'accuracy': accuracy,
                'balanced_accuracy': bal_acc,
                'TP': int(tp),
                'FP': int(fp),
                'TN': int(tn),
                'FN': int(fn),
                'epochs_run': len(history.history.get('loss', [])),
            }
            results.append(row)
            print(row)

            state = {
                'row': row,
                'report': report,
                'model': model,
                'y_pred_probs': y_pred_probs.copy(),
                'y_pred': y_pred.copy(),
            }

            # Fallback: mejor balanced accuracy si no se encuentra candidato válido.
            if best_state is None or (
                row['balanced_accuracy'], row['recall_1'], row['recall_0'], row['precision_1']
            ) > (
                best_state['row']['balanced_accuracy'], best_state['row']['recall_1'], best_state['row']['recall_0'], best_state['row']['precision_1']
            ):
                best_state = state

            is_valid = (recall1 >= min_recall_1 and recall0 >= min_recall_0)
            if is_valid:
                if best_valid_state is None or (
                    row['balanced_accuracy'], row['recall_0'], row['precision_1'], row['accuracy']
                ) > (
                    best_valid_state['row']['balanced_accuracy'], best_valid_state['row']['recall_0'], best_valid_state['row']['precision_1'], best_valid_state['row']['accuracy']
                ):
                    best_valid_state = state

                if stop_at_first_match:
                    print(
                        f"\n🚀 Condición alcanzada (recall_1={recall1:.3f}, recall_0={recall0:.3f}); "
                        "deteniendo grid-search de forma determinista."
                    )
                    condition_met = True
                    break

    df_results = pd.DataFrame(results)
    df_results.to_csv(output_dir / 'gridsearch_results.csv', index=False)

    selected = best_valid_state if best_valid_state is not None else best_state
    if selected is None:
        raise RuntimeError("No se entrenó ningún candidato del grid-search.")

    selected_row = selected['row']
    print("\nCandidato seleccionado:")
    print(pd.Series(selected_row))
    print("\nReporte seleccionado:")
    print(classification_report(y_val, selected['y_pred'], digits=3, zero_division=0))

    selected['model'].save(output_dir / 'best_model.h5')
    with open(output_dir / 'best_report.json', 'w', encoding='utf-8') as f:
        json.dump(selected['report'], f, indent=2)

    config = {
        'random_state': random_state,
        'threshold': threshold,
        'pca_threshold': pca_threshold,
        'pca_scope': 'train_only',
        'n_components': n_components,
        'batch_size': batch_size,
        'precision_policy': str(tf.keras.mixed_precision.global_policy()),
        'deterministic_ops_requested': True,
        'shuffle_seed': random_state,
        'reshuffle_each_iteration': False,
        'stop_at_first_match': stop_at_first_match,
        'min_recall_1': min_recall_1,
        'min_recall_0': min_recall_0,
        'selected_candidate': selected_row,
        'condition_met': condition_met,
    }
    with open(output_dir / 'config.json', 'w', encoding='utf-8') as f:
        json.dump(config, f, indent=2)

    # 9. Guardar conjuntos entreno/val a CSV
    pd.DataFrame(X_train, columns=pc_cols).to_csv(output_dir / 'X_train.csv', index=False)
    pd.DataFrame(X_val, columns=pc_cols).to_csv(output_dir / 'X_val.csv', index=False)
    pd.Series(y_train, name='PERPETRADOR').to_csv(output_dir / 'y_train.csv', index=False)
    pd.Series(y_val, name='PERPETRADOR').to_csv(output_dir / 'y_val.csv', index=False)

    # 10. Predicciones con probabilidades y guardado desde el candidato seleccionado
    df_pred = pd.DataFrame({
        'idx_original': val_idx,
        'y_true_perp': y_val.astype(int),
        'y_pred_perp': selected['y_pred'].astype(int),
        'y_prob_perp': selected['y_pred_probs'].astype(float),
    }).sort_values('idx_original').reset_index(drop=True)

    pred_path = output_dir / 'predictions_with_probs.csv'
    df_pred.to_csv(pred_path, index=False)

    print(f"Saved: {pred_path}")
    print(df_pred.head())
    print(df_pred.shape)

    # También dejamos best_combination compatible con tu código previo.
    best_combination = pd.Series(selected_row)
    return df_results, best_combination


#Montamos el dataset original
feat_df = pd.read_csv('./../data/lista_global_vars.csv')
target_df = pd.read_csv('./../data/target_col.csv').fillna(0) # fillna imputa los missings con la categoría 0 que es la correcta.
df_merged = feat_df.join(target_df, how='inner')
df_merged = df_merged[~((df_merged["GENERO_BIN_2"] == 1) | (df_merged["ORIENTSEX.BN_3"] == 1))].drop(columns=["GENERO_BIN_2","ORIENTSEX.BN_3"]).reset_index(drop=True)

df_merged_perpretador = df_merged.drop(columns=['VÍCTIMA', 'VICTIMA_PERPETRADOR', 'POLIVICTIMIZACION', 'POLIPERPETRACION', 'SOLO.VICTIMA', 'SOLO.PERPETRADOR', 'NO.VICT_NO.PERP', 'V.O', 'P.SUM.TOTAL', 'V.SUM.TOTAL'])

df_merged_perpetrador_feat = df_merged_perpretador.drop(columns=["PERPETRADOR"])
df_merged_perpetrador_target = df_merged_perpretador["PERPETRADOR"]

#Quitamos el warning de replace
pd.set_option('future.no_silent_downcasting', True)

#Pasamos País a Booleano
df_merged_perpetrador_feat['PAÍS'] = df_merged_perpetrador_feat['PAÍS'].replace({1: True, 2: False})
#Pasamos Etnia a Booleano
df_merged_perpetrador_feat['ETNIA.BN'] = df_merged_perpetrador_feat['ETNIA.BN'].replace({0.0: False, 1.0: True})
#Pasamos Fugas a Booleano
df_merged_perpetrador_feat['FUGAS.BN'] = df_merged_perpetrador_feat['FUGAS.BN'].replace({0.0: False, 1.0: True})
#One-hot encoding de Porno
#df_merged_perpetrador_feat = pd.get_dummies(df_merged_perpetrador_feat, columns=['PORNO.T'])
"""
# ABUSOSUBS2 hereda de ABUSOSUBS1 si es 0
df_merged_perpetrador_feat.loc[df_merged_perpetrador_feat['ABUSOSUBS1'] == 0, 'ABUSOSUBS2'] = 0
# Agrupamos ABUSOSUBS2, categoría False es nunca, anual, mensual True es Diario, Semanal. Dejamos solo la binaria
df_merged_perpetrador_feat['ABUSOSUBS2.BN'] = (~df_merged_perpetrador_feat['ABUSOSUBS2'].isin([1,2,3]))
df_merged_perpetrador_feat = df_merged_perpetrador_feat.drop(columns=["ABUSOSUBS2"])
df_merged_perpetrador_feat = pd.get_dummies(df_merged_perpetrador_feat, columns=['ABUSOSUBS1'])
"""
"""
#Limpiamos genero y orientacion sexual
df_merged_perpetrador_feat = df_merged_perpetrador_feat.drop(columns=["GENERO_BIN_1","ORIENTSEX.BN_2"])
#Renombramos
df_merged_perpetrador_feat = df_merged_perpetrador_feat.rename(columns=
                                                       {'GENERO_BIN_0': 'GENERO.BN', 'ORIENTSEX.BN_1': 'ORIENTSEX.BN'})
#Convertimos a booleano
df_merged_perpetrador_feat['GENERO.BN'] = df_merged_perpetrador_feat['GENERO.BN'].replace({0.0: False, 1.0: True})
df_merged_perpetrador_feat['ORIENTSEX.BN'] = df_merged_perpetrador_feat['ORIENTSEX.BN'].replace({0.0: False, 1.0: True})
"""

#Alternativa, convertimos a booleanos sin limpiar para no perder precisión
df_merged_perpetrador_feat['GENERO.BN0'] = df_merged_perpetrador_feat['GENERO_BIN_0'].replace({0.0: False, 1.0: True})
df_merged_perpetrador_feat['ORIENTSEX.BN0'] = df_merged_perpetrador_feat['ORIENTSEX.BN_1'].replace({0.0: False, 1.0: True})
df_merged_perpetrador_feat['GENERO.BN1'] = df_merged_perpetrador_feat['GENERO_BIN_1'].replace({0.0: False, 1.0: True})
df_merged_perpetrador_feat['ORIENTSEX.BN1'] = df_merged_perpetrador_feat['ORIENTSEX.BN_2'].replace({0.0: False, 1.0: True})
df_merged_perpetrador_feat = df_merged_perpetrador_feat.drop(columns=["GENERO_BIN_0","GENERO_BIN_1","ORIENTSEX.BN_1","ORIENTSEX.BN_2"])

#Convive con hermanos
df_merged_perpetrador_feat = df_merged_perpetrador_feat.rename(columns= {'CONVIVEN.5': 'CONVIVEN_H'})
df_merged_perpetrador_feat['CONVIVEN_H'] = df_merged_perpetrador_feat['CONVIVEN_H'].replace({0.0: False, 1.0: True})
#Conviven con 0 progenitores
df_merged_perpetrador_feat = df_merged_perpetrador_feat.rename(columns= {'CONVIVEN.6': 'CONVIVEN_0'})
df_merged_perpetrador_feat['CONVIVEN_0'] = df_merged_perpetrador_feat['CONVIVEN_0'].replace({0.0: False, 1.0: True})
"""
#Conviven con 1 progenitore
df_merged_perpetrador_feat['CONVIVEN_1'] = ((df_merged_perpetrador_feat[['CONVIVEN.1','CONVIVEN.2','CONVIVEN.3','CONVIVEN.4']] == 1).sum(axis=1) == 1)
#Conviven con 2 progenitores
df_merged_perpetrador_feat['CONVIVEN_2'] = ((df_merged_perpetrador_feat[['CONVIVEN.1','CONVIVEN.2','CONVIVEN.3','CONVIVEN.4']] == 1).sum(axis=1) > 1)
#Limpiamos las conviven viejas
df_merged_perpetrador_feat = df_merged_perpetrador_feat.drop(columns=["CONVIVEN.1","CONVIVEN.2","CONVIVEN.3","CONVIVEN.4"])
"""
#Mostramos el data-set final
display(df_merged_perpetrador_feat)

df_merged_perpetrador_feat.to_csv("df_perpetrador_feat.csv")
df_merged_perpetrador_target.to_csv("df_perpretador_target.csv")

# PCA TRAIN-ONLY TEST
# No se ajusta scaler/PCA sobre toda la muestra. El split se hace dentro del clasificador y el PCA se ajusta SOLO en train.
df_results, best_combination = NN_perpetrator_classifier(
    df_merged_perpetrador_feat,
    df_merged_perpetrador_target,
    output_dir='./content/perpetrator',
    batch_size=128,
    grid_params=None,
    tpu_address=None,
    pca_threshold=0.99
)
plot_pca_variance(df_variance)

#Mostramos las max_variables variables más importantes de cada PC hasta max_PC
max_PC = 18
max_variables = 5
loadings = pd.DataFrame(
    pca.components_,
    columns=df_merged_perpetrador_feat.columns,
    index=[f"PC{i+1}" for i in range(pca.n_components_)]
)
filas = []
for pc in loadings.index[:max_PC]:
    s = loadings.loc[pc].sort_values(key=abs, ascending=False).head(max_variables)

    fila = {"PC": pc}

    for i, (var, valor) in enumerate(s.items(), start=1):
        fila[f"var_{i}"] = var
        fila[f"loading_{i}"] = valor

    filas.append(fila)
tabla_top_pcs = pd.DataFrame(filas)
display(tabla_top_pcs)

# Comprobación final del CSV de predicciones para SMART AND
data_set = pd.read_csv('./content/perpetrator/predictions_with_probs.csv')

print("=== CHECK predictions_with_probs.csv ===")
print(data_set.head())
print(data_set.shape)
print(data_set.columns.tolist())

true_column = data_set['y_true_perp']
pred_column = data_set['y_pred_perp']

print(classification_report(true_column, pred_column, digits=3))
# Out:
# Determinismo TensorFlow activado.
# Política de precisión: <DTypePolicy "float32">
# /var/folders/5x/ww_kz7lx5wz4pn1typnpk_g40000gn/T/ipykernel_41787/3543543580.py:622: Pandas4Warning: 'future.no_silent_downcasting' is deprecated, please refrain from using it.
#   pd.set_option('future.no_silent_downcasting', True)
#        PAÍS ETNIA.BN  EDAD FUGAS.BN  ABUSOSUBS1  ABUSOSUBS2  CONVIVEN.1  \
# 0      True    False  16.0    False           4           4         1.0
# 1      True    False  16.0    False           3           2         1.0
# 2      True    False  17.0    False           3           3         1.0
# 3      True    False  16.0    False           3           3         1.0
# 4      True    False  17.0    False           3           3         1.0
# ...     ...      ...   ...      ...         ...         ...         ...
# 3762   True    False  14.0    False           0           0         1.0
# 3763  False    False  14.0     True           2           0         1.0
# 3764   True    False  14.0    False           2           0         1.0
# 3765  False    False  14.0    False           0           0         1.0
# 3766   True    False  15.0     True           4           4         0.0
#
#       CONVIVEN.2  CONVIVEN.3  CONVIVEN.4  ... APOYO.MEAN APOYO.MEDIAN  \
# 0            1.0         0.0         0.0  ...   4.000000          4.0
# 1            1.0         0.0         0.0  ...   3.428571          4.0
# 2            1.0         0.0         0.0  ...   3.285714          4.0
# 3            1.0         0.0         0.0  ...   3.285714          4.0
# 4            1.0         0.0         0.0  ...   3.571429          4.0
# ...          ...         ...         ...  ...        ...          ...
# 3762         1.0         0.0         0.0  ...   3.285714          4.0
# 3763         1.0         0.0         0.0  ...   2.714286          3.0
# 3764         1.0         0.0         0.0  ...   3.714286          4.0
# 3765         1.0         0.0         0.0  ...   3.714286          4.0
# 3766         0.0         0.0         1.0  ...   2.571429          3.0
#
#       APOYO.VAR  MORAL.MEAN  MORAL.VAR  PORNO.T  GENERO.BN0  ORIENTSEX.BN0  \
# 0      0.000000         5.0       0.00      1.0       False           True
# 1      0.530612         2.8       0.56      4.0        True           True
# 2      0.775510         4.2       0.96      3.0       False           True
# 3      0.775510         4.0       0.40      4.0        True           True
# 4      0.530612         4.4       1.44      2.0       False           True
# ...         ...         ...        ...      ...         ...            ...
# 3762   1.061224         3.6       0.24      1.0       False           True
# 3763   1.061224         4.4       0.64      1.0       False           True
# 3764   0.489796         4.8       0.16      1.0       False           True
# 3765   0.204082         5.0       0.00      1.0       False           True
# 3766   1.959184         1.8       0.96      2.0       False           True
#
#       GENERO.BN1  ORIENTSEX.BN1
# 0           True          False
# 1          False          False
# 2           True          False
# 3          False          False
# 4           True          False
# ...          ...            ...
# 3762        True          False
# 3763        True          False
# 3764        True          False
# 3765        True          False
# 3766        True          False
#
# [3767 rows x 27 columns]
# ⚠️ No se encontró TPU, usando _DefaultDistributionStrategy
# Política de precisión: <DTypePolicy "float32">
# Índices de split guardados en 'content/perpetrator/splits_indices.json'
# PCA train-only seleccionado: 22 componentes (threshold=0.99)
# Train n=2825 positives=664; Val n=942 positives=221
# class_weight: {0: 1.0, 1: 3.2545180722891565}
# {'candidate_i': 0, 'seed': 42, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.6893203883495146, 'recall_1': 0.6334841628959276, 'precision_1': 0.38461538461538464, 'f1_1': 0.47863247863247865, 'accuracy': 0.6762208067940552, 'balanced_accuracy': 0.6614022756227211, 'TP': 140, 'FP': 224, 'TN': 497, 'FN': 81, 'epochs_run': 11}
# {'candidate_i': 1, 'seed': 1042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.4590846047156727, 'recall_1': 0.6832579185520362, 'precision_1': 0.27911275415896486, 'f1_1': 0.3963254593175853, 'accuracy': 0.5116772823779193, 'balanced_accuracy': 0.5711712616338545, 'TP': 151, 'FP': 390, 'TN': 331, 'FN': 70, 'epochs_run': 6}
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x12a746e80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# {'candidate_i': 2, 'seed': 2042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.5533980582524272, 'recall_1': 0.5701357466063348, 'precision_1': 0.28125, 'f1_1': 0.37668161434977576, 'accuracy': 0.5573248407643312, 'balanced_accuracy': 0.561766902429381, 'TP': 126, 'FP': 322, 'TN': 399, 'FN': 95, 'epochs_run': 6}
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x12aa98a40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# {'candidate_i': 3, 'seed': 3042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.6643550624133149, 'recall_1': 0.6380090497737556, 'precision_1': 0.3681462140992167, 'f1_1': 0.46688741721854304, 'accuracy': 0.6581740976645435, 'balanced_accuracy': 0.6511820560935353, 'TP': 141, 'FP': 242, 'TN': 479, 'FN': 80, 'epochs_run': 7}
# {'candidate_i': 4, 'seed': 4042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.5409153952843273, 'recall_1': 0.6606334841628959, 'precision_1': 0.3060796645702306, 'f1_1': 0.4183381088825215, 'accuracy': 0.5690021231422505, 'balanced_accuracy': 0.6007744397236117, 'TP': 146, 'FP': 331, 'TN': 390, 'FN': 75, 'epochs_run': 6}
# {'candidate_i': 5, 'seed': 5042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.59500693481276, 'recall_1': 0.6515837104072398, 'precision_1': 0.3302752293577982, 'f1_1': 0.4383561643835616, 'accuracy': 0.60828025477707, 'balanced_accuracy': 0.62329532261, 'TP': 144, 'FP': 292, 'TN': 429, 'FN': 77, 'epochs_run': 6}
# {'candidate_i': 6, 'seed': 6042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6490984743411928, 'recall_1': 0.6515837104072398, 'precision_1': 0.36272040302267, 'f1_1': 0.46601941747572817, 'accuracy': 0.6496815286624203, 'balanced_accuracy': 0.6503410923742163, 'TP': 144, 'FP': 253, 'TN': 468, 'FN': 77, 'epochs_run': 10}
# {'candidate_i': 7, 'seed': 7042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.5672676837725381, 'recall_1': 0.669683257918552, 'precision_1': 0.3217391304347826, 'f1_1': 0.434654919236417, 'accuracy': 0.5912951167728238, 'balanced_accuracy': 0.6184754708455451, 'TP': 148, 'FP': 312, 'TN': 409, 'FN': 73, 'epochs_run': 6}
#
# Detenido en epoch 1: Δrecall > 0.1
# {'candidate_i': 8, 'seed': 8042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.5936199722607489, 'recall_1': 0.5294117647058824, 'precision_1': 0.28536585365853656, 'f1_1': 0.37083993660855785, 'accuracy': 0.578556263269639, 'balanced_accuracy': 0.5615158684833157, 'TP': 117, 'FP': 293, 'TN': 428, 'FN': 104, 'epochs_run': 1}
# {'candidate_i': 9, 'seed': 9042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 10, 'seed': 10042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.6629680998613038, 'recall_1': 0.6108597285067874, 'precision_1': 0.35714285714285715, 'f1_1': 0.4507512520868113, 'accuracy': 0.6507430997876857, 'balanced_accuracy': 0.6369139141840456, 'TP': 135, 'FP': 243, 'TN': 478, 'FN': 86, 'epochs_run': 8}
# {'candidate_i': 11, 'seed': 11042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.6671289875173371, 'recall_1': 0.6515837104072398, 'precision_1': 0.375, 'f1_1': 0.47603305785123967, 'accuracy': 0.6634819532908705, 'balanced_accuracy': 0.6593563489622885, 'TP': 144, 'FP': 240, 'TN': 481, 'FN': 77, 'epochs_run': 15}
#
# Detenido en epoch 1: Δrecall > 0.1
# {'candidate_i': 12, 'seed': 12042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.5464632454923717, 'recall_1': 0.5520361990950227, 'precision_1': 0.2717149220489978, 'f1_1': 0.3641791044776119, 'accuracy': 0.5477707006369427, 'balanced_accuracy': 0.5492497222936972, 'TP': 122, 'FP': 327, 'TN': 394, 'FN': 99, 'epochs_run': 1}
# {'candidate_i': 13, 'seed': 13042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.5145631067961165, 'recall_1': 0.665158371040724, 'precision_1': 0.29577464788732394, 'f1_1': 0.40947075208913647, 'accuracy': 0.5498938428874734, 'balanced_accuracy': 0.5898607389184203, 'TP': 147, 'FP': 350, 'TN': 371, 'FN': 74, 'epochs_run': 6}
#
# Detenido en epoch 1: Δrecall > 0.1
# {'candidate_i': 14, 'seed': 14042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.5936199722607489, 'recall_1': 0.5158371040723982, 'precision_1': 0.2800982800982801, 'f1_1': 0.3630573248407643, 'accuracy': 0.5753715498938429, 'balanced_accuracy': 0.5547285381665736, 'TP': 114, 'FP': 293, 'TN': 428, 'FN': 107, 'epochs_run': 1}
# {'candidate_i': 15, 'seed': 15042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.6601941747572816, 'recall_1': 0.6244343891402715, 'precision_1': 0.360313315926893, 'f1_1': 0.45695364238410596, 'accuracy': 0.6518046709129511, 'balanced_accuracy': 0.6423142819487766, 'TP': 138, 'FP': 245, 'TN': 476, 'FN': 83, 'epochs_run': 8}
# {'candidate_i': 16, 'seed': 16042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.5325936199722607, 'recall_1': 0.6832579185520362, 'precision_1': 0.3094262295081967, 'f1_1': 0.42595204513399154, 'accuracy': 0.5679405520169851, 'balanced_accuracy': 0.6079257692621485, 'TP': 151, 'FP': 337, 'TN': 384, 'FN': 70, 'epochs_run': 6}
# {'candidate_i': 17, 'seed': 17042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.5423023578363384, 'recall_1': 0.5927601809954751, 'precision_1': 0.2841648590021692, 'f1_1': 0.3841642228739003, 'accuracy': 0.554140127388535, 'balanced_accuracy': 0.5675312694159067, 'TP': 131, 'FP': 330, 'TN': 391, 'FN': 90, 'epochs_run': 6}
# {'candidate_i': 18, 'seed': 18042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6171983356449375, 'recall_1': 0.6470588235294118, 'precision_1': 0.3412887828162291, 'f1_1': 0.446875, 'accuracy': 0.6242038216560509, 'balanced_accuracy': 0.6321285795871747, 'TP': 143, 'FP': 276, 'TN': 445, 'FN': 78, 'epochs_run': 7}
# {'candidate_i': 19, 'seed': 19042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.6823855755894591, 'recall_1': 0.6470588235294118, 'precision_1': 0.3844086021505376, 'f1_1': 0.4822934232715008, 'accuracy': 0.6740976645435244, 'balanced_accuracy': 0.6647221995594355, 'TP': 143, 'FP': 229, 'TN': 492, 'FN': 78, 'epochs_run': 9}
# {'candidate_i': 20, 'seed': 20042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.7115117891816921, 'recall_1': 0.6334841628959276, 'precision_1': 0.40229885057471265, 'f1_1': 0.492091388400703, 'accuracy': 0.6932059447983014, 'balanced_accuracy': 0.6724979760388099, 'TP': 140, 'FP': 208, 'TN': 513, 'FN': 81, 'epochs_run': 9}
# {'candidate_i': 21, 'seed': 21042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 22, 'seed': 22042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.680998613037448, 'recall_1': 0.6289592760180995, 'precision_1': 0.37669376693766937, 'f1_1': 0.4711864406779661, 'accuracy': 0.6687898089171974, 'balanced_accuracy': 0.6549789445277738, 'TP': 139, 'FP': 230, 'TN': 491, 'FN': 82, 'epochs_run': 20}
# {'candidate_i': 23, 'seed': 23042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 24, 'seed': 24042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.3106796116504854, 'recall_1': 0.8190045248868778, 'precision_1': 0.2669616519174041, 'f1_1': 0.40266963292547275, 'accuracy': 0.4299363057324841, 'balanced_accuracy': 0.5648420682686817, 'TP': 181, 'FP': 497, 'TN': 224, 'FN': 40, 'epochs_run': 6}
# {'candidate_i': 25, 'seed': 25042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.5228848821081831, 'recall_1': 0.6606334841628959, 'precision_1': 0.2979591836734694, 'f1_1': 0.41068917018284107, 'accuracy': 0.5552016985138004, 'balanced_accuracy': 0.5917591831355395, 'TP': 146, 'FP': 344, 'TN': 377, 'FN': 75, 'epochs_run': 6}
# {'candidate_i': 26, 'seed': 26042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.6213592233009708, 'recall_1': 0.6923076923076923, 'precision_1': 0.3591549295774648, 'f1_1': 0.47295208655332305, 'accuracy': 0.638004246284501, 'balanced_accuracy': 0.6568334578043316, 'TP': 153, 'FP': 273, 'TN': 448, 'FN': 68, 'epochs_run': 16}
# {'candidate_i': 27, 'seed': 27042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.7198335644937587, 'recall_1': 0.6380090497737556, 'precision_1': 0.4110787172011662, 'f1_1': 0.5, 'accuracy': 0.7006369426751592, 'balanced_accuracy': 0.6789213071337572, 'TP': 141, 'FP': 202, 'TN': 519, 'FN': 80, 'epochs_run': 11}
# {'candidate_i': 28, 'seed': 28042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.608876560332871, 'recall_1': 0.6199095022624435, 'precision_1': 0.3269689737470167, 'f1_1': 0.428125, 'accuracy': 0.6114649681528662, 'balanced_accuracy': 0.6143930312976572, 'TP': 137, 'FP': 282, 'TN': 439, 'FN': 84, 'epochs_run': 6}
# {'candidate_i': 29, 'seed': 29042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.6934812760055479, 'recall_1': 0.6153846153846154, 'precision_1': 0.38095238095238093, 'f1_1': 0.47058823529411764, 'accuracy': 0.6751592356687898, 'balanced_accuracy': 0.6544329456950817, 'TP': 136, 'FP': 221, 'TN': 500, 'FN': 85, 'epochs_run': 10}
# {'candidate_i': 30, 'seed': 30042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6629680998613038, 'recall_1': 0.6380090497737556, 'precision_1': 0.3671875, 'f1_1': 0.46611570247933887, 'accuracy': 0.6571125265392781, 'balanced_accuracy': 0.6504885748175298, 'TP': 141, 'FP': 243, 'TN': 478, 'FN': 80, 'epochs_run': 8}
# {'candidate_i': 31, 'seed': 31042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.6990291262135923, 'recall_1': 0.6153846153846154, 'precision_1': 0.38526912181303113, 'f1_1': 0.4738675958188153, 'accuracy': 0.6794055201698513, 'balanced_accuracy': 0.6572068707991039, 'TP': 136, 'FP': 217, 'TN': 504, 'FN': 85, 'epochs_run': 18}
# {'candidate_i': 32, 'seed': 32042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.6865464632454924, 'recall_1': 0.6018099547511312, 'precision_1': 0.37047353760445684, 'f1_1': 0.4586206896551724, 'accuracy': 0.6666666666666666, 'balanced_accuracy': 0.6441782089983118, 'TP': 133, 'FP': 226, 'TN': 495, 'FN': 88, 'epochs_run': 11}
# {'candidate_i': 33, 'seed': 33042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 34, 'seed': 34042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 35, 'seed': 35042, 'u1': 64, 'a1': 'relu', 'd1': 0.3, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 36, 'seed': 36042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.43966712898751736, 'recall_1': 0.6832579185520362, 'precision_1': 0.27207207207207207, 'f1_1': 0.38917525773195877, 'accuracy': 0.4968152866242038, 'balanced_accuracy': 0.5614625237697768, 'TP': 151, 'FP': 404, 'TN': 317, 'FN': 70, 'epochs_run': 6}
# {'candidate_i': 37, 'seed': 37042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.5104022191400832, 'recall_1': 0.7330316742081447, 'precision_1': 0.3145631067961165, 'f1_1': 0.44021739130434784, 'accuracy': 0.5626326963906582, 'balanced_accuracy': 0.6217169466741139, 'TP': 162, 'FP': 353, 'TN': 368, 'FN': 59, 'epochs_run': 6}
# {'candidate_i': 38, 'seed': 38042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.6393897364771152, 'recall_1': 0.6515837104072398, 'precision_1': 0.3564356435643564, 'f1_1': 0.4608, 'accuracy': 0.6422505307855626, 'balanced_accuracy': 0.6454867234421775, 'TP': 144, 'FP': 260, 'TN': 461, 'FN': 77, 'epochs_run': 8}
# {'candidate_i': 39, 'seed': 39042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.6047156726768377, 'recall_1': 0.6787330316742082, 'precision_1': 0.3448275862068966, 'f1_1': 0.4573170731707317, 'accuracy': 0.6220806794055201, 'balanced_accuracy': 0.6417243521755229, 'TP': 150, 'FP': 285, 'TN': 436, 'FN': 71, 'epochs_run': 7}
#
# Detenido en epoch 1: Δrecall > 0.1
# {'candidate_i': 40, 'seed': 40042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.6199722607489597, 'recall_1': 0.5656108597285068, 'precision_1': 0.3132832080200501, 'f1_1': 0.4032258064516129, 'accuracy': 0.6072186836518046, 'balanced_accuracy': 0.5927915602387333, 'TP': 125, 'FP': 274, 'TN': 447, 'FN': 96, 'epochs_run': 1}
# {'candidate_i': 41, 'seed': 41042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.5436893203883495, 'recall_1': 0.6199095022624435, 'precision_1': 0.2939914163090129, 'f1_1': 0.3988355167394469, 'accuracy': 0.5615711252653928, 'balanced_accuracy': 0.5817994113253965, 'TP': 137, 'FP': 329, 'TN': 392, 'FN': 84, 'epochs_run': 6}
#
# Detenido en epoch 1: Δrecall > 0.1
# {'candidate_i': 42, 'seed': 42042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6435506241331485, 'recall_1': 0.6199095022624435, 'precision_1': 0.3477157360406091, 'f1_1': 0.44552845528455287, 'accuracy': 0.638004246284501, 'balanced_accuracy': 0.631730063197796, 'TP': 137, 'FP': 257, 'TN': 464, 'FN': 84, 'epochs_run': 1}
# {'candidate_i': 43, 'seed': 43042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.651872399445215, 'recall_1': 0.6244343891402715, 'precision_1': 0.35475578406169667, 'f1_1': 0.4524590163934426, 'accuracy': 0.6454352441613588, 'balanced_accuracy': 0.6381533942927433, 'TP': 138, 'FP': 251, 'TN': 470, 'FN': 83, 'epochs_run': 6}
# {'candidate_i': 44, 'seed': 44042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.4882108183079057, 'recall_1': 0.6470588235294118, 'precision_1': 0.279296875, 'f1_1': 0.39017735334242837, 'accuracy': 0.5254777070063694, 'balanced_accuracy': 0.5676348209186588, 'TP': 143, 'FP': 369, 'TN': 352, 'FN': 78, 'epochs_run': 6}
# {'candidate_i': 45, 'seed': 45042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.49930651872399445, 'recall_1': 0.7375565610859729, 'precision_1': 0.3110687022900763, 'f1_1': 0.4375838926174497, 'accuracy': 0.5552016985138004, 'balanced_accuracy': 0.6184315399049837, 'TP': 163, 'FP': 361, 'TN': 360, 'FN': 58, 'epochs_run': 6}
# {'candidate_i': 46, 'seed': 46042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.6962552011095701, 'recall_1': 0.6380090497737556, 'precision_1': 0.39166666666666666, 'f1_1': 0.4853700516351119, 'accuracy': 0.6825902335456475, 'balanced_accuracy': 0.6671321254416629, 'TP': 141, 'FP': 219, 'TN': 502, 'FN': 80, 'epochs_run': 19}
# {'candidate_i': 47, 'seed': 47042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.6851595006934813, 'recall_1': 0.6380090497737556, 'precision_1': 0.38315217391304346, 'f1_1': 0.47877758913412566, 'accuracy': 0.6740976645435244, 'balanced_accuracy': 0.6615842752336185, 'TP': 141, 'FP': 227, 'TN': 494, 'FN': 80, 'epochs_run': 16}
# {'candidate_i': 48, 'seed': 48042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.6782246879334258, 'recall_1': 0.6515837104072398, 'precision_1': 0.3829787234042553, 'f1_1': 0.4824120603015075, 'accuracy': 0.6719745222929936, 'balanced_accuracy': 0.6649041991703328, 'TP': 144, 'FP': 232, 'TN': 489, 'FN': 77, 'epochs_run': 15}
#
# Detenido en epoch 2: Δrecall > 0.1
# {'candidate_i': 49, 'seed': 49042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.10818307905686546, 'recall_1': 0.9366515837104072, 'precision_1': 0.24352941176470588, 'f1_1': 0.3865546218487395, 'accuracy': 0.30254777070063693, 'balanced_accuracy': 0.5224173313836363, 'TP': 207, 'FP': 643, 'TN': 78, 'FN': 14, 'epochs_run': 2}
# {'candidate_i': 50, 'seed': 50042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.4590846047156727, 'recall_1': 0.7737556561085973, 'precision_1': 0.3048128342245989, 'f1_1': 0.4373401534526854, 'accuracy': 0.5329087048832272, 'balanced_accuracy': 0.6164201304121351, 'TP': 171, 'FP': 390, 'TN': 331, 'FN': 50, 'epochs_run': 6}
# {'candidate_i': 51, 'seed': 51042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.5256588072122053, 'recall_1': 0.6832579185520362, 'precision_1': 0.30628803245436104, 'f1_1': 0.42296918767507, 'accuracy': 0.5626326963906582, 'balanced_accuracy': 0.6044583628821207, 'TP': 151, 'FP': 342, 'TN': 379, 'FN': 70, 'epochs_run': 6}
# {'candidate_i': 52, 'seed': 52042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.5922330097087378, 'recall_1': 0.6380090497737556, 'precision_1': 0.32413793103448274, 'f1_1': 0.4298780487804878, 'accuracy': 0.6029723991507431, 'balanced_accuracy': 0.6151210297412467, 'TP': 141, 'FP': 294, 'TN': 427, 'FN': 80, 'epochs_run': 7}
# {'candidate_i': 53, 'seed': 53042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.651872399445215, 'recall_1': 0.6244343891402715, 'precision_1': 0.35475578406169667, 'f1_1': 0.4524590163934426, 'accuracy': 0.6454352441613588, 'balanced_accuracy': 0.6381533942927433, 'TP': 138, 'FP': 251, 'TN': 470, 'FN': 83, 'epochs_run': 8}
# {'candidate_i': 54, 'seed': 54042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6823855755894591, 'recall_1': 0.6380090497737556, 'precision_1': 0.3810810810810811, 'f1_1': 0.47715736040609136, 'accuracy': 0.6719745222929936, 'balanced_accuracy': 0.6601973126816074, 'TP': 141, 'FP': 229, 'TN': 492, 'FN': 80, 'epochs_run': 17}
# {'candidate_i': 55, 'seed': 55042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.44521497919556174, 'recall_1': 0.6787330316742082, 'precision_1': 0.2727272727272727, 'f1_1': 0.38910505836575876, 'accuracy': 0.5, 'balanced_accuracy': 0.561974005434885, 'TP': 150, 'FP': 400, 'TN': 321, 'FN': 71, 'epochs_run': 6}
# {'candidate_i': 56, 'seed': 56042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.6990291262135923, 'recall_1': 0.6380090497737556, 'precision_1': 0.39385474860335196, 'f1_1': 0.48704663212435234, 'accuracy': 0.6847133757961783, 'balanced_accuracy': 0.668519087993674, 'TP': 141, 'FP': 217, 'TN': 504, 'FN': 80, 'epochs_run': 15}
# {'candidate_i': 57, 'seed': 57042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.420249653259362, 'recall_1': 0.6968325791855203, 'precision_1': 0.2692307692307692, 'f1_1': 0.3883984867591425, 'accuracy': 0.4851380042462845, 'balanced_accuracy': 0.5585411162224412, 'TP': 154, 'FP': 418, 'TN': 303, 'FN': 67, 'epochs_run': 6}
# {'candidate_i': 58, 'seed': 58042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.6601941747572816, 'recall_1': 0.6470588235294118, 'precision_1': 0.36855670103092786, 'f1_1': 0.4696223316912972, 'accuracy': 0.6571125265392781, 'balanced_accuracy': 0.6536264991433467, 'TP': 143, 'FP': 245, 'TN': 476, 'FN': 78, 'epochs_run': 22}
# {'candidate_i': 59, 'seed': 59042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.6380027739251041, 'recall_1': 0.665158371040724, 'precision_1': 0.3602941176470588, 'f1_1': 0.46740858505564387, 'accuracy': 0.6443736730360934, 'balanced_accuracy': 0.651580572482914, 'TP': 147, 'FP': 261, 'TN': 460, 'FN': 74, 'epochs_run': 26}
# {'candidate_i': 60, 'seed': 60042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.5298196948682385, 'recall_1': 0.7149321266968326, 'precision_1': 0.317907444668008, 'f1_1': 0.4401114206128134, 'accuracy': 0.5732484076433121, 'balanced_accuracy': 0.6223759107825355, 'TP': 158, 'FP': 339, 'TN': 382, 'FN': 63, 'epochs_run': 8}
# {'candidate_i': 61, 'seed': 61042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.6185852981969486, 'recall_1': 0.6063348416289592, 'precision_1': 0.3276283618581907, 'f1_1': 0.4253968253968254, 'accuracy': 0.6157112526539278, 'balanced_accuracy': 0.6124600699129539, 'TP': 134, 'FP': 275, 'TN': 446, 'FN': 87, 'epochs_run': 7}
# {'candidate_i': 62, 'seed': 62042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.6643550624133149, 'recall_1': 0.6470588235294118, 'precision_1': 0.37142857142857144, 'f1_1': 0.47194719471947194, 'accuracy': 0.6602972399150743, 'balanced_accuracy': 0.6557069429713633, 'TP': 143, 'FP': 242, 'TN': 479, 'FN': 78, 'epochs_run': 12}
# {'candidate_i': 63, 'seed': 63042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.6754507628294036, 'recall_1': 0.5972850678733032, 'precision_1': 0.36065573770491804, 'f1_1': 0.4497444633730835, 'accuracy': 0.6571125265392781, 'balanced_accuracy': 0.6363679153513534, 'TP': 132, 'FP': 234, 'TN': 487, 'FN': 89, 'epochs_run': 6}
# {'candidate_i': 64, 'seed': 64042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.47295423023578365, 'recall_1': 0.6606334841628959, 'precision_1': 0.27756653992395436, 'f1_1': 0.3908969210174029, 'accuracy': 0.5169851380042463, 'balanced_accuracy': 0.5667938571993398, 'TP': 146, 'FP': 380, 'TN': 341, 'FN': 75, 'epochs_run': 6}
# {'candidate_i': 65, 'seed': 65042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.5714285714285714, 'recall_1': 0.6289592760180995, 'precision_1': 0.31026785714285715, 'f1_1': 0.4155455904334828, 'accuracy': 0.5849256900212314, 'balanced_accuracy': 0.6001939237233355, 'TP': 139, 'FP': 309, 'TN': 412, 'FN': 82, 'epochs_run': 6}
# {'candidate_i': 66, 'seed': 66042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.4521497919556172, 'recall_1': 0.6334841628959276, 'precision_1': 0.2616822429906542, 'f1_1': 0.37037037037037035, 'accuracy': 0.49469214437367304, 'balanced_accuracy': 0.5428169774257724, 'TP': 140, 'FP': 395, 'TN': 326, 'FN': 81, 'epochs_run': 6}
# {'candidate_i': 67, 'seed': 67042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.6823855755894591, 'recall_1': 0.6334841628959276, 'precision_1': 0.3794037940379404, 'f1_1': 0.4745762711864407, 'accuracy': 0.6709129511677282, 'balanced_accuracy': 0.6579348692426934, 'TP': 140, 'FP': 229, 'TN': 492, 'FN': 81, 'epochs_run': 14}
# {'candidate_i': 68, 'seed': 68042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.4798890429958391, 'recall_1': 0.7647058823529411, 'precision_1': 0.31066176470588236, 'f1_1': 0.4418300653594771, 'accuracy': 0.5467091295116773, 'balanced_accuracy': 0.6222974626743901, 'TP': 169, 'FP': 375, 'TN': 346, 'FN': 52, 'epochs_run': 6}
# {'candidate_i': 69, 'seed': 69042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.6490984743411928, 'recall_1': 0.6606334841628959, 'precision_1': 0.3659147869674185, 'f1_1': 0.47096774193548385, 'accuracy': 0.6518046709129511, 'balanced_accuracy': 0.6548659792520444, 'TP': 146, 'FP': 253, 'TN': 468, 'FN': 75, 'epochs_run': 31}
# {'candidate_i': 70, 'seed': 70042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 71, 'seed': 71042, 'u1': 64, 'a1': 'relu', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.6588072122052705, 'recall_1': 0.669683257918552, 'precision_1': 0.3756345177664975, 'f1_1': 0.4813008130081301, 'accuracy': 0.6613588110403397, 'balanced_accuracy': 0.6642452350619112, 'TP': 148, 'FP': 246, 'TN': 475, 'FN': 73, 'epochs_run': 21}
# {'candidate_i': 72, 'seed': 72042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.6796116504854369, 'recall_1': 0.6063348416289592, 'precision_1': 0.36712328767123287, 'f1_1': 0.45733788395904434, 'accuracy': 0.6624203821656051, 'balanced_accuracy': 0.6429732460571981, 'TP': 134, 'FP': 231, 'TN': 490, 'FN': 87, 'epochs_run': 15}
# {'candidate_i': 73, 'seed': 73042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.42579750346740636, 'recall_1': 0.7194570135746606, 'precision_1': 0.2774869109947644, 'f1_1': 0.4005037783375315, 'accuracy': 0.49469214437367304, 'balanced_accuracy': 0.5726272585210335, 'TP': 159, 'FP': 414, 'TN': 307, 'FN': 62, 'epochs_run': 6}
# {'candidate_i': 74, 'seed': 74042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.6671289875173371, 'recall_1': 0.6561085972850679, 'precision_1': 0.37662337662337664, 'f1_1': 0.47854785478547857, 'accuracy': 0.6645435244161358, 'balanced_accuracy': 0.6616187924012025, 'TP': 145, 'FP': 240, 'TN': 481, 'FN': 76, 'epochs_run': 16}
#
# Detenido en epoch 1: Δrecall > 0.1
# {'candidate_i': 75, 'seed': 75042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.6338418862690708, 'recall_1': 0.579185520361991, 'precision_1': 0.32653061224489793, 'f1_1': 0.4176182707993475, 'accuracy': 0.6210191082802548, 'balanced_accuracy': 0.6065137033155309, 'TP': 128, 'FP': 264, 'TN': 457, 'FN': 93, 'epochs_run': 1}
# {'candidate_i': 76, 'seed': 76042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.6851595006934813, 'recall_1': 0.6063348416289592, 'precision_1': 0.37119113573407203, 'f1_1': 0.46048109965635736, 'accuracy': 0.6666666666666666, 'balanced_accuracy': 0.6457471711612203, 'TP': 134, 'FP': 227, 'TN': 494, 'FN': 87, 'epochs_run': 10}
# {'candidate_i': 77, 'seed': 77042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.49653259361997226, 'recall_1': 0.6289592760180995, 'precision_1': 0.27689243027888444, 'f1_1': 0.38450899031811897, 'accuracy': 0.5276008492569002, 'balanced_accuracy': 0.5627459348190359, 'TP': 139, 'FP': 363, 'TN': 358, 'FN': 82, 'epochs_run': 6}
# {'candidate_i': 78, 'seed': 78042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.7018030513176144, 'recall_1': 0.6108597285067874, 'precision_1': 0.38571428571428573, 'f1_1': 0.47285464098073554, 'accuracy': 0.6804670912951167, 'balanced_accuracy': 0.656331389912201, 'TP': 135, 'FP': 215, 'TN': 506, 'FN': 86, 'epochs_run': 14}
# {'candidate_i': 79, 'seed': 79042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.5436893203883495, 'recall_1': 0.6380090497737556, 'precision_1': 0.3, 'f1_1': 0.4081041968162084, 'accuracy': 0.5658174097664543, 'balanced_accuracy': 0.5908491850810526, 'TP': 141, 'FP': 329, 'TN': 392, 'FN': 80, 'epochs_run': 6}
# {'candidate_i': 80, 'seed': 80042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.6324549237170597, 'recall_1': 0.6742081447963801, 'precision_1': 0.35990338164251207, 'f1_1': 0.4692913385826772, 'accuracy': 0.6422505307855626, 'balanced_accuracy': 0.6533315342567199, 'TP': 149, 'FP': 265, 'TN': 456, 'FN': 72, 'epochs_run': 6}
# {'candidate_i': 81, 'seed': 81042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 82, 'seed': 82042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.7004160887656034, 'recall_1': 0.6153846153846154, 'precision_1': 0.38636363636363635, 'f1_1': 0.47469458987783597, 'accuracy': 0.6804670912951167, 'balanced_accuracy': 0.6579003520751094, 'TP': 136, 'FP': 216, 'TN': 505, 'FN': 85, 'epochs_run': 13}
#
# Detenido en epoch 2: Δrecall > 0.1
# {'candidate_i': 83, 'seed': 83042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.04299583911234397, 'recall_1': 0.9140271493212669, 'precision_1': 0.226457399103139, 'f1_1': 0.36298292902066487, 'accuracy': 0.24734607218683652, 'balanced_accuracy': 0.47851149421680544, 'TP': 202, 'FP': 690, 'TN': 31, 'FN': 19, 'epochs_run': 2}
#
# Detenido en epoch 1: Δrecall > 0.1
# {'candidate_i': 84, 'seed': 84042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.5728155339805825, 'recall_1': 0.4841628959276018, 'precision_1': 0.25783132530120484, 'f1_1': 0.33647798742138363, 'accuracy': 0.5520169851380042, 'balanced_accuracy': 0.5284892149540922, 'TP': 107, 'FP': 308, 'TN': 413, 'FN': 114, 'epochs_run': 1}
# {'candidate_i': 85, 'seed': 85042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.6421636615811374, 'recall_1': 0.665158371040724, 'precision_1': 0.362962962962963, 'f1_1': 0.4696485623003195, 'accuracy': 0.6475583864118896, 'balanced_accuracy': 0.6536610163109307, 'TP': 147, 'FP': 258, 'TN': 463, 'FN': 74, 'epochs_run': 15}
# {'candidate_i': 86, 'seed': 86042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.6338418862690708, 'recall_1': 0.6742081447963801, 'precision_1': 0.36077481840193704, 'f1_1': 0.47003154574132494, 'accuracy': 0.643312101910828, 'balanced_accuracy': 0.6540250155327254, 'TP': 149, 'FP': 264, 'TN': 457, 'FN': 72, 'epochs_run': 7}
# {'candidate_i': 87, 'seed': 87042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.6199722607489597, 'recall_1': 0.6244343891402715, 'precision_1': 0.33495145631067963, 'f1_1': 0.43601895734597157, 'accuracy': 0.6210191082802548, 'balanced_accuracy': 0.6222033249446156, 'TP': 138, 'FP': 274, 'TN': 447, 'FN': 83, 'epochs_run': 6}
# {'candidate_i': 88, 'seed': 88042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.6768377253814147, 'recall_1': 0.6108597285067874, 'precision_1': 0.36684782608695654, 'f1_1': 0.45840407470288624, 'accuracy': 0.6613588110403397, 'balanced_accuracy': 0.6438487269441011, 'TP': 135, 'FP': 233, 'TN': 488, 'FN': 86, 'epochs_run': 11}
# {'candidate_i': 89, 'seed': 89042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.6074895977808599, 'recall_1': 0.6606334841628959, 'precision_1': 0.34032634032634035, 'f1_1': 0.4492307692307692, 'accuracy': 0.6199575371549894, 'balanced_accuracy': 0.634061540971878, 'TP': 146, 'FP': 283, 'TN': 438, 'FN': 75, 'epochs_run': 6}
# {'candidate_i': 90, 'seed': 90042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6907073509015257, 'recall_1': 0.6199095022624435, 'precision_1': 0.38055555555555554, 'f1_1': 0.47160068846815834, 'accuracy': 0.6740976645435244, 'balanced_accuracy': 0.6553084265819846, 'TP': 137, 'FP': 223, 'TN': 498, 'FN': 84, 'epochs_run': 19}
# {'candidate_i': 91, 'seed': 91042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.6962552011095701, 'recall_1': 0.6244343891402715, 'precision_1': 0.3865546218487395, 'f1_1': 0.47750865051903113, 'accuracy': 0.6794055201698513, 'balanced_accuracy': 0.6603447951249208, 'TP': 138, 'FP': 219, 'TN': 502, 'FN': 83, 'epochs_run': 9}
# {'candidate_i': 92, 'seed': 92042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.7128987517337032, 'recall_1': 0.6108597285067874, 'precision_1': 0.39473684210526316, 'f1_1': 0.47957371225577267, 'accuracy': 0.6889596602972399, 'balanced_accuracy': 0.6618792401202453, 'TP': 135, 'FP': 207, 'TN': 514, 'FN': 86, 'epochs_run': 13}
# {'candidate_i': 93, 'seed': 93042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.6796116504854369, 'recall_1': 0.6289592760180995, 'precision_1': 0.37567567567567567, 'f1_1': 0.4703891708967851, 'accuracy': 0.667728237791932, 'balanced_accuracy': 0.6542854632517683, 'TP': 139, 'FP': 231, 'TN': 490, 'FN': 82, 'epochs_run': 18}
# {'candidate_i': 94, 'seed': 94042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 95, 'seed': 95042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.6879334257975035, 'recall_1': 0.6289592760180995, 'precision_1': 0.38186813186813184, 'f1_1': 0.4752136752136752, 'accuracy': 0.6740976645435244, 'balanced_accuracy': 0.6584463509078016, 'TP': 139, 'FP': 225, 'TN': 496, 'FN': 82, 'epochs_run': 18}
# {'candidate_i': 96, 'seed': 96042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.6685159500693482, 'recall_1': 0.6561085972850679, 'precision_1': 0.3776041666666667, 'f1_1': 0.4793388429752066, 'accuracy': 0.6656050955414012, 'balanced_accuracy': 0.662312273677208, 'TP': 145, 'FP': 239, 'TN': 482, 'FN': 76, 'epochs_run': 19}
# {'candidate_i': 97, 'seed': 97042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.6033287101248266, 'recall_1': 0.7058823529411765, 'precision_1': 0.35294117647058826, 'f1_1': 0.47058823529411764, 'accuracy': 0.6273885350318471, 'balanced_accuracy': 0.6546055315330015, 'TP': 156, 'FP': 286, 'TN': 435, 'FN': 65, 'epochs_run': 8}
# {'candidate_i': 98, 'seed': 98042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.5256588072122053, 'recall_1': 0.5972850678733032, 'precision_1': 0.27848101265822783, 'f1_1': 0.37985611510791367, 'accuracy': 0.5424628450106157, 'balanced_accuracy': 0.5614719375427542, 'TP': 132, 'FP': 342, 'TN': 379, 'FN': 89, 'epochs_run': 6}
# {'candidate_i': 99, 'seed': 99042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.5450762829403606, 'recall_1': 0.6470588235294118, 'precision_1': 0.3036093418259023, 'f1_1': 0.41329479768786126, 'accuracy': 0.5690021231422505, 'balanced_accuracy': 0.5960675532348862, 'TP': 143, 'FP': 328, 'TN': 393, 'FN': 78, 'epochs_run': 6}
# {'candidate_i': 100, 'seed': 100042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.6754507628294036, 'recall_1': 0.6199095022624435, 'precision_1': 0.3692722371967655, 'f1_1': 0.46283783783783783, 'accuracy': 0.6624203821656051, 'balanced_accuracy': 0.6476801325459236, 'TP': 137, 'FP': 234, 'TN': 487, 'FN': 84, 'epochs_run': 10}
# {'candidate_i': 101, 'seed': 101042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.6463245492371706, 'recall_1': 0.6108597285067874, 'precision_1': 0.34615384615384615, 'f1_1': 0.44189852700491, 'accuracy': 0.638004246284501, 'balanced_accuracy': 0.6285921388719791, 'TP': 135, 'FP': 255, 'TN': 466, 'FN': 86, 'epochs_run': 7}
# {'candidate_i': 102, 'seed': 102042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6782246879334258, 'recall_1': 0.6108597285067874, 'precision_1': 0.3678474114441417, 'f1_1': 0.45918367346938777, 'accuracy': 0.6624203821656051, 'balanced_accuracy': 0.6445422082201067, 'TP': 135, 'FP': 232, 'TN': 489, 'FN': 86, 'epochs_run': 18}
# {'candidate_i': 103, 'seed': 103042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.6823855755894591, 'recall_1': 0.6425339366515838, 'precision_1': 0.38274932614555257, 'f1_1': 0.4797297297297297, 'accuracy': 0.673036093418259, 'balanced_accuracy': 0.6624597561205214, 'TP': 142, 'FP': 229, 'TN': 492, 'FN': 79, 'epochs_run': 18}
# {'candidate_i': 104, 'seed': 104042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.6865464632454924, 'recall_1': 0.6063348416289592, 'precision_1': 0.37222222222222223, 'f1_1': 0.4612736660929432, 'accuracy': 0.667728237791932, 'balanced_accuracy': 0.6464406524372258, 'TP': 134, 'FP': 226, 'TN': 495, 'FN': 87, 'epochs_run': 7}
# {'candidate_i': 105, 'seed': 105042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.651872399445215, 'recall_1': 0.6561085972850679, 'precision_1': 0.3661616161616162, 'f1_1': 0.4700162074554295, 'accuracy': 0.6528662420382165, 'balanced_accuracy': 0.6539904983651414, 'TP': 145, 'FP': 251, 'TN': 470, 'FN': 76, 'epochs_run': 28}
# {'candidate_i': 106, 'seed': 106042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 107, 'seed': 107042, 'u1': 64, 'a1': 'relu', 'd1': 0.1, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 108, 'seed': 108042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.7031900138696255, 'recall_1': 0.579185520361991, 'precision_1': 0.3742690058479532, 'f1_1': 0.4547069271758437, 'accuracy': 0.6740976645435244, 'balanced_accuracy': 0.6411877671158083, 'TP': 128, 'FP': 214, 'TN': 507, 'FN': 93, 'epochs_run': 7}
# {'candidate_i': 109, 'seed': 109042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.6421636615811374, 'recall_1': 0.6425339366515838, 'precision_1': 0.355, 'f1_1': 0.4573268921095008, 'accuracy': 0.6422505307855626, 'balanced_accuracy': 0.6423487991163606, 'TP': 142, 'FP': 258, 'TN': 463, 'FN': 79, 'epochs_run': 9}
# {'candidate_i': 110, 'seed': 110042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.6671289875173371, 'recall_1': 0.6199095022624435, 'precision_1': 0.363395225464191, 'f1_1': 0.45819397993311034, 'accuracy': 0.6560509554140127, 'balanced_accuracy': 0.6435192448898903, 'TP': 137, 'FP': 240, 'TN': 481, 'FN': 84, 'epochs_run': 17}
# {'candidate_i': 111, 'seed': 111042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.680998613037448, 'recall_1': 0.6334841628959276, 'precision_1': 0.3783783783783784, 'f1_1': 0.47377326565143824, 'accuracy': 0.6698513800424628, 'balanced_accuracy': 0.6572413879666879, 'TP': 140, 'FP': 230, 'TN': 491, 'FN': 81, 'epochs_run': 8}
# {'candidate_i': 112, 'seed': 112042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.6754507628294036, 'recall_1': 0.6199095022624435, 'precision_1': 0.3692722371967655, 'f1_1': 0.46283783783783783, 'accuracy': 0.6624203821656051, 'balanced_accuracy': 0.6476801325459236, 'TP': 137, 'FP': 234, 'TN': 487, 'FN': 84, 'epochs_run': 7}
# {'candidate_i': 113, 'seed': 113042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.6976421636615812, 'recall_1': 0.6199095022624435, 'precision_1': 0.38591549295774646, 'f1_1': 0.4756944444444444, 'accuracy': 0.6794055201698513, 'balanced_accuracy': 0.6587758329620124, 'TP': 137, 'FP': 218, 'TN': 503, 'FN': 84, 'epochs_run': 9}
# {'candidate_i': 114, 'seed': 114042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6601941747572816, 'recall_1': 0.6244343891402715, 'precision_1': 0.360313315926893, 'f1_1': 0.45695364238410596, 'accuracy': 0.6518046709129511, 'balanced_accuracy': 0.6423142819487766, 'TP': 138, 'FP': 245, 'TN': 476, 'FN': 83, 'epochs_run': 6}
# {'candidate_i': 115, 'seed': 115042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.624133148404993, 'recall_1': 0.6380090497737556, 'precision_1': 0.3422330097087379, 'f1_1': 0.44549763033175355, 'accuracy': 0.6273885350318471, 'balanced_accuracy': 0.6310710990893743, 'TP': 141, 'FP': 271, 'TN': 450, 'FN': 80, 'epochs_run': 6}
# {'candidate_i': 116, 'seed': 116042, 'u1': 64, 'a1': 'linear', 'd1': 0.3, 'u2': 16, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.6879334257975035, 'recall_1': 0.6470588235294118, 'precision_1': 0.38858695652173914, 'f1_1': 0.4855687606112054, 'accuracy': 0.678343949044586, 'balanced_accuracy': 0.6674961246634576, 'TP': 143, 'FP': 225, 'TN': 496, 'FN': 78, 'epochs_run': 10}
# ...
# {'candidate_i': 1134, 'seed': 1134042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6643550624133149, 'recall_1': 0.6832579185520362, 'precision_1': 0.3842239185750636, 'f1_1': 0.49185667752442996, 'accuracy': 0.6687898089171974, 'balanced_accuracy': 0.6738064904826755, 'TP': 151, 'FP': 242, 'TN': 479, 'FN': 70, 'epochs_run': 14}
# {'candidate_i': 1135, 'seed': 1135042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.6601941747572816, 'recall_1': 0.6063348416289592, 'precision_1': 0.35356200527704484, 'f1_1': 0.44666666666666666, 'accuracy': 0.6475583864118896, 'balanced_accuracy': 0.6332645081931204, 'TP': 134, 'FP': 245, 'TN': 476, 'FN': 87, 'epochs_run': 8}
# {'candidate_i': 1136, 'seed': 1136042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.6158113730929264, 'recall_1': 0.5927601809954751, 'precision_1': 0.32107843137254904, 'f1_1': 0.4165341812400636, 'accuracy': 0.6104033970276008, 'balanced_accuracy': 0.6042857770442007, 'TP': 131, 'FP': 277, 'TN': 444, 'FN': 90, 'epochs_run': 7}
# {'candidate_i': 1137, 'seed': 1137042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.39389736477115117, 'recall_1': 0.7918552036199095, 'precision_1': 0.28594771241830064, 'f1_1': 0.42016806722689076, 'accuracy': 0.4872611464968153, 'balanced_accuracy': 0.5928762841955303, 'TP': 175, 'FP': 437, 'TN': 284, 'FN': 46, 'epochs_run': 6}
# {'candidate_i': 1138, 'seed': 1138042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
#
# Detenido en epoch 3: Δrecall > 0.1
# {'candidate_i': 1139, 'seed': 1139042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.7004160887656034, 'recall_1': 0.3755656108597285, 'precision_1': 0.27759197324414714, 'f1_1': 0.3192307692307692, 'accuracy': 0.6242038216560509, 'balanced_accuracy': 0.537990849812666, 'TP': 83, 'FP': 216, 'TN': 505, 'FN': 138, 'epochs_run': 3}
# {'candidate_i': 1140, 'seed': 1140042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.6629680998613038, 'recall_1': 0.665158371040724, 'precision_1': 0.3769230769230769, 'f1_1': 0.48117839607201307, 'accuracy': 0.6634819532908705, 'balanced_accuracy': 0.6640632354510139, 'TP': 147, 'FP': 243, 'TN': 478, 'FN': 74, 'epochs_run': 36}
# {'candidate_i': 1141, 'seed': 1141042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.05409153952843273, 'recall_1': 0.9457013574660633, 'precision_1': 0.2345679012345679, 'f1_1': 0.37589928057553956, 'accuracy': 0.2632696390658174, 'balanced_accuracy': 0.499896448497248, 'TP': 209, 'FP': 682, 'TN': 39, 'FN': 12, 'epochs_run': 6}
# {'candidate_i': 1142, 'seed': 1142042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.6546463245492372, 'recall_1': 0.6742081447963801, 'precision_1': 0.3743718592964824, 'f1_1': 0.481421647819063, 'accuracy': 0.6592356687898089, 'balanced_accuracy': 0.6644272346728086, 'TP': 149, 'FP': 249, 'TN': 472, 'FN': 72, 'epochs_run': 19}
# {'candidate_i': 1143, 'seed': 1143042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.6726768377253814, 'recall_1': 0.6470588235294118, 'precision_1': 0.37730870712401055, 'f1_1': 0.4766666666666667, 'accuracy': 0.6666666666666666, 'balanced_accuracy': 0.6598678306273966, 'TP': 143, 'FP': 236, 'TN': 485, 'FN': 78, 'epochs_run': 15}
# {'candidate_i': 1144, 'seed': 1144042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.6269070735090153, 'recall_1': 0.6199095022624435, 'precision_1': 0.3374384236453202, 'f1_1': 0.4370015948963317, 'accuracy': 0.6252653927813163, 'balanced_accuracy': 0.6234082878857294, 'TP': 137, 'FP': 269, 'TN': 452, 'FN': 84, 'epochs_run': 9}
# {'candidate_i': 1145, 'seed': 1145042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.7142857142857143, 'recall_1': 0.6108597285067874, 'precision_1': 0.39589442815249265, 'f1_1': 0.4804270462633452, 'accuracy': 0.6900212314225053, 'balanced_accuracy': 0.6625727213962509, 'TP': 135, 'FP': 206, 'TN': 515, 'FN': 86, 'epochs_run': 14}
# {'candidate_i': 1146, 'seed': 1146042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6477115117891817, 'recall_1': 0.6289592760180995, 'precision_1': 0.35368956743002544, 'f1_1': 0.4527687296416938, 'accuracy': 0.643312101910828, 'balanced_accuracy': 0.6383353939036407, 'TP': 139, 'FP': 254, 'TN': 467, 'FN': 82, 'epochs_run': 13}
# {'candidate_i': 1147, 'seed': 1147042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.7253814147018031, 'recall_1': 0.6244343891402715, 'precision_1': 0.4107142857142857, 'f1_1': 0.4955116696588869, 'accuracy': 0.7016985138004246, 'balanced_accuracy': 0.6749079019210373, 'TP': 138, 'FP': 198, 'TN': 523, 'FN': 83, 'epochs_run': 11}
# {'candidate_i': 1148, 'seed': 1148042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.6574202496532594, 'recall_1': 0.6244343891402715, 'precision_1': 0.35844155844155845, 'f1_1': 0.45544554455445546, 'accuracy': 0.6496815286624203, 'balanced_accuracy': 0.6409273193967655, 'TP': 138, 'FP': 247, 'TN': 474, 'FN': 83, 'epochs_run': 12}
# {'candidate_i': 1149, 'seed': 1149042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 1150, 'seed': 1150042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.016643550624133148, 'recall_1': 0.9864253393665159, 'precision_1': 0.23516720604099245, 'f1_1': 0.3797909407665505, 'accuracy': 0.24416135881104034, 'balanced_accuracy': 0.5015344449953245, 'TP': 218, 'FP': 709, 'TN': 12, 'FN': 3, 'epochs_run': 6}
# {'candidate_i': 1151, 'seed': 1151042, 'u1': 16, 'a1': 'tanh', 'd1': 0.2, 'u2': 4, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.6754507628294036, 'recall_1': 0.6244343891402715, 'precision_1': 0.3709677419354839, 'f1_1': 0.4654300168634064, 'accuracy': 0.6634819532908705, 'balanced_accuracy': 0.6499425759848376, 'TP': 138, 'FP': 234, 'TN': 487, 'FN': 83, 'epochs_run': 19}
# {'candidate_i': 1152, 'seed': 1152042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.36615811373092927, 'recall_1': 0.8552036199095022, 'precision_1': 0.29256965944272445, 'f1_1': 0.4359861591695502, 'accuracy': 0.48089171974522293, 'balanced_accuracy': 0.6106808668202157, 'TP': 189, 'FP': 457, 'TN': 264, 'FN': 32, 'epochs_run': 6}
# {'candidate_i': 1153, 'seed': 1153042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.5159500693481276, 'recall_1': 0.6199095022624435, 'precision_1': 0.28189300411522633, 'f1_1': 0.38755304101838756, 'accuracy': 0.5403397027600849, 'balanced_accuracy': 0.5679297858052855, 'TP': 137, 'FP': 349, 'TN': 372, 'FN': 84, 'epochs_run': 7}
# {'candidate_i': 1154, 'seed': 1154042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.6754507628294036, 'recall_1': 0.6470588235294118, 'precision_1': 0.3793103448275862, 'f1_1': 0.4782608695652174, 'accuracy': 0.6687898089171974, 'balanced_accuracy': 0.6612547931794077, 'TP': 143, 'FP': 234, 'TN': 487, 'FN': 78, 'epochs_run': 14}
# {'candidate_i': 1155, 'seed': 1155042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.6907073509015257, 'recall_1': 0.6289592760180995, 'precision_1': 0.3839779005524862, 'f1_1': 0.47684391080617494, 'accuracy': 0.6762208067940552, 'balanced_accuracy': 0.6598333134598127, 'TP': 139, 'FP': 223, 'TN': 498, 'FN': 82, 'epochs_run': 16}
# {'candidate_i': 1156, 'seed': 1156042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.6199722607489597, 'recall_1': 0.6199095022624435, 'precision_1': 0.3333333333333333, 'f1_1': 0.43354430379746833, 'accuracy': 0.6199575371549894, 'balanced_accuracy': 0.6199408815057016, 'TP': 137, 'FP': 274, 'TN': 447, 'FN': 84, 'epochs_run': 6}
# {'candidate_i': 1157, 'seed': 1157042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.6934812760055479, 'recall_1': 0.6380090497737556, 'precision_1': 0.38950276243093923, 'f1_1': 0.483704974271012, 'accuracy': 0.6804670912951167, 'balanced_accuracy': 0.6657451628896518, 'TP': 141, 'FP': 221, 'TN': 500, 'FN': 80, 'epochs_run': 16}
# {'candidate_i': 1158, 'seed': 1158042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.6837725381414702, 'recall_1': 0.6425339366515838, 'precision_1': 0.3837837837837838, 'f1_1': 0.4805414551607445, 'accuracy': 0.6740976645435244, 'balanced_accuracy': 0.663153237396527, 'TP': 142, 'FP': 228, 'TN': 493, 'FN': 79, 'epochs_run': 16}
# {'candidate_i': 1159, 'seed': 1159042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.7031900138696255, 'recall_1': 0.6334841628959276, 'precision_1': 0.3954802259887006, 'f1_1': 0.48695652173913045, 'accuracy': 0.6868365180467091, 'balanced_accuracy': 0.6683370883827766, 'TP': 140, 'FP': 214, 'TN': 507, 'FN': 81, 'epochs_run': 14}
# {'candidate_i': 1160, 'seed': 1160042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.6962552011095701, 'recall_1': 0.6244343891402715, 'precision_1': 0.3865546218487395, 'f1_1': 0.47750865051903113, 'accuracy': 0.6794055201698513, 'balanced_accuracy': 0.6603447951249208, 'TP': 138, 'FP': 219, 'TN': 502, 'FN': 83, 'epochs_run': 12}
# {'candidate_i': 1161, 'seed': 1161042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 1162, 'seed': 1162042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.0, 'recall_1': 1.0, 'precision_1': 0.2346072186836518, 'f1_1': 0.38005159071367156, 'accuracy': 0.2346072186836518, 'balanced_accuracy': 0.5, 'TP': 221, 'FP': 721, 'TN': 0, 'FN': 0, 'epochs_run': 6}
# {'candidate_i': 1163, 'seed': 1163042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 16, 'a2': 'sigmoid', 'd2': 0.0, 'recall_0': 0.6893203883495146, 'recall_1': 0.6515837104072398, 'precision_1': 0.391304347826087, 'f1_1': 0.48896434634974534, 'accuracy': 0.6804670912951167, 'balanced_accuracy': 0.6704520493783772, 'TP': 144, 'FP': 224, 'TN': 497, 'FN': 77, 'epochs_run': 17}
# {'candidate_i': 1164, 'seed': 1164042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.1, 'recall_0': 0.6768377253814147, 'recall_1': 0.6470588235294118, 'precision_1': 0.3803191489361702, 'f1_1': 0.47906197654941374, 'accuracy': 0.6698513800424628, 'balanced_accuracy': 0.6619482744554133, 'TP': 143, 'FP': 233, 'TN': 488, 'FN': 78, 'epochs_run': 32}
# {'candidate_i': 1165, 'seed': 1165042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.05, 'recall_0': 0.44660194174757284, 'recall_1': 0.746606334841629, 'precision_1': 0.2925531914893617, 'f1_1': 0.42038216560509556, 'accuracy': 0.5169851380042463, 'balanced_accuracy': 0.5966041382946009, 'TP': 165, 'FP': 399, 'TN': 322, 'FN': 56, 'epochs_run': 6}
#
# Detenido en epoch 2: Δrecall > 0.1
# {'candidate_i': 1166, 'seed': 1166042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'relu', 'd2': 0.0, 'recall_0': 0.34119278779472956, 'recall_1': 0.7104072398190046, 'precision_1': 0.24841772151898733, 'f1_1': 0.36811254396248533, 'accuracy': 0.4278131634819533, 'balanced_accuracy': 0.525800013806867, 'TP': 157, 'FP': 475, 'TN': 246, 'FN': 64, 'epochs_run': 2}
# Exception ignored in: <function WeakKeyDictionary.__init__.<locals>.remove at 0x1212804a0>
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.13_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/weakref.py", line 369, in remove
#     def remove(k, selfref=ref(self)):
#
# KeyboardInterrupt:
# {'candidate_i': 1167, 'seed': 1167042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.1, 'recall_0': 0.6920943134535368, 'recall_1': 0.6289592760180995, 'precision_1': 0.3850415512465374, 'f1_1': 0.47766323024054985, 'accuracy': 0.6772823779193206, 'balanced_accuracy': 0.6605267947358182, 'TP': 139, 'FP': 222, 'TN': 499, 'FN': 82, 'epochs_run': 11}
# {'candidate_i': 1168, 'seed': 1168042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.05, 'recall_0': 0.6782246879334258, 'recall_1': 0.6153846153846154, 'precision_1': 0.3695652173913043, 'f1_1': 0.4617996604414261, 'accuracy': 0.6634819532908705, 'balanced_accuracy': 0.6468046516590207, 'TP': 136, 'FP': 232, 'TN': 489, 'FN': 85, 'epochs_run': 13}
# {'candidate_i': 1169, 'seed': 1169042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'linear', 'd2': 0.0, 'recall_0': 0.7073509015256588, 'recall_1': 0.6289592760180995, 'precision_1': 0.39714285714285713, 'f1_1': 0.4868651488616462, 'accuracy': 0.6889596602972399, 'balanced_accuracy': 0.6681550887718792, 'TP': 139, 'FP': 211, 'TN': 510, 'FN': 82, 'epochs_run': 16}
# {'candidate_i': 1170, 'seed': 1170042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.1, 'recall_0': 0.694868238557559, 'recall_1': 0.6199095022624435, 'precision_1': 0.38375350140056025, 'f1_1': 0.4740484429065744, 'accuracy': 0.6772823779193206, 'balanced_accuracy': 0.6573888704100013, 'TP': 137, 'FP': 220, 'TN': 501, 'FN': 84, 'epochs_run': 16}
# Exception ignored in: <function WeakKeyDictionary.__init__.<locals>.remove at 0x1212804a0>
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.13_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/weakref.py", line 369, in remove
#     def remove(k, selfref=ref(self)):
#
# KeyboardInterrupt:
# {'candidate_i': 1171, 'seed': 1171042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.05, 'recall_0': 0.6823855755894591, 'recall_1': 0.6244343891402715, 'precision_1': 0.3760217983651226, 'f1_1': 0.46938775510204084, 'accuracy': 0.6687898089171974, 'balanced_accuracy': 0.6534099823648654, 'TP': 138, 'FP': 229, 'TN': 492, 'FN': 83, 'epochs_run': 19}
#
# Detenido en epoch 4: Δrecall > 0.1
# {'candidate_i': 1172, 'seed': 1172042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'tanh', 'd2': 0.0, 'recall_0': 0.5963938973647711, 'recall_1': 0.5158371040723982, 'precision_1': 0.2814814814814815, 'f1_1': 0.36421725239616615, 'accuracy': 0.5774946921443737, 'balanced_accuracy': 0.5561155007185847, 'TP': 114, 'FP': 291, 'TN': 430, 'FN': 107, 'epochs_run': 4}
# {'candidate_i': 1173, 'seed': 1173042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.1, 'recall_0': 0.6726768377253814, 'recall_1': 0.6199095022624435, 'precision_1': 0.3672922252010724, 'f1_1': 0.4612794612794613, 'accuracy': 0.6602972399150743, 'balanced_accuracy': 0.6462931699939125, 'TP': 137, 'FP': 236, 'TN': 485, 'FN': 84, 'epochs_run': 21}
# {'candidate_i': 1174, 'seed': 1174042, 'u1': 16, 'a1': 'tanh', 'd1': 0.1, 'u2': 8, 'a2': 'sigmoid', 'd2': 0.05, 'recall_0': 0.6740638002773925, 'recall_1': 0.6289592760180995, 'precision_1': 0.3716577540106952, 'f1_1': 0.4672268907563025, 'accuracy': 0.6634819532908705, 'balanced_accuracy': 0.6515115381477461, 'TP': 139, 'FP': 235, 'TN': 486, 'FN': 82, 'epochs_run': 23}

# %%
# CHECK opcional: ejecutar SOLO después de que haya terminado la celda principal.
# No usa variables internas de la función; lee directamente el CSV generado.
import pandas as pd
from sklearn.metrics import classification_report
from pathlib import Path

pred_path = Path("./content/perpetrator/predictions_with_probs.csv")

if pred_path.exists():
    df_pred = pd.read_csv(pred_path)
    print("Saved:", pred_path)
    print(df_pred.head())
    print(df_pred.shape)
    print(df_pred.columns.tolist())

    print("\n=== FINAL REPORT — PERPETRATOR CSV ===")
    print(classification_report(df_pred["y_true_perp"], df_pred["y_pred_perp"], digits=3))
else:
    print("Todavía no existe:", pred_path)
    print("Ejecuta primero la celda principal que entrena el modelo.")
